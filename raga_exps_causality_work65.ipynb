# %%
import pandas as pd
import data
from utils import distances, draw, parallelizer
import numpy as np
import multiprocessing

# %%
df = pd.read_csv("/home/efm-workstation/notations/65/himadrisute-parsed.txt")
df_filtered1 = df[df[" Note"] < 99999]

df = pd.read_csv("/home/efm-workstation/notations/65/jalajakshi-parsed.txt")
df_filtered2 = df[df[" Note"] < 99999]

df = pd.read_csv("/home/efm-workstation/notations/65/kamalambam-parsed.txt")
df_filtered3 = df[df[" Note"] < 99999]

df = pd.read_csv("/home/efm-workstation/notations/65/nidhicala-parsed.txt")
df_filtered4 = df[df[" Note"] < 99999]

df = pd.read_csv("/home/efm-workstation/notations/65/pankajalocana-parsed.txt")#"/home/efm-workstation/notations/65/jalajakshi-parsed.txt")
df_filtered5 = df[df[" Note"] < 99999]

df = pd.read_csv("/home/efm-workstation/notations/65/raghunayaka-parsed.txt")
df_filtered6 = df[df[" Note"] < 99999]

df = pd.read_csv("/home/efm-workstation/notations/65/sivakaameswari-parsed.txt")
df_filtered7 = df[df[" Note"] < 99999]

df = pd.read_csv("/home/efm-workstation/notations/65/sive-pahimam-parsed.txt")
df_filtered8 = df[df[" Note"] < 99999]

df = pd.read_csv("/home/efm-workstation/notations/65/vaarana-parsed.txt")
df_filtered9 = df[df[" Note"] < 99999]

df = pd.read_csv("/home/efm-workstation/notations/65/vatapi-parsed.txt")
df_filtered10 = df[df[" Note"] < 99999]

df = pd.read_csv("/home/efm-workstation/notations/65/surrogate-parsed.txt")
df_filtered11 = df[df[" Note"] < 99999]

df = pd.read_csv("/home/efm-workstation/notations/65/surrogate2-parsed.txt")
df_filtered13 = df[df[" Note"] < 99999]

df = pd.read_csv("/home/efm-workstation/notations/65/surrogate_d-parsed.txt")
df_filtered12 = df[df[" Note"] < 99999]

df = pd.read_csv("/home/efm-workstation/notations/65/surrogate2_d-parsed.txt")
df_filtered14 = df[df[" Note"] < 99999]

song_coords1 = []
for i in range(len(df_filtered1)):
    song_coords1.append((df_filtered1.iloc[i, 0], df_filtered1.iloc[i, 1], df_filtered1.iloc[i, 2]))


song_coords2 = []
for i in range(len(df_filtered2)):
    song_coords2.append((df_filtered2.iloc[i, 0], df_filtered2.iloc[i, 1], df_filtered2.iloc[i, 2]))


song_coords3 = []
for i in range(len(df_filtered3)):
    song_coords3.append((df_filtered3.iloc[i, 0], df_filtered3.iloc[i, 1], df_filtered3.iloc[i, 2]))


song_coords4 = []
for i in range(len(df_filtered4)):
    song_coords4.append((df_filtered4.iloc[i, 0], df_filtered4.iloc[i, 1], df_filtered4.iloc[i, 2]))


song_coords5 = []
for i in range(len(df_filtered5)):
    song_coords5.append((df_filtered5.iloc[i, 0], df_filtered5.iloc[i, 1], df_filtered5.iloc[i, 2]))


song_coords6 = []
for i in range(len(df_filtered6)):
    song_coords6.append((df_filtered6.iloc[i, 0], df_filtered6.iloc[i, 1], df_filtered6.iloc[i, 2]))


song_coords7 = []
for i in range(len(df_filtered7)):
    song_coords7.append((df_filtered7.iloc[i, 0], df_filtered7.iloc[i, 1], df_filtered7.iloc[i, 2]))


song_coords8 = []
for i in range(len(df_filtered8)):
    song_coords8.append((df_filtered8.iloc[i, 0], df_filtered8.iloc[i, 1], df_filtered8.iloc[i, 2]))

song_coords9 = []
for i in range(len(df_filtered9)):
    song_coords9.append((df_filtered9.iloc[i, 0], df_filtered9.iloc[i, 1], df_filtered9.iloc[i, 2]))

song_coords10 = []
for i in range(len(df_filtered10)):
    song_coords10.append((df_filtered10.iloc[i, 0], df_filtered10.iloc[i, 1], df_filtered10.iloc[i, 2]))
song_coords11 = []
for i in range(len(df_filtered11)):
    song_coords11.append((df_filtered11.iloc[i, 0], df_filtered11.iloc[i, 1], df_filtered11.iloc[i, 2]))

song_coords12 = []
for i in range(len(df_filtered12)):
    song_coords12.append((df_filtered12.iloc[i, 0], df_filtered12.iloc[i, 1], df_filtered12.iloc[i, 2]))

song_coords13 = []
for i in range(len(df_filtered13)):
    song_coords13.append((df_filtered13.iloc[i, 0], df_filtered13.iloc[i, 1], df_filtered13.iloc[i, 2]))

song_coords14 = []
for i in range(len(df_filtered14)):
    song_coords14.append((df_filtered14.iloc[i, 0], df_filtered14.iloc[i, 1], df_filtered14.iloc[i, 2]))

# %%
# def calc_metrics(all_coords):
#     dist_matrix = np.zeros((len(all_coords), len(all_coords)))
#     for i in range(len(all_coords)):
#         for j in range(len(all_coords)):
#             dist_matrix[i, j] = distances.dtwEuclidean(all_coords[i], all_coords[j], len(all_coords[i]), len(all_coords[j]))

    # return dist_matrix
lists = [song_coords1, song_coords2, song_coords3, song_coords4, song_coords5, song_coords6, song_coords7, song_coords8, song_coords9, song_coords10]

dists = parallelizer.list_parallelizer(distances.dtwEuclidean, lists)

# %%
labels = ["Himadri-Sute(Kalyani)", "Jalajakshi(Hamsadhwani)", "Kamalambam(Kalyani)", "nidhi-chala(Kalyani)", "Pankaja-lochana(Kalyani)", "raghunaayaka(Hamsadhwani)", "sivakaameswari(Kalyani)", "Sive-Pahi Maam(Kalyani)", "vaarana mukha va(Hamsadhwani)", "vatapi-ganapathim(Hamsadhwani)", "surrogate(Kalyani)", "surrogate(Hamsadhwani)", "surrogate2(Kalyani)", "surrogate2(Hamsadhwani)"]

# draw.draw_weighted_graph(dists, 5000, labels)

from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt
def llf(id):
    return labels[id]
Z = linkage(dists, 'single')
fig = plt.figure()
dn = dendrogram(Z, leaf_label_func=llf, leaf_rotation=0, orientation='right')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e9f242a43ecc> in <module>
#       7 def llf(id):
#       8     return labels[id]
# ----> 9 Z = linkage(dists, 'single')
#      10 fig = plt.figure()
#      11 dn = dendrogram(Z, leaf_label_func=llf, leaf_rotation=0, orientation='right')
#
# NameError: name 'dists' is not defined

# %%
song_coords1 = data.GetAdjustedMelody(song_coords1)
song_coords2 = data.GetAdjustedMelody(song_coords2)
song_coords3 = data.GetAdjustedMelody(song_coords3)
song_coords4 = data.GetAdjustedMelody(song_coords4)
song_coords5 = data.GetAdjustedMelody(song_coords5)
song_coords6 = data.GetAdjustedMelody(song_coords6)
song_coords7 = data.GetAdjustedMelody(song_coords7)
song_coords8 = data.GetAdjustedMelody(song_coords8)
song_coords9 = data.GetAdjustedMelody(song_coords9)
song_coords10 = data.GetAdjustedMelody(song_coords10)
song_coords11 = data.GetAdjustedMelody(song_coords11)
song_coords12 = data.GetAdjustedMelody(song_coords12)
song_coords13 = data.GetAdjustedMelody(song_coords13)
song_coords14 = data.GetAdjustedMelody(song_coords14)

# %%
print(len(song_coords1))
print(len(song_coords2))
print(len(song_coords3))
print(len(song_coords4))
print(len(song_coords5))
print(len(song_coords6))
print(len(song_coords7))
print(len(song_coords8))
print(len(song_coords9))
print(len(song_coords10))

np.mean([
    len(song_coords1),
    len(song_coords2),
    len(song_coords3),
    len(song_coords4),
    len(song_coords5),
    len(song_coords6),
    len(song_coords7),
    len(song_coords8),
    len(song_coords9),
    len(song_coords10),
])
# Out:
# 114980
# 212034
# 89140
# 271834
# 239046
# 156777
# 79104
# 107954
# 154627
# 84611
# 151010.7

# %%
lists = [song_coords1, song_coords2, song_coords3, song_coords4, song_coords5, song_coords6, song_coords7, song_coords8, song_coords9, song_coords10, song_coords11, song_coords12, song_coords13, song_coords14]

# lists = [song_coords1, song_coords2, song_coords3, song_coords4, song_coords5, song_coords6, song_coords7, song_coords8, song_coords9, song_coords10,]# song_coords11, song_coords12, song_coords13, song_coords14]

list_lens = [len(i) for i in lists]
min_len = np.min(list_lens)
indices = [np.random.randint(0, i - min_len + 1, 1)[0]  for i in list_lens]
for i in range(len(lists)):
    lists[i] = lists[i][indices[i]:indices[i]+min_len]

list_lens = [len(i) for i in lists]
list_lens
# Out:
# [79104,
#  79104,
#  79104,
#  79104,
#  79104,
#  79104,
#  79104,
#  79104,
#  79104,
#  79104,
#  79104,
#  79104,
#  79104,
#  79104]

# %%
dists = parallelizer.list_parallelizer(distances.GetLZPCausality, lists)

# %%
XYTuples = []
for i in range(len(lists)):
    for j in range(len(lists)):
        XYTuples.append((i, j, lists[i], lists[j]))

distances.GetLZPCausalityParallel(XYTuples)
# Out:
# ....................................................................................................
# [{'index_pair': 0,
#   'index_x': 0,
#   'index_y': 0,
#   'length_x': 114980,
#   'length_y': 114980,
#   'ETC_x': 443,
#   'ETC_y': 443,
#   'ETC_x_given_Gy': 443,
#   'ETC_y_given_Gx': 443,
#   'length_x_residual': 1,
#   'length_y_residual': 1,
#   'ETC_x_residual': 0,
#   'ETC_y_residual': 0,
#   'ETC_x_residual_norm': 0,
#   'ETC_y_residual_norm': 0,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0,
#   'ETCE_y_to_x': 0,
#   'ETCE_strength': 0,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'n_or_m',
#   'ETCE_cause': 'n_or_m',
#   'LZ_x': 107,
#   'LZ_y': 107,
#   'LZ_xy': 108,
#   'LZ_yx': 108,
#   'LZ_concat_mean': 108.0,
#   'LZ_concat_diff': 0,
#   'LZP_x_to_y': 1,
#   'LZP_y_to_x': 1,
#   'LZP_strength': 0,
#   'LZP_threshold': 1,
#   'LZP_direction': 'n_or_m',
#   'LZP_cause': 'n_or_m',
#   'Consensus': True},
#  {'index_pair': 1,
#   'index_x': 0,
#   'index_y': 1,
#   'length_x': 114980,
#   'length_y': 212034,
#   'ETC_x': 443,
#   'ETC_y': 441,
#   'ETC_x_given_Gy': 67,
#   'ETC_y_given_Gx': 4,
#   'length_x_residual': 46189,
#   'length_y_residual': 154921,
#   'ETC_x_residual': 378,
#   'ETC_y_residual': 437,
#   'ETC_x_residual_norm': 0.00818394388152767,
#   'ETC_y_residual_norm': 0.0028208107410276273,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 2,
#   'ETCP_strength': 2,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'x_causes_y',
#   'ETCP_cause': 'x',
#   'ETCE_x_to_y': 0.0028208107410276273,
#   'ETCE_y_to_x': 0.00818394388152767,
#   'ETCE_strength': 0.005363133140500042,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'y_causes_x',
#   'ETCE_cause': 'y',
#   'LZ_x': 107,
#   'LZ_y': 162,
#   'LZ_xy': 259,
#   'LZ_yx': 253,
#   'LZ_concat_mean': 256.0,
#   'LZ_concat_diff': 6,
#   'LZP_x_to_y': 146,
#   'LZP_y_to_x': 97,
#   'LZP_strength': 49,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 2,
#   'index_x': 0,
#   'index_y': 2,
#   'length_x': 114980,
#   'length_y': 89140,
#   'ETC_x': 443,
#   'ETC_y': 788,
#   'ETC_x_given_Gy': 93,
#   'ETC_y_given_Gx': 96,
#   'length_x_residual': 2687,
#   'length_y_residual': 3457,
#   'ETC_x_residual': 350,
#   'ETC_y_residual': 692,
#   'ETC_x_residual_norm': 0.1303052866716307,
#   'ETC_y_residual_norm': 0.20023148148148148,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.20023148148148148,
#   'ETCE_y_to_x': 0.1303052866716307,
#   'ETCE_strength': 0.0699261948098508,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 107,
#   'LZ_y': 231,
#   'LZ_xy': 293,
#   'LZ_yx': 329,
#   'LZ_concat_mean': 311.0,
#   'LZ_concat_diff': 36,
#   'LZP_x_to_y': 222,
#   'LZP_y_to_x': 62,
#   'LZP_strength': 160,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 3,
#   'index_x': 0,
#   'index_y': 3,
#   'length_x': 114980,
#   'length_y': 271834,
#   'ETC_x': 443,
#   'ETC_y': 675,
#   'ETC_x_given_Gy': 134,
#   'ETC_y_given_Gx': 56,
#   'length_x_residual': 1612,
#   'length_y_residual': 16557,
#   'ETC_x_residual': 317,
#   'ETC_y_residual': 619,
#   'ETC_x_residual_norm': 0.196772191185599,
#   'ETC_y_residual_norm': 0.037388258033341386,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 8,
#   'ETCP_strength': 8,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'x_causes_y',
#   'ETCP_cause': 'x',
#   'ETCE_x_to_y': 0.037388258033341386,
#   'ETCE_y_to_x': 0.196772191185599,
#   'ETCE_strength': 0.1593839331522576,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'y_causes_x',
#   'ETCE_cause': 'y',
#   'LZ_x': 107,
#   'LZ_y': 204,
#   'LZ_xy': 288,
#   'LZ_yx': 279,
#   'LZ_concat_mean': 283.5,
#   'LZ_concat_diff': 9,
#   'LZP_x_to_y': 172,
#   'LZP_y_to_x': 84,
#   'LZP_strength': 88,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 4,
#   'index_x': 0,
#   'index_y': 4,
#   'length_x': 114980,
#   'length_y': 239046,
#   'ETC_x': 443,
#   'ETC_y': 565,
#   'ETC_x_given_Gy': 144,
#   'ETC_y_given_Gx': 153,
#   'length_x_residual': 860,
#   'length_y_residual': 1744,
#   'ETC_x_residual': 306,
#   'ETC_y_residual': 418,
#   'ETC_x_residual_norm': 0.3562281722933644,
#   'ETC_y_residual_norm': 0.23981640849110727,
#   'ETCP_x_to_y': 6,
#   'ETCP_y_to_x': 7,
#   'ETCP_strength': 1,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.23981640849110727,
#   'ETCE_y_to_x': 0.3562281722933644,
#   'ETCE_strength': 0.11641176380225712,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'y_causes_x',
#   'ETCE_cause': 'y',
#   'LZ_x': 107,
#   'LZ_y': 170,
#   'LZ_xy': 254,
#   'LZ_yx': 248,
#   'LZ_concat_mean': 251.0,
#   'LZ_concat_diff': 6,
#   'LZP_x_to_y': 141,
#   'LZP_y_to_x': 84,
#   'LZP_strength': 57,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 5,
#   'index_x': 0,
#   'index_y': 5,
#   'length_x': 114980,
#   'length_y': 156777,
#   'ETC_x': 443,
#   'ETC_y': 562,
#   'ETC_x_given_Gy': 114,
#   'ETC_y_given_Gx': 4,
#   'length_x_residual': 26465,
#   'length_y_residual': 107271,
#   'ETC_x_residual': 332,
#   'ETC_y_residual': 558,
#   'ETC_x_residual_norm': 0.0125453446191052,
#   'ETC_y_residual_norm': 0.0052018271650974175,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 3,
#   'ETCP_strength': 3,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'x_causes_y',
#   'ETCP_cause': 'x',
#   'ETCE_x_to_y': 0.0052018271650974175,
#   'ETCE_y_to_x': 0.0125453446191052,
#   'ETCE_strength': 0.007343517454007782,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'y_causes_x',
#   'ETCE_cause': 'y',
#   'LZ_x': 107,
#   'LZ_y': 152,
#   'LZ_xy': 242,
#   'LZ_yx': 245,
#   'LZ_concat_mean': 243.5,
#   'LZ_concat_diff': 3,
#   'LZP_x_to_y': 138,
#   'LZP_y_to_x': 90,
#   'LZP_strength': 48,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 6,
#   'index_x': 0,
#   'index_y': 6,
#   'length_x': 114980,
#   'length_y': 79104,
#   'ETC_x': 443,
#   'ETC_y': 792,
#   'ETC_x_given_Gy': 93,
#   'ETC_y_given_Gx': 96,
#   'length_x_residual': 3502,
#   'length_y_residual': 3780,
#   'ETC_x_residual': 350,
#   'ETC_y_residual': 698,
#   'ETC_x_residual_norm': 0.09997143673236218,
#   'ETC_y_residual_norm': 0.18470494839904736,
#   'ETCP_x_to_y': 2,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 2,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'y_causes_x',
#   'ETCP_cause': 'y',
#   'ETCE_x_to_y': 0.18470494839904736,
#   'ETCE_y_to_x': 0.09997143673236218,
#   'ETCE_strength': 0.08473351166668518,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 107,
#   'LZ_y': 239,
#   'LZ_xy': 308,
#   'LZ_yx': 342,
#   'LZ_concat_mean': 325.0,
#   'LZ_concat_diff': 34,
#   'LZP_x_to_y': 235,
#   'LZP_y_to_x': 69,
#   'LZP_strength': 166,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 7,
#   'index_x': 0,
#   'index_y': 7,
#   'length_x': 114980,
#   'length_y': 107954,
#   'ETC_x': 443,
#   'ETC_y': 877,
#   'ETC_x_given_Gy': 93,
#   'ETC_y_given_Gx': 96,
#   'length_x_residual': 5713,
#   'length_y_residual': 6327,
#   'ETC_x_residual': 350,
#   'ETC_y_residual': 781,
#   'ETC_x_residual_norm': 0.061274509803921566,
#   'ETC_y_residual_norm': 0.12345874170091685,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.12345874170091685,
#   'ETCE_y_to_x': 0.061274509803921566,
#   'ETCE_strength': 0.06218423189699528,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 107,
#   'LZ_y': 234,
#   'LZ_xy': 315,
#   'LZ_yx': 329,
#   'LZ_concat_mean': 322.0,
#   'LZ_concat_diff': 14,
#   'LZP_x_to_y': 222,
#   'LZP_y_to_x': 81,
#   'LZP_strength': 141,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 8,
#   'index_x': 0,
#   'index_y': 8,
#   'length_x': 114980,
#   'length_y': 154627,
#   'ETC_x': 443,
#   'ETC_y': 512,
#   'ETC_x_given_Gy': 70,
#   'ETC_y_given_Gx': 4,
#   'length_x_residual': 38107,
#   'length_y_residual': 107840,
#   'ETC_x_residual': 375,
#   'ETC_y_residual': 508,
#   'ETC_x_residual_norm': 0.009840969925995906,
#   'ETC_y_residual_norm': 0.004710726175131446,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 2,
#   'ETCP_strength': 2,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'x_causes_y',
#   'ETCP_cause': 'x',
#   'ETCE_x_to_y': 0.004710726175131446,
#   'ETCE_y_to_x': 0.009840969925995906,
#   'ETCE_strength': 0.0051302437508644605,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'y_causes_x',
#   'ETCE_cause': 'y',
#   'LZ_x': 107,
#   'LZ_y': 128,
#   'LZ_xy': 223,
#   'LZ_yx': 223,
#   'LZ_concat_mean': 223.0,
#   'LZ_concat_diff': 0,
#   'LZP_x_to_y': 116,
#   'LZP_y_to_x': 95,
#   'LZP_strength': 21,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 9,
#   'index_x': 0,
#   'index_y': 9,
#   'length_x': 114980,
#   'length_y': 84611,
#   'ETC_x': 443,
#   'ETC_y': 571,
#   'ETC_x_given_Gy': 66,
#   'ETC_y_given_Gx': 4,
#   'length_x_residual': 45449,
#   'length_y_residual': 60546,
#   'ETC_x_residual': 377,
#   'ETC_y_residual': 567,
#   'ETC_x_residual_norm': 0.008295194508009153,
#   'ETC_y_residual_norm': 0.009364935172185977,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.009364935172185977,
#   'ETCE_y_to_x': 0.008295194508009153,
#   'ETCE_strength': 0.0010697406641768242,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 107,
#   'LZ_y': 186,
#   'LZ_xy': 276,
#   'LZ_yx': 285,
#   'LZ_concat_mean': 280.5,
#   'LZ_concat_diff': 9,
#   'LZP_x_to_y': 178,
#   'LZP_y_to_x': 90,
#   'LZP_strength': 88,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 10,
#   'index_x': 1,
#   'index_y': 0,
#   'length_x': 212034,
#   'length_y': 114980,
#   'ETC_x': 441,
#   'ETC_y': 443,
#   'ETC_x_given_Gy': 4,
#   'ETC_y_given_Gx': 67,
#   'length_x_residual': 154921,
#   'length_y_residual': 46189,
#   'ETC_x_residual': 437,
#   'ETC_y_residual': 378,
#   'ETC_x_residual_norm': 0.0028208107410276273,
#   'ETC_y_residual_norm': 0.00818394388152767,
#   'ETCP_x_to_y': 2,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 2,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'y_causes_x',
#   'ETCP_cause': 'y',
#   'ETCE_x_to_y': 0.00818394388152767,
#   'ETCE_y_to_x': 0.0028208107410276273,
#   'ETCE_strength': 0.005363133140500042,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 162,
#   'LZ_y': 107,
#   'LZ_xy': 253,
#   'LZ_yx': 259,
#   'LZ_concat_mean': 256.0,
#   'LZ_concat_diff': 6,
#   'LZP_x_to_y': 97,
#   'LZP_y_to_x': 146,
#   'LZP_strength': 49,
#   'LZP_threshold': 1,
#   'LZP_direction': 'x_causes_y',
#   'LZP_cause': 'x',
#   'Consensus': False},
#  {'index_pair': 11,
#   'index_x': 1,
#   'index_y': 1,
#   'length_x': 212034,
#   'length_y': 212034,
#   'ETC_x': 441,
#   'ETC_y': 441,
#   'ETC_x_given_Gy': 441,
#   'ETC_y_given_Gx': 441,
#   'length_x_residual': 1,
#   'length_y_residual': 1,
#   'ETC_x_residual': 0,
#   'ETC_y_residual': 0,
#   'ETC_x_residual_norm': 0,
#   'ETC_y_residual_norm': 0,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0,
#   'ETCE_y_to_x': 0,
#   'ETCE_strength': 0,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'n_or_m',
#   'ETCE_cause': 'n_or_m',
#   'LZ_x': 162,
#   'LZ_y': 162,
#   'LZ_xy': 163,
#   'LZ_yx': 163,
#   'LZ_concat_mean': 163.0,
#   'LZ_concat_diff': 0,
#   'LZP_x_to_y': 1,
#   'LZP_y_to_x': 1,
#   'LZP_strength': 0,
#   'LZP_threshold': 1,
#   'LZP_direction': 'n_or_m',
#   'LZP_cause': 'n_or_m',
#   'Consensus': True},
#  {'index_pair': 12,
#   'index_x': 1,
#   'index_y': 2,
#   'length_x': 212034,
#   'length_y': 89140,
#   'ETC_x': 441,
#   'ETC_y': 788,
#   'ETC_x_given_Gy': 3,
#   'ETC_y_given_Gx': 5,
#   'length_x_residual': 168299,
#   'length_y_residual': 66401,
#   'ETC_x_residual': 438,
#   'ETC_y_residual': 783,
#   'ETC_x_residual_norm': 0.0026025264709028033,
#   'ETC_y_residual_norm': 0.011792168674698796,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.011792168674698796,
#   'ETCE_y_to_x': 0.0026025264709028033,
#   'ETCE_strength': 0.009189642203795992,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 162,
#   'LZ_y': 231,
#   'LZ_xy': 362,
#   'LZ_yx': 391,
#   'LZ_concat_mean': 376.5,
#   'LZ_concat_diff': 29,
#   'LZP_x_to_y': 229,
#   'LZP_y_to_x': 131,
#   'LZP_strength': 98,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 13,
#   'index_x': 1,
#   'index_y': 3,
#   'length_x': 212034,
#   'length_y': 271834,
#   'ETC_x': 441,
#   'ETC_y': 675,
#   'ETC_x_given_Gy': 4,
#   'ETC_y_given_Gx': 25,
#   'length_x_residual': 154921,
#   'length_y_residual': 138427,
#   'ETC_x_residual': 437,
#   'ETC_y_residual': 650,
#   'ETC_x_residual_norm': 0.0028208107410276273,
#   'ETC_y_residual_norm': 0.004695649661190817,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.004695649661190817,
#   'ETCE_y_to_x': 0.0028208107410276273,
#   'ETCE_strength': 0.0018748389201631898,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 162,
#   'LZ_y': 204,
#   'LZ_xy': 351,
#   'LZ_yx': 351,
#   'LZ_concat_mean': 351.0,
#   'LZ_concat_diff': 0,
#   'LZP_x_to_y': 189,
#   'LZP_y_to_x': 147,
#   'LZP_strength': 42,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 14,
#   'index_x': 1,
#   'index_y': 4,
#   'length_x': 212034,
#   'length_y': 239046,
#   'ETC_x': 441,
#   'ETC_y': 565,
#   'ETC_x_given_Gy': 3,
#   'ETC_y_given_Gx': 62,
#   'length_x_residual': 165155,
#   'length_y_residual': 86464,
#   'ETC_x_residual': 438,
#   'ETC_y_residual': 502,
#   'ETC_x_residual_norm': 0.002652070189035688,
#   'ETC_y_residual_norm': 0.005805951678752762,
#   'ETCP_x_to_y': -1,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 1,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.005805951678752762,
#   'ETCE_y_to_x': 0.002652070189035688,
#   'ETCE_strength': 0.0031538814897170736,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 162,
#   'LZ_y': 170,
#   'LZ_xy': 321,
#   'LZ_yx': 322,
#   'LZ_concat_mean': 321.5,
#   'LZ_concat_diff': 1,
#   'LZP_x_to_y': 160,
#   'LZP_y_to_x': 151,
#   'LZP_strength': 9,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 15,
#   'index_x': 1,
#   'index_y': 5,
#   'length_x': 212034,
#   'length_y': 156777,
#   'ETC_x': 441,
#   'ETC_y': 562,
#   'ETC_x_given_Gy': 4,
#   'ETC_y_given_Gx': 56,
#   'length_x_residual': 151833,
#   'length_y_residual': 37882,
#   'ETC_x_residual': 437,
#   'ETC_y_residual': 506,
#   'ETC_x_residual_norm': 0.002878181147584172,
#   'ETC_y_residual_norm': 0.013357619914996965,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.013357619914996965,
#   'ETCE_y_to_x': 0.002878181147584172,
#   'ETCE_strength': 0.010479438767412794,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 162,
#   'LZ_y': 152,
#   'LZ_xy': 284,
#   'LZ_yx': 301,
#   'LZ_concat_mean': 292.5,
#   'LZ_concat_diff': 17,
#   'LZP_x_to_y': 139,
#   'LZP_y_to_x': 132,
#   'LZP_strength': 7,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 16,
#   'index_x': 1,
#   'index_y': 6,
#   'length_x': 212034,
#   'length_y': 79104,
#   'ETC_x': 441,
#   'ETC_y': 792,
#   'ETC_x_given_Gy': 2,
#   'ETC_y_given_Gx': 68,
#   'length_x_residual': 191547,
#   'length_y_residual': 23699,
#   'ETC_x_residual': 439,
#   'ETC_y_residual': 726,
#   'ETC_x_residual_norm': 0.002291877669071659,
#   'ETC_y_residual_norm': 0.030635496666385348,
#   'ETCP_x_to_y': 2,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 2,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'y_causes_x',
#   'ETCP_cause': 'y',
#   'ETCE_x_to_y': 0.030635496666385348,
#   'ETCE_y_to_x': 0.002291877669071659,
#   'ETCE_strength': 0.028343618997313687,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 162,
#   'LZ_y': 239,
#   'LZ_xy': 370,
#   'LZ_yx': 399,
#   'LZ_concat_mean': 384.5,
#   'LZ_concat_diff': 29,
#   'LZP_x_to_y': 237,
#   'LZP_y_to_x': 131,
#   'LZP_strength': 106,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 17,
#   'index_x': 1,
#   'index_y': 7,
#   'length_x': 212034,
#   'length_y': 107954,
#   'ETC_x': 441,
#   'ETC_y': 877,
#   'ETC_x_given_Gy': 5,
#   'ETC_y_given_Gx': 98,
#   'length_x_residual': 148840,
#   'length_y_residual': 25210,
#   'ETC_x_residual': 436,
#   'ETC_y_residual': 779,
#   'ETC_x_residual_norm': 0.002929339756381056,
#   'ETC_y_residual_norm': 0.03090166210480384,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.03090166210480384,
#   'ETCE_y_to_x': 0.002929339756381056,
#   'ETCE_strength': 0.027972322348422785,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 162,
#   'LZ_y': 234,
#   'LZ_xy': 367,
#   'LZ_yx': 392,
#   'LZ_concat_mean': 379.5,
#   'LZ_concat_diff': 25,
#   'LZP_x_to_y': 230,
#   'LZP_y_to_x': 133,
#   'LZP_strength': 97,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 18,
#   'index_x': 1,
#   'index_y': 8,
#   'length_x': 212034,
#   'length_y': 154627,
#   'ETC_x': 441,
#   'ETC_y': 512,
#   'ETC_x_given_Gy': 3,
#   'ETC_y_given_Gx': 84,
#   'length_x_residual': 165155,
#   'length_y_residual': 16487,
#   'ETC_x_residual': 438,
#   'ETC_y_residual': 426,
#   'ETC_x_residual_norm': 0.002652070189035688,
#   'ETC_y_residual_norm': 0.025840106757248574,
#   'ETCP_x_to_y': -2,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 2,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'x_causes_y',
#   'ETCP_cause': 'x',
#   'ETCE_x_to_y': 0.025840106757248574,
#   'ETCE_y_to_x': 0.002652070189035688,
#   'ETCE_strength': 0.023188036568212885,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 162,
#   'LZ_y': 128,
#   'LZ_xy': 268,
#   'LZ_yx': 278,
#   'LZ_concat_mean': 273.0,
#   'LZ_concat_diff': 10,
#   'LZP_x_to_y': 116,
#   'LZP_y_to_x': 140,
#   'LZP_strength': 24,
#   'LZP_threshold': 1,
#   'LZP_direction': 'x_causes_y',
#   'LZP_cause': 'x',
#   'Consensus': True},
#  {'index_pair': 19,
#   'index_x': 1,
#   'index_y': 9,
#   'length_x': 212034,
#   'length_y': 84611,
#   'ETC_x': 441,
#   'ETC_y': 571,
#   'ETC_x_given_Gy': 4,
#   'ETC_y_given_Gx': 68,
#   'length_x_residual': 151833,
#   'length_y_residual': 11733,
#   'ETC_x_residual': 437,
#   'ETC_y_residual': 504,
#   'ETC_x_residual_norm': 0.002878181147584172,
#   'ETC_y_residual_norm': 0.04295942720763723,
#   'ETCP_x_to_y': 1,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 1,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.04295942720763723,
#   'ETCE_y_to_x': 0.002878181147584172,
#   'ETCE_strength': 0.040081246060053054,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 162,
#   'LZ_y': 186,
#   'LZ_xy': 321,
#   'LZ_yx': 346,
#   'LZ_concat_mean': 333.5,
#   'LZ_concat_diff': 25,
#   'LZP_x_to_y': 184,
#   'LZP_y_to_x': 135,
#   'LZP_strength': 49,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 20,
#   'index_x': 2,
#   'index_y': 0,
#   'length_x': 89140,
#   'length_y': 114980,
#   'ETC_x': 788,
#   'ETC_y': 443,
#   'ETC_x_given_Gy': 96,
#   'ETC_y_given_Gx': 93,
#   'length_x_residual': 3457,
#   'length_y_residual': 2687,
#   'ETC_x_residual': 692,
#   'ETC_y_residual': 350,
#   'ETC_x_residual_norm': 0.20023148148148148,
#   'ETC_y_residual_norm': 0.1303052866716307,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.1303052866716307,
#   'ETCE_y_to_x': 0.20023148148148148,
#   'ETCE_strength': 0.0699261948098508,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'y_causes_x',
#   'ETCE_cause': 'y',
#   'LZ_x': 231,
#   'LZ_y': 107,
#   'LZ_xy': 329,
#   'LZ_yx': 293,
#   'LZ_concat_mean': 311.0,
#   'LZ_concat_diff': 36,
#   'LZP_x_to_y': 62,
#   'LZP_y_to_x': 222,
#   'LZP_strength': 160,
#   'LZP_threshold': 1,
#   'LZP_direction': 'x_causes_y',
#   'LZP_cause': 'x',
#   'Consensus': False},
#  {'index_pair': 21,
#   'index_x': 2,
#   'index_y': 1,
#   'length_x': 89140,
#   'length_y': 212034,
#   'ETC_x': 788,
#   'ETC_y': 441,
#   'ETC_x_given_Gy': 5,
#   'ETC_y_given_Gx': 3,
#   'length_x_residual': 66401,
#   'length_y_residual': 168299,
#   'ETC_x_residual': 783,
#   'ETC_y_residual': 438,
#   'ETC_x_residual_norm': 0.011792168674698796,
#   'ETC_y_residual_norm': 0.0026025264709028033,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.0026025264709028033,
#   'ETCE_y_to_x': 0.011792168674698796,
#   'ETCE_strength': 0.009189642203795992,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'y_causes_x',
#   'ETCE_cause': 'y',
#   'LZ_x': 231,
#   'LZ_y': 162,
#   'LZ_xy': 391,
#   'LZ_yx': 362,
#   'LZ_concat_mean': 376.5,
#   'LZ_concat_diff': 29,
#   'LZP_x_to_y': 131,
#   'LZP_y_to_x': 229,
#   'LZP_strength': 98,
#   'LZP_threshold': 1,
#   'LZP_direction': 'x_causes_y',
#   'LZP_cause': 'x',
#   'Consensus': False},
#  {'index_pair': 22,
#   'index_x': 2,
#   'index_y': 2,
#   'length_x': 89140,
#   'length_y': 89140,
#   'ETC_x': 788,
#   'ETC_y': 788,
#   'ETC_x_given_Gy': 788,
#   'ETC_y_given_Gx': 788,
#   'length_x_residual': 1,
#   'length_y_residual': 1,
#   'ETC_x_residual': 0,
#   'ETC_y_residual': 0,
#   'ETC_x_residual_norm': 0,
#   'ETC_y_residual_norm': 0,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0,
#   'ETCE_y_to_x': 0,
#   'ETCE_strength': 0,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'n_or_m',
#   'ETCE_cause': 'n_or_m',
#   'LZ_x': 231,
#   'LZ_y': 231,
#   'LZ_xy': 232,
#   'LZ_yx': 232,
#   'LZ_concat_mean': 232.0,
#   'LZ_concat_diff': 0,
#   'LZP_x_to_y': 1,
#   'LZP_y_to_x': 1,
#   'LZP_strength': 0,
#   'LZP_threshold': 1,
#   'LZP_direction': 'n_or_m',
#   'LZP_cause': 'n_or_m',
#   'Consensus': True},
#  {'index_pair': 23,
#   'index_x': 2,
#   'index_y': 3,
#   'length_x': 89140,
#   'length_y': 271834,
#   'ETC_x': 788,
#   'ETC_y': 675,
#   'ETC_x_given_Gy': 93,
#   'ETC_y_given_Gx': 16,
#   'length_x_residual': 9306,
#   'length_y_residual': 118729,
#   'ETC_x_residual': 696,
#   'ETC_y_residual': 659,
#   'ETC_x_residual_norm': 0.07479849543256314,
#   'ETC_y_residual_norm': 0.005550501987736676,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 1,
#   'ETCP_strength': 1,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.005550501987736676,
#   'ETCE_y_to_x': 0.07479849543256314,
#   'ETCE_strength': 0.06924799344482648,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'y_causes_x',
#   'ETCE_cause': 'y',
#   'LZ_x': 231,
#   'LZ_y': 204,
#   'LZ_xy': 428,
#   'LZ_yx': 387,
#   'LZ_concat_mean': 407.5,
#   'LZ_concat_diff': 41,
#   'LZP_x_to_y': 156,
#   'LZP_y_to_x': 224,
#   'LZP_strength': 68,
#   'LZP_threshold': 1,
#   'LZP_direction': 'x_causes_y',
#   'LZP_cause': 'x',
#   'Consensus': False},
#  {'index_pair': 24,
#   'index_x': 2,
#   'index_y': 4,
#   'length_x': 89140,
#   'length_y': 239046,
#   'ETC_x': 788,
#   'ETC_y': 565,
#   'ETC_x_given_Gy': 94,
#   'ETC_y_given_Gx': 93,
#   'length_x_residual': 3659,
#   'length_y_residual': 5746,
#   'ETC_x_residual': 695,
#   'ETC_y_residual': 472,
#   'ETC_x_residual_norm': 0.18999453253143794,
#   'ETC_y_residual_norm': 0.08215839860748476,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 1,
#   'ETCP_strength': 1,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.08215839860748476,
#   'ETCE_y_to_x': 0.18999453253143794,
#   'ETCE_strength': 0.10783613392395318,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'y_causes_x',
#   'ETCE_cause': 'y',
#   'LZ_x': 231,
#   'LZ_y': 170,
#   'LZ_xy': 387,
#   'LZ_yx': 352,
#   'LZ_concat_mean': 369.5,
#   'LZ_concat_diff': 35,
#   'LZP_x_to_y': 121,
#   'LZP_y_to_x': 217,
#   'LZP_strength': 96,
#   'LZP_threshold': 1,
#   'LZP_direction': 'x_causes_y',
#   'LZP_cause': 'x',
#   'Consensus': False},
#  {'index_pair': 25,
#   'index_x': 2,
#   'index_y': 5,
#   'length_x': 89140,
#   'length_y': 156777,
#   'ETC_x': 788,
#   'ETC_y': 562,
#   'ETC_x_given_Gy': 65,
#   'ETC_y_given_Gx': 3,
#   'length_x_residual': 25004,
#   'length_y_residual': 120394,
#   'ETC_x_residual': 724,
#   'ETC_y_residual': 559,
#   'ETC_x_residual_norm': 0.028956525216973963,
#   'ETC_y_residual_norm': 0.004643127092106684,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 1,
#   'ETCP_strength': 1,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.004643127092106684,
#   'ETCE_y_to_x': 0.028956525216973963,
#   'ETCE_strength': 0.02431339812486728,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'y_causes_x',
#   'ETCE_cause': 'y',
#   'LZ_x': 231,
#   'LZ_y': 152,
#   'LZ_xy': 375,
#   'LZ_yx': 353,
#   'LZ_concat_mean': 364.0,
#   'LZ_concat_diff': 22,
#   'LZP_x_to_y': 122,
#   'LZP_y_to_x': 223,
#   'LZP_strength': 101,
#   'LZP_threshold': 1,
#   'LZP_direction': 'x_causes_y',
#   'LZP_cause': 'x',
#   'Consensus': False},
#  {'index_pair': 26,
#   'index_x': 2,
#   'index_y': 6,
#   'length_x': 89140,
#   'length_y': 79104,
#   'ETC_x': 788,
#   'ETC_y': 792,
#   'ETC_x_given_Gy': 90,
#   'ETC_y_given_Gx': 93,
#   'length_x_residual': 6077,
#   'length_y_residual': 3626,
#   'ETC_x_residual': 699,
#   'ETC_y_residual': 699,
#   'ETC_x_residual_norm': 0.11504279131007242,
#   'ETC_y_residual_norm': 0.19282758620689655,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 1,
#   'ETCP_strength': 1,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.19282758620689655,
#   'ETCE_y_to_x': 0.11504279131007242,
#   'ETCE_strength': 0.07778479489682413,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 231,
#   'LZ_y': 239,
#   'LZ_xy': 423,
#   'LZ_yx': 438,
#   'LZ_concat_mean': 430.5,
#   'LZ_concat_diff': 15,
#   'LZP_x_to_y': 207,
#   'LZP_y_to_x': 184,
#   'LZP_strength': 23,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 27,
#   'index_x': 2,
#   'index_y': 7,
#   'length_x': 89140,
#   'length_y': 107954,
#   'ETC_x': 788,
#   'ETC_y': 877,
#   'ETC_x_given_Gy': 82,
#   'ETC_y_given_Gx': 93,
#   'length_x_residual': 7086,
#   'length_y_residual': 5456,
#   'ETC_x_residual': 707,
#   'ETC_y_residual': 784,
#   'ETC_x_residual_norm': 0.09978828510938603,
#   'ETC_y_residual_norm': 0.14372135655362053,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 1,
#   'ETCP_strength': 1,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.14372135655362053,
#   'ETCE_y_to_x': 0.09978828510938603,
#   'ETCE_strength': 0.0439330714442345,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 231,
#   'LZ_y': 234,
#   'LZ_xy': 428,
#   'LZ_yx': 425,
#   'LZ_concat_mean': 426.5,
#   'LZ_concat_diff': 3,
#   'LZP_x_to_y': 194,
#   'LZP_y_to_x': 194,
#   'LZP_strength': 0,
#   'LZP_threshold': 1,
#   'LZP_direction': 'n_or_m',
#   'LZP_cause': 'n_or_m',
#   'Consensus': False},
#  {'index_pair': 28,
#   'index_x': 2,
#   'index_y': 8,
#   'length_x': 89140,
#   'length_y': 154627,
#   'ETC_x': 788,
#   'ETC_y': 512,
#   'ETC_x_given_Gy': 3,
#   'ETC_y_given_Gx': 3,
#   'length_x_residual': 75575,
#   'length_y_residual': 119330,
#   'ETC_x_residual': 785,
#   'ETC_y_residual': 509,
#   'ETC_x_residual_norm': 0.010387170190806361,
#   'ETC_y_residual_norm': 0.004265518021604136,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.004265518021604136,
#   'ETCE_y_to_x': 0.010387170190806361,
#   'ETCE_strength': 0.006121652169202225,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'y_causes_x',
#   'ETCE_cause': 'y',
#   'LZ_x': 231,
#   'LZ_y': 128,
#   'LZ_xy': 354,
#   'LZ_yx': 328,
#   'LZ_concat_mean': 341.0,
#   'LZ_concat_diff': 26,
#   'LZP_x_to_y': 97,
#   'LZP_y_to_x': 226,
#   'LZP_strength': 129,
#   'LZP_threshold': 1,
#   'LZP_direction': 'x_causes_y',
#   'LZP_cause': 'x',
#   'Consensus': False},
#  {'index_pair': 29,
#   'index_x': 2,
#   'index_y': 9,
#   'length_x': 89140,
#   'length_y': 84611,
#   'ETC_x': 788,
#   'ETC_y': 571,
#   'ETC_x_given_Gy': 61,
#   'ETC_y_given_Gx': 3,
#   'length_x_residual': 32449,
#   'length_y_residual': 66948,
#   'ETC_x_residual': 728,
#   'ETC_y_residual': 568,
#   'ETC_x_residual_norm': 0.022435897435897436,
#   'ETC_y_residual_norm': 0.00848432342001882,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 1,
#   'ETCP_strength': 1,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.00848432342001882,
#   'ETCE_y_to_x': 0.022435897435897436,
#   'ETCE_strength': 0.013951574015878616,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'y_causes_x',
#   'ETCE_cause': 'y',
#   'LZ_x': 231,
#   'LZ_y': 186,
#   'LZ_xy': 393,
#   'LZ_yx': 388,
#   'LZ_concat_mean': 390.5,
#   'LZ_concat_diff': 5,
#   'LZP_x_to_y': 157,
#   'LZP_y_to_x': 207,
#   'LZP_strength': 50,
#   'LZP_threshold': 1,
#   'LZP_direction': 'x_causes_y',
#   'LZP_cause': 'x',
#   'Consensus': False},
#  {'index_pair': 30,
#   'index_x': 3,
#   'index_y': 0,
#   'length_x': 271834,
#   'length_y': 114980,
#   'ETC_x': 675,
#   'ETC_y': 443,
#   'ETC_x_given_Gy': 56,
#   'ETC_y_given_Gx': 134,
#   'length_x_residual': 16557,
#   'length_y_residual': 1612,
#   'ETC_x_residual': 619,
#   'ETC_y_residual': 317,
#   'ETC_x_residual_norm': 0.037388258033341386,
#   'ETC_y_residual_norm': 0.196772191185599,
#   'ETCP_x_to_y': 8,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 8,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'y_causes_x',
#   'ETCP_cause': 'y',
#   'ETCE_x_to_y': 0.196772191185599,
#   'ETCE_y_to_x': 0.037388258033341386,
#   'ETCE_strength': 0.1593839331522576,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 204,
#   'LZ_y': 107,
#   'LZ_xy': 279,
#   'LZ_yx': 288,
#   'LZ_concat_mean': 283.5,
#   'LZ_concat_diff': 9,
#   'LZP_x_to_y': 84,
#   'LZP_y_to_x': 172,
#   'LZP_strength': 88,
#   'LZP_threshold': 1,
#   'LZP_direction': 'x_causes_y',
#   'LZP_cause': 'x',
#   'Consensus': False},
#  {'index_pair': 31,
#   'index_x': 3,
#   'index_y': 1,
#   'length_x': 271834,
#   'length_y': 212034,
#   'ETC_x': 675,
#   'ETC_y': 441,
#   'ETC_x_given_Gy': 25,
#   'ETC_y_given_Gx': 4,
#   'length_x_residual': 138427,
#   'length_y_residual': 154921,
#   'ETC_x_residual': 650,
#   'ETC_y_residual': 437,
#   'ETC_x_residual_norm': 0.004695649661190817,
#   'ETC_y_residual_norm': 0.0028208107410276273,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.0028208107410276273,
#   'ETCE_y_to_x': 0.004695649661190817,
#   'ETCE_strength': 0.0018748389201631898,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'y_causes_x',
#   'ETCE_cause': 'y',
#   'LZ_x': 204,
#   'LZ_y': 162,
#   'LZ_xy': 351,
#   'LZ_yx': 351,
#   'LZ_concat_mean': 351.0,
#   'LZ_concat_diff': 0,
#   'LZP_x_to_y': 147,
#   'LZP_y_to_x': 189,
#   'LZP_strength': 42,
#   'LZP_threshold': 1,
#   'LZP_direction': 'x_causes_y',
#   'LZP_cause': 'x',
#   'Consensus': False},
#  {'index_pair': 32,
#   'index_x': 3,
#   'index_y': 2,
#   'length_x': 271834,
#   'length_y': 89140,
#   'ETC_x': 675,
#   'ETC_y': 788,
#   'ETC_x_given_Gy': 16,
#   'ETC_y_given_Gx': 93,
#   'length_x_residual': 118729,
#   'length_y_residual': 9306,
#   'ETC_x_residual': 659,
#   'ETC_y_residual': 696,
#   'ETC_x_residual_norm': 0.005550501987736676,
#   'ETC_y_residual_norm': 0.07479849543256314,
#   'ETCP_x_to_y': 1,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 1,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.07479849543256314,
#   'ETCE_y_to_x': 0.005550501987736676,
#   'ETCE_strength': 0.06924799344482648,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 204,
#   'LZ_y': 231,
#   'LZ_xy': 387,
#   'LZ_yx': 428,
#   'LZ_concat_mean': 407.5,
#   'LZ_concat_diff': 41,
#   'LZP_x_to_y': 224,
#   'LZP_y_to_x': 156,
#   'LZP_strength': 68,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 33,
#   'index_x': 3,
#   'index_y': 3,
#   'length_x': 271834,
#   'length_y': 271834,
#   'ETC_x': 675,
#   'ETC_y': 675,
#   'ETC_x_given_Gy': 675,
#   'ETC_y_given_Gx': 675,
#   'length_x_residual': 1,
#   'length_y_residual': 1,
#   'ETC_x_residual': 0,
#   'ETC_y_residual': 0,
#   'ETC_x_residual_norm': 0,
#   'ETC_y_residual_norm': 0,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0,
#   'ETCE_y_to_x': 0,
#   'ETCE_strength': 0,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'n_or_m',
#   'ETCE_cause': 'n_or_m',
#   'LZ_x': 204,
#   'LZ_y': 204,
#   'LZ_xy': 205,
#   'LZ_yx': 205,
#   'LZ_concat_mean': 205.0,
#   'LZ_concat_diff': 0,
#   'LZP_x_to_y': 1,
#   'LZP_y_to_x': 1,
#   'LZP_strength': 0,
#   'LZP_threshold': 1,
#   'LZP_direction': 'n_or_m',
#   'LZP_cause': 'n_or_m',
#   'Consensus': True},
#  {'index_pair': 34,
#   'index_x': 3,
#   'index_y': 4,
#   'length_x': 271834,
#   'length_y': 239046,
#   'ETC_x': 675,
#   'ETC_y': 565,
#   'ETC_x_given_Gy': 51,
#   'ETC_y_given_Gx': 135,
#   'length_x_residual': 18521,
#   'length_y_residual': 4108,
#   'ETC_x_residual': 624,
#   'ETC_y_residual': 431,
#   'ETC_x_residual_norm': 0.033693304535637146,
#   'ETC_y_residual_norm': 0.1049427806184563,
#   'ETCP_x_to_y': 1,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 1,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.1049427806184563,
#   'ETCE_y_to_x': 0.033693304535637146,
#   'ETCE_strength': 0.07124947608281915,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 204,
#   'LZ_y': 170,
#   'LZ_xy': 342,
#   'LZ_yx': 333,
#   'LZ_concat_mean': 337.5,
#   'LZ_concat_diff': 9,
#   'LZP_x_to_y': 129,
#   'LZP_y_to_x': 172,
#   'LZP_strength': 43,
#   'LZP_threshold': 1,
#   'LZP_direction': 'x_causes_y',
#   'LZP_cause': 'x',
#   'Consensus': False},
#  {'index_pair': 35,
#   'index_x': 3,
#   'index_y': 5,
#   'length_x': 271834,
#   'length_y': 156777,
#   'ETC_x': 675,
#   'ETC_y': 562,
#   'ETC_x_given_Gy': 15,
#   'ETC_y_given_Gx': 4,
#   'length_x_residual': 129793,
#   'length_y_residual': 107271,
#   'ETC_x_residual': 660,
#   'ETC_y_residual': 558,
#   'ETC_x_residual_norm': 0.005085059171597633,
#   'ETC_y_residual_norm': 0.0052018271650974175,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.0052018271650974175,
#   'ETCE_y_to_x': 0.005085059171597633,
#   'ETCE_strength': 0.00011676799349978444,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 204,
#   'LZ_y': 152,
#   'LZ_xy': 331,
#   'LZ_yx': 340,
#   'LZ_concat_mean': 335.5,
#   'LZ_concat_diff': 9,
#   'LZP_x_to_y': 136,
#   'LZP_y_to_x': 179,
#   'LZP_strength': 43,
#   'LZP_threshold': 1,
#   'LZP_direction': 'x_causes_y',
#   'LZP_cause': 'x',
#   'Consensus': False},
#  {'index_pair': 36,
#   'index_x': 3,
#   'index_y': 6,
#   'length_x': 271834,
#   'length_y': 79104,
#   'ETC_x': 675,
#   'ETC_y': 792,
#   'ETC_x_given_Gy': 46,
#   'ETC_y_given_Gx': 93,
#   'length_x_residual': 44130,
#   'length_y_residual': 3700,
#   'ETC_x_residual': 629,
#   'ETC_y_residual': 699,
#   'ETC_x_residual_norm': 0.01425366539010628,
#   'ETC_y_residual_norm': 0.18896999188969993,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.18896999188969993,
#   'ETCE_y_to_x': 0.01425366539010628,
#   'ETCE_strength': 0.17471632649959365,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 204,
#   'LZ_y': 239,
#   'LZ_xy': 393,
#   'LZ_yx': 440,
#   'LZ_concat_mean': 416.5,
#   'LZ_concat_diff': 47,
#   'LZP_x_to_y': 236,
#   'LZP_y_to_x': 154,
#   'LZP_strength': 82,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 37,
#   'index_x': 3,
#   'index_y': 7,
#   'length_x': 271834,
#   'length_y': 107954,
#   'ETC_x': 675,
#   'ETC_y': 877,
#   'ETC_x_given_Gy': 21,
#   'ETC_y_given_Gx': 93,
#   'length_x_residual': 96937,
#   'length_y_residual': 10621,
#   'ETC_x_residual': 654,
#   'ETC_y_residual': 784,
#   'ETC_x_residual_norm': 0.006746719485021045,
#   'ETC_y_residual_norm': 0.07382297551789077,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.07382297551789077,
#   'ETCE_y_to_x': 0.006746719485021045,
#   'ETCE_strength': 0.06707625603286972,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 204,
#   'LZ_y': 234,
#   'LZ_xy': 398,
#   'LZ_yx': 428,
#   'LZ_concat_mean': 413.0,
#   'LZ_concat_diff': 30,
#   'LZP_x_to_y': 224,
#   'LZP_y_to_x': 164,
#   'LZP_strength': 60,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 38,
#   'index_x': 3,
#   'index_y': 8,
#   'length_x': 271834,
#   'length_y': 154627,
#   'ETC_x': 675,
#   'ETC_y': 512,
#   'ETC_x_given_Gy': 11,
#   'ETC_y_given_Gx': 4,
#   'length_x_residual': 152057,
#   'length_y_residual': 107840,
#   'ETC_x_residual': 664,
#   'ETC_y_residual': 508,
#   'ETC_x_residual_norm': 0.004366812227074236,
#   'ETC_y_residual_norm': 0.004710726175131446,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.004710726175131446,
#   'ETCE_y_to_x': 0.004366812227074236,
#   'ETCE_strength': 0.00034391394805721037,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 204,
#   'LZ_y': 128,
#   'LZ_xy': 314,
#   'LZ_yx': 318,
#   'LZ_concat_mean': 316.0,
#   'LZ_concat_diff': 4,
#   'LZP_x_to_y': 114,
#   'LZP_y_to_x': 186,
#   'LZP_strength': 72,
#   'LZP_threshold': 1,
#   'LZP_direction': 'x_causes_y',
#   'LZP_cause': 'x',
#   'Consensus': False},
#  {'index_pair': 39,
#   'index_x': 3,
#   'index_y': 9,
#   'length_x': 271834,
#   'length_y': 84611,
#   'ETC_x': 675,
#   'ETC_y': 571,
#   'ETC_x_given_Gy': 5,
#   'ETC_y_given_Gx': 4,
#   'length_x_residual': 199312,
#   'length_y_residual': 60546,
#   'ETC_x_residual': 670,
#   'ETC_y_residual': 567,
#   'ETC_x_residual_norm': 0.003361580645323138,
#   'ETC_y_residual_norm': 0.009364935172185977,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.009364935172185977,
#   'ETCE_y_to_x': 0.003361580645323138,
#   'ETCE_strength': 0.006003354526862839,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 204,
#   'LZ_y': 186,
#   'LZ_xy': 367,
#   'LZ_yx': 386,
#   'LZ_concat_mean': 376.5,
#   'LZ_concat_diff': 19,
#   'LZP_x_to_y': 182,
#   'LZP_y_to_x': 181,
#   'LZP_strength': 1,
#   'LZP_threshold': 1,
#   'LZP_direction': 'n_or_m',
#   'LZP_cause': 'n_or_m',
#   'Consensus': False},
#  {'index_pair': 40,
#   'index_x': 4,
#   'index_y': 0,
#   'length_x': 239046,
#   'length_y': 114980,
#   'ETC_x': 565,
#   'ETC_y': 443,
#   'ETC_x_given_Gy': 153,
#   'ETC_y_given_Gx': 144,
#   'length_x_residual': 1744,
#   'length_y_residual': 860,
#   'ETC_x_residual': 418,
#   'ETC_y_residual': 306,
#   'ETC_x_residual_norm': 0.23981640849110727,
#   'ETC_y_residual_norm': 0.3562281722933644,
#   'ETCP_x_to_y': 7,
#   'ETCP_y_to_x': 6,
#   'ETCP_strength': 1,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.3562281722933644,
#   'ETCE_y_to_x': 0.23981640849110727,
#   'ETCE_strength': 0.11641176380225712,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 170,
#   'LZ_y': 107,
#   'LZ_xy': 248,
#   'LZ_yx': 254,
#   'LZ_concat_mean': 251.0,
#   'LZ_concat_diff': 6,
#   'LZP_x_to_y': 84,
#   'LZP_y_to_x': 141,
#   'LZP_strength': 57,
#   'LZP_threshold': 1,
#   'LZP_direction': 'x_causes_y',
#   'LZP_cause': 'x',
#   'Consensus': False},
#  {'index_pair': 41,
#   'index_x': 4,
#   'index_y': 1,
#   'length_x': 239046,
#   'length_y': 212034,
#   'ETC_x': 565,
#   'ETC_y': 441,
#   'ETC_x_given_Gy': 62,
#   'ETC_y_given_Gx': 3,
#   'length_x_residual': 86464,
#   'length_y_residual': 165155,
#   'ETC_x_residual': 502,
#   'ETC_y_residual': 438,
#   'ETC_x_residual_norm': 0.005805951678752762,
#   'ETC_y_residual_norm': 0.002652070189035688,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': -1,
#   'ETCP_strength': 1,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.002652070189035688,
#   'ETCE_y_to_x': 0.005805951678752762,
#   'ETCE_strength': 0.0031538814897170736,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'y_causes_x',
#   'ETCE_cause': 'y',
#   'LZ_x': 170,
#   'LZ_y': 162,
#   'LZ_xy': 322,
#   'LZ_yx': 321,
#   'LZ_concat_mean': 321.5,
#   'LZ_concat_diff': 1,
#   'LZP_x_to_y': 151,
#   'LZP_y_to_x': 160,
#   'LZP_strength': 9,
#   'LZP_threshold': 1,
#   'LZP_direction': 'x_causes_y',
#   'LZP_cause': 'x',
#   'Consensus': False},
#  {'index_pair': 42,
#   'index_x': 4,
#   'index_y': 2,
#   'length_x': 239046,
#   'length_y': 89140,
#   'ETC_x': 565,
#   'ETC_y': 788,
#   'ETC_x_given_Gy': 93,
#   'ETC_y_given_Gx': 94,
#   'length_x_residual': 5746,
#   'length_y_residual': 3659,
#   'ETC_x_residual': 472,
#   'ETC_y_residual': 695,
#   'ETC_x_residual_norm': 0.08215839860748476,
#   'ETC_y_residual_norm': 0.18999453253143794,
#   'ETCP_x_to_y': 1,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 1,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.18999453253143794,
#   'ETCE_y_to_x': 0.08215839860748476,
#   'ETCE_strength': 0.10783613392395318,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 170,
#   'LZ_y': 231,
#   'LZ_xy': 352,
#   'LZ_yx': 387,
#   'LZ_concat_mean': 369.5,
#   'LZ_concat_diff': 35,
#   'LZP_x_to_y': 217,
#   'LZP_y_to_x': 121,
#   'LZP_strength': 96,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 43,
#   'index_x': 4,
#   'index_y': 3,
#   'length_x': 239046,
#   'length_y': 271834,
#   'ETC_x': 565,
#   'ETC_y': 675,
#   'ETC_x_given_Gy': 135,
#   'ETC_y_given_Gx': 51,
#   'length_x_residual': 4108,
#   'length_y_residual': 18521,
#   'ETC_x_residual': 431,
#   'ETC_y_residual': 624,
#   'ETC_x_residual_norm': 0.1049427806184563,
#   'ETC_y_residual_norm': 0.033693304535637146,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 1,
#   'ETCP_strength': 1,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.033693304535637146,
#   'ETCE_y_to_x': 0.1049427806184563,
#   'ETCE_strength': 0.07124947608281915,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'y_causes_x',
#   'ETCE_cause': 'y',
#   'LZ_x': 170,
#   'LZ_y': 204,
#   'LZ_xy': 333,
#   'LZ_yx': 342,
#   'LZ_concat_mean': 337.5,
#   'LZ_concat_diff': 9,
#   'LZP_x_to_y': 172,
#   'LZP_y_to_x': 129,
#   'LZP_strength': 43,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 44,
#   'index_x': 4,
#   'index_y': 4,
#   'length_x': 239046,
#   'length_y': 239046,
#   'ETC_x': 565,
#   'ETC_y': 565,
#   'ETC_x_given_Gy': 565,
#   'ETC_y_given_Gx': 565,
#   'length_x_residual': 1,
#   'length_y_residual': 1,
#   'ETC_x_residual': 0,
#   'ETC_y_residual': 0,
#   'ETC_x_residual_norm': 0,
#   'ETC_y_residual_norm': 0,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0,
#   'ETCE_y_to_x': 0,
#   'ETCE_strength': 0,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'n_or_m',
#   'ETCE_cause': 'n_or_m',
#   'LZ_x': 170,
#   'LZ_y': 170,
#   'LZ_xy': 171,
#   'LZ_yx': 171,
#   'LZ_concat_mean': 171.0,
#   'LZ_concat_diff': 0,
#   'LZP_x_to_y': 1,
#   'LZP_y_to_x': 1,
#   'LZP_strength': 0,
#   'LZP_threshold': 1,
#   'LZP_direction': 'n_or_m',
#   'LZP_cause': 'n_or_m',
#   'Consensus': True},
#  {'index_pair': 45,
#   'index_x': 4,
#   'index_y': 5,
#   'length_x': 239046,
#   'length_y': 156777,
#   'ETC_x': 565,
#   'ETC_y': 562,
#   'ETC_x_given_Gy': 114,
#   'ETC_y_given_Gx': 3,
#   'length_x_residual': 50698,
#   'length_y_residual': 113670,
#   'ETC_x_residual': 449,
#   'ETC_y_residual': 559,
#   'ETC_x_residual_norm': 0.008856539834704222,
#   'ETC_y_residual_norm': 0.004917787611398007,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': -2,
#   'ETCP_strength': 2,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'y_causes_x',
#   'ETCP_cause': 'y',
#   'ETCE_x_to_y': 0.004917787611398007,
#   'ETCE_y_to_x': 0.008856539834704222,
#   'ETCE_strength': 0.003938752223306216,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'y_causes_x',
#   'ETCE_cause': 'y',
#   'LZ_x': 170,
#   'LZ_y': 152,
#   'LZ_xy': 300,
#   'LZ_yx': 306,
#   'LZ_concat_mean': 303.0,
#   'LZ_concat_diff': 6,
#   'LZP_x_to_y': 136,
#   'LZP_y_to_x': 148,
#   'LZP_strength': 12,
#   'LZP_threshold': 1,
#   'LZP_direction': 'x_causes_y',
#   'LZP_cause': 'x',
#   'Consensus': False},
#  {'index_pair': 46,
#   'index_x': 4,
#   'index_y': 6,
#   'length_x': 239046,
#   'length_y': 79104,
#   'ETC_x': 565,
#   'ETC_y': 792,
#   'ETC_x_given_Gy': 95,
#   'ETC_y_given_Gx': 97,
#   'length_x_residual': 8289,
#   'length_y_residual': 3492,
#   'ETC_x_residual': 471,
#   'ETC_y_residual': 697,
#   'ETC_x_residual_norm': 0.05682915057915058,
#   'ETC_y_residual_norm': 0.1996562589515898,
#   'ETCP_x_to_y': 2,
#   'ETCP_y_to_x': 1,
#   'ETCP_strength': 1,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.1996562589515898,
#   'ETCE_y_to_x': 0.05682915057915058,
#   'ETCE_strength': 0.14282710837243923,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 170,
#   'LZ_y': 239,
#   'LZ_xy': 364,
#   'LZ_yx': 405,
#   'LZ_concat_mean': 384.5,
#   'LZ_concat_diff': 41,
#   'LZP_x_to_y': 235,
#   'LZP_y_to_x': 125,
#   'LZP_strength': 110,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 47,
#   'index_x': 4,
#   'index_y': 7,
#   'length_x': 239046,
#   'length_y': 107954,
#   'ETC_x': 565,
#   'ETC_y': 877,
#   'ETC_x_given_Gy': 103,
#   'ETC_y_given_Gx': 97,
#   'length_x_residual': 8891,
#   'length_y_residual': 5939,
#   'ETC_x_residual': 462,
#   'ETC_y_residual': 780,
#   'ETC_x_residual_norm': 0.05196850393700787,
#   'ETC_y_residual_norm': 0.13135735938026272,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.13135735938026272,
#   'ETCE_y_to_x': 0.05196850393700787,
#   'ETCE_strength': 0.07938885544325484,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 170,
#   'LZ_y': 234,
#   'LZ_xy': 367,
#   'LZ_yx': 397,
#   'LZ_concat_mean': 382.0,
#   'LZ_concat_diff': 30,
#   'LZP_x_to_y': 227,
#   'LZP_y_to_x': 133,
#   'LZP_strength': 94,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 48,
#   'index_x': 4,
#   'index_y': 8,
#   'length_x': 239046,
#   'length_y': 154627,
#   'ETC_x': 565,
#   'ETC_y': 512,
#   'ETC_x_given_Gy': 77,
#   'ETC_y_given_Gx': 3,
#   'length_x_residual': 75985,
#   'length_y_residual': 114154,
#   'ETC_x_residual': 488,
#   'ETC_y_residual': 509,
#   'ETC_x_residual_norm': 0.00642240471678248,
#   'ETC_y_residual_norm': 0.0044589279300587805,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.0044589279300587805,
#   'ETCE_y_to_x': 0.00642240471678248,
#   'ETCE_strength': 0.0019634767867236997,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'y_causes_x',
#   'ETCE_cause': 'y',
#   'LZ_x': 170,
#   'LZ_y': 128,
#   'LZ_xy': 284,
#   'LZ_yx': 286,
#   'LZ_concat_mean': 285.0,
#   'LZ_concat_diff': 2,
#   'LZP_x_to_y': 116,
#   'LZP_y_to_x': 156,
#   'LZP_strength': 40,
#   'LZP_threshold': 1,
#   'LZP_direction': 'x_causes_y',
#   'LZP_cause': 'x',
# ...
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'y_causes_x',
#   'ETCE_cause': 'y',
#   'LZ_x': 128,
#   'LZ_y': 204,
#   'LZ_xy': 318,
#   'LZ_yx': 314,
#   'LZ_concat_mean': 316.0,
#   'LZ_concat_diff': 4,
#   'LZP_x_to_y': 186,
#   'LZP_y_to_x': 114,
#   'LZP_strength': 72,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 84,
#   'index_x': 8,
#   'index_y': 4,
#   'length_x': 154627,
#   'length_y': 239046,
#   'ETC_x': 512,
#   'ETC_y': 565,
#   'ETC_x_given_Gy': 3,
#   'ETC_y_given_Gx': 77,
#   'length_x_residual': 114154,
#   'length_y_residual': 75985,
#   'ETC_x_residual': 509,
#   'ETC_y_residual': 488,
#   'ETC_x_residual_norm': 0.0044589279300587805,
#   'ETC_y_residual_norm': 0.00642240471678248,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.00642240471678248,
#   'ETCE_y_to_x': 0.0044589279300587805,
#   'ETCE_strength': 0.0019634767867236997,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 128,
#   'LZ_y': 170,
#   'LZ_xy': 286,
#   'LZ_yx': 284,
#   'LZ_concat_mean': 285.0,
#   'LZ_concat_diff': 2,
#   'LZP_x_to_y': 156,
#   'LZP_y_to_x': 116,
#   'LZP_strength': 40,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 85,
#   'index_x': 8,
#   'index_y': 5,
#   'length_x': 154627,
#   'length_y': 156777,
#   'ETC_x': 512,
#   'ETC_y': 562,
#   'ETC_x_given_Gy': 4,
#   'ETC_y_given_Gx': 70,
#   'length_x_residual': 108950,
#   'length_y_residual': 24821,
#   'ETC_x_residual': 508,
#   'ETC_y_residual': 492,
#   'ETC_x_residual_norm': 0.0046627321040119685,
#   'ETC_y_residual_norm': 0.019822723609991943,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.019822723609991943,
#   'ETCE_y_to_x': 0.0046627321040119685,
#   'ETCE_strength': 0.015159991505979974,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 128,
#   'LZ_y': 152,
#   'LZ_xy': 252,
#   'LZ_yx': 255,
#   'LZ_concat_mean': 253.5,
#   'LZ_concat_diff': 3,
#   'LZP_x_to_y': 127,
#   'LZP_y_to_x': 100,
#   'LZP_strength': 27,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 86,
#   'index_x': 8,
#   'index_y': 6,
#   'length_x': 154627,
#   'length_y': 79104,
#   'ETC_x': 512,
#   'ETC_y': 792,
#   'ETC_x_given_Gy': 2,
#   'ETC_y_given_Gx': 95,
#   'length_x_residual': 130938,
#   'length_y_residual': 20320,
#   'ETC_x_residual': 510,
#   'ETC_y_residual': 705,
#   'ETC_x_residual_norm': 0.003895002940345357,
#   'ETC_y_residual_norm': 0.0346965893990846,
#   'ETCP_x_to_y': 8,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 8,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'y_causes_x',
#   'ETCP_cause': 'y',
#   'ETCE_x_to_y': 0.0346965893990846,
#   'ETCE_y_to_x': 0.003895002940345357,
#   'ETCE_strength': 0.03080158645873924,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 128,
#   'LZ_y': 239,
#   'LZ_xy': 341,
#   'LZ_yx': 365,
#   'LZ_concat_mean': 353.0,
#   'LZ_concat_diff': 24,
#   'LZP_x_to_y': 237,
#   'LZP_y_to_x': 102,
#   'LZP_strength': 135,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 87,
#   'index_x': 8,
#   'index_y': 7,
#   'length_x': 154627,
#   'length_y': 107954,
#   'ETC_x': 512,
#   'ETC_y': 877,
#   'ETC_x_given_Gy': 5,
#   'ETC_y_given_Gx': 77,
#   'length_x_residual': 106803,
#   'length_y_residual': 26206,
#   'ETC_x_residual': 507,
#   'ETC_y_residual': 800,
#   'ETC_x_residual_norm': 0.0047471021141926185,
#   'ETC_y_residual_norm': 0.03052852509063156,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.03052852509063156,
#   'ETCE_y_to_x': 0.0047471021141926185,
#   'ETCE_strength': 0.025781422976438942,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 128,
#   'LZ_y': 234,
#   'LZ_xy': 337,
#   'LZ_yx': 358,
#   'LZ_concat_mean': 347.5,
#   'LZ_concat_diff': 21,
#   'LZP_x_to_y': 230,
#   'LZP_y_to_x': 103,
#   'LZP_strength': 127,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 88,
#   'index_x': 8,
#   'index_y': 8,
#   'length_x': 154627,
#   'length_y': 154627,
#   'ETC_x': 512,
#   'ETC_y': 512,
#   'ETC_x_given_Gy': 512,
#   'ETC_y_given_Gx': 512,
#   'length_x_residual': 1,
#   'length_y_residual': 1,
#   'ETC_x_residual': 0,
#   'ETC_y_residual': 0,
#   'ETC_x_residual_norm': 0,
#   'ETC_y_residual_norm': 0,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0,
#   'ETCE_y_to_x': 0,
#   'ETCE_strength': 0,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'n_or_m',
#   'ETCE_cause': 'n_or_m',
#   'LZ_x': 128,
#   'LZ_y': 128,
#   'LZ_xy': 129,
#   'LZ_yx': 129,
#   'LZ_concat_mean': 129.0,
#   'LZ_concat_diff': 0,
#   'LZP_x_to_y': 1,
#   'LZP_y_to_x': 1,
#   'LZP_strength': 0,
#   'LZP_threshold': 1,
#   'LZP_direction': 'n_or_m',
#   'LZP_cause': 'n_or_m',
#   'Consensus': True},
#  {'index_pair': 89,
#   'index_x': 8,
#   'index_y': 9,
#   'length_x': 154627,
#   'length_y': 84611,
#   'ETC_x': 512,
#   'ETC_y': 571,
#   'ETC_x_given_Gy': 84,
#   'ETC_y_given_Gx': 105,
#   'length_x_residual': 2720,
#   'length_y_residual': 1594,
#   'ETC_x_residual': 422,
#   'ETC_y_residual': 468,
#   'ETC_x_residual_norm': 0.1552041191614564,
#   'ETC_y_residual_norm': 0.2937853107344633,
#   'ETCP_x_to_y': 2,
#   'ETCP_y_to_x': -6,
#   'ETCP_strength': 8,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'y_causes_x',
#   'ETCP_cause': 'y',
#   'ETCE_x_to_y': 0.2937853107344633,
#   'ETCE_y_to_x': 0.1552041191614564,
#   'ETCE_strength': 0.13858119157300688,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 128,
#   'LZ_y': 186,
#   'LZ_xy': 282,
#   'LZ_yx': 301,
#   'LZ_concat_mean': 291.5,
#   'LZ_concat_diff': 19,
#   'LZP_x_to_y': 173,
#   'LZP_y_to_x': 96,
#   'LZP_strength': 77,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 90,
#   'index_x': 9,
#   'index_y': 0,
#   'length_x': 84611,
#   'length_y': 114980,
#   'ETC_x': 571,
#   'ETC_y': 443,
#   'ETC_x_given_Gy': 4,
#   'ETC_y_given_Gx': 66,
#   'length_x_residual': 60546,
#   'length_y_residual': 45449,
#   'ETC_x_residual': 567,
#   'ETC_y_residual': 377,
#   'ETC_x_residual_norm': 0.009364935172185977,
#   'ETC_y_residual_norm': 0.008295194508009153,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.008295194508009153,
#   'ETCE_y_to_x': 0.009364935172185977,
#   'ETCE_strength': 0.0010697406641768242,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'y_causes_x',
#   'ETCE_cause': 'y',
#   'LZ_x': 186,
#   'LZ_y': 107,
#   'LZ_xy': 285,
#   'LZ_yx': 276,
#   'LZ_concat_mean': 280.5,
#   'LZ_concat_diff': 9,
#   'LZP_x_to_y': 90,
#   'LZP_y_to_x': 178,
#   'LZP_strength': 88,
#   'LZP_threshold': 1,
#   'LZP_direction': 'x_causes_y',
#   'LZP_cause': 'x',
#   'Consensus': False},
#  {'index_pair': 91,
#   'index_x': 9,
#   'index_y': 1,
#   'length_x': 84611,
#   'length_y': 212034,
#   'ETC_x': 571,
#   'ETC_y': 441,
#   'ETC_x_given_Gy': 68,
#   'ETC_y_given_Gx': 4,
#   'length_x_residual': 11733,
#   'length_y_residual': 151833,
#   'ETC_x_residual': 504,
#   'ETC_y_residual': 437,
#   'ETC_x_residual_norm': 0.04295942720763723,
#   'ETC_y_residual_norm': 0.002878181147584172,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 1,
#   'ETCP_strength': 1,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.002878181147584172,
#   'ETCE_y_to_x': 0.04295942720763723,
#   'ETCE_strength': 0.040081246060053054,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'y_causes_x',
#   'ETCE_cause': 'y',
#   'LZ_x': 186,
#   'LZ_y': 162,
#   'LZ_xy': 346,
#   'LZ_yx': 321,
#   'LZ_concat_mean': 333.5,
#   'LZ_concat_diff': 25,
#   'LZP_x_to_y': 135,
#   'LZP_y_to_x': 184,
#   'LZP_strength': 49,
#   'LZP_threshold': 1,
#   'LZP_direction': 'x_causes_y',
#   'LZP_cause': 'x',
#   'Consensus': False},
#  {'index_pair': 92,
#   'index_x': 9,
#   'index_y': 2,
#   'length_x': 84611,
#   'length_y': 89140,
#   'ETC_x': 571,
#   'ETC_y': 788,
#   'ETC_x_given_Gy': 3,
#   'ETC_y_given_Gx': 61,
#   'length_x_residual': 66948,
#   'length_y_residual': 32449,
#   'ETC_x_residual': 568,
#   'ETC_y_residual': 728,
#   'ETC_x_residual_norm': 0.00848432342001882,
#   'ETC_y_residual_norm': 0.022435897435897436,
#   'ETCP_x_to_y': 1,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 1,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.022435897435897436,
#   'ETCE_y_to_x': 0.00848432342001882,
#   'ETCE_strength': 0.013951574015878616,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 186,
#   'LZ_y': 231,
#   'LZ_xy': 388,
#   'LZ_yx': 393,
#   'LZ_concat_mean': 390.5,
#   'LZ_concat_diff': 5,
#   'LZP_x_to_y': 207,
#   'LZP_y_to_x': 157,
#   'LZP_strength': 50,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 93,
#   'index_x': 9,
#   'index_y': 3,
#   'length_x': 84611,
#   'length_y': 271834,
#   'ETC_x': 571,
#   'ETC_y': 675,
#   'ETC_x_given_Gy': 4,
#   'ETC_y_given_Gx': 5,
#   'length_x_residual': 60546,
#   'length_y_residual': 199312,
#   'ETC_x_residual': 567,
#   'ETC_y_residual': 670,
#   'ETC_x_residual_norm': 0.009364935172185977,
#   'ETC_y_residual_norm': 0.003361580645323138,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.003361580645323138,
#   'ETCE_y_to_x': 0.009364935172185977,
#   'ETCE_strength': 0.006003354526862839,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'y_causes_x',
#   'ETCE_cause': 'y',
#   'LZ_x': 186,
#   'LZ_y': 204,
#   'LZ_xy': 386,
#   'LZ_yx': 367,
#   'LZ_concat_mean': 376.5,
#   'LZ_concat_diff': 19,
#   'LZP_x_to_y': 181,
#   'LZP_y_to_x': 182,
#   'LZP_strength': 1,
#   'LZP_threshold': 1,
#   'LZP_direction': 'n_or_m',
#   'LZP_cause': 'n_or_m',
#   'Consensus': False},
#  {'index_pair': 94,
#   'index_x': 9,
#   'index_y': 4,
#   'length_x': 84611,
#   'length_y': 239046,
#   'ETC_x': 571,
#   'ETC_y': 565,
#   'ETC_x_given_Gy': 3,
#   'ETC_y_given_Gx': 66,
#   'length_x_residual': 63971,
#   'length_y_residual': 84959,
#   'ETC_x_residual': 568,
#   'ETC_y_residual': 500,
#   'ETC_x_residual_norm': 0.008879162107237768,
#   'ETC_y_residual_norm': 0.0058852609524706325,
#   'ETCP_x_to_y': 1,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 1,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.0058852609524706325,
#   'ETCE_y_to_x': 0.008879162107237768,
#   'ETCE_strength': 0.002993901154767136,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'y_causes_x',
#   'ETCE_cause': 'y',
#   'LZ_x': 186,
#   'LZ_y': 170,
#   'LZ_xy': 348,
#   'LZ_yx': 334,
#   'LZ_concat_mean': 341.0,
#   'LZ_concat_diff': 14,
#   'LZP_x_to_y': 148,
#   'LZP_y_to_x': 178,
#   'LZP_strength': 30,
#   'LZP_threshold': 1,
#   'LZP_direction': 'x_causes_y',
#   'LZP_cause': 'x',
#   'Consensus': False},
#  {'index_pair': 95,
#   'index_x': 9,
#   'index_y': 5,
#   'length_x': 84611,
#   'length_y': 156777,
#   'ETC_x': 571,
#   'ETC_y': 562,
#   'ETC_x_given_Gy': 4,
#   'ETC_y_given_Gx': 66,
#   'length_x_residual': 59349,
#   'length_y_residual': 29287,
#   'ETC_x_residual': 567,
#   'ETC_y_residual': 496,
#   'ETC_x_residual_norm': 0.00955381815730943,
#   'ETC_y_residual_norm': 0.016936420132486512,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.016936420132486512,
#   'ETCE_y_to_x': 0.00955381815730943,
#   'ETCE_strength': 0.007382601975177082,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 186,
#   'LZ_y': 152,
#   'LZ_xy': 324,
#   'LZ_yx': 309,
#   'LZ_concat_mean': 316.5,
#   'LZ_concat_diff': 15,
#   'LZP_x_to_y': 123,
#   'LZP_y_to_x': 172,
#   'LZP_strength': 49,
#   'LZP_threshold': 1,
#   'LZP_direction': 'x_causes_y',
#   'LZP_cause': 'x',
#   'Consensus': False},
#  {'index_pair': 96,
#   'index_x': 9,
#   'index_y': 6,
#   'length_x': 84611,
#   'length_y': 79104,
#   'ETC_x': 571,
#   'ETC_y': 792,
#   'ETC_x_given_Gy': 2,
#   'ETC_y_given_Gx': 86,
#   'length_x_residual': 74759,
#   'length_y_residual': 20474,
#   'ETC_x_residual': 569,
#   'ETC_y_residual': 708,
#   'ETC_x_residual_norm': 0.007611225554455711,
#   'ETC_y_residual_norm': 0.0345821325648415,
#   'ETCP_x_to_y': 2,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 2,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'y_causes_x',
#   'ETCP_cause': 'y',
#   'ETCE_x_to_y': 0.0345821325648415,
#   'ETCE_y_to_x': 0.007611225554455711,
#   'ETCE_strength': 0.026970907010385792,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 186,
#   'LZ_y': 239,
#   'LZ_xy': 398,
#   'LZ_yx': 409,
#   'LZ_concat_mean': 403.5,
#   'LZ_concat_diff': 11,
#   'LZP_x_to_y': 223,
#   'LZP_y_to_x': 159,
#   'LZP_strength': 64,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 97,
#   'index_x': 9,
#   'index_y': 7,
#   'length_x': 84611,
#   'length_y': 107954,
#   'ETC_x': 571,
#   'ETC_y': 877,
#   'ETC_x_given_Gy': 5,
#   'ETC_y_given_Gx': 66,
#   'length_x_residual': 58870,
#   'length_y_residual': 28068,
#   'ETC_x_residual': 566,
#   'ETC_y_residual': 811,
#   'ETC_x_residual_norm': 0.009614567938983166,
#   'ETC_y_residual_norm': 0.028895143763138204,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.028895143763138204,
#   'ETCE_y_to_x': 0.009614567938983166,
#   'ETCE_strength': 0.019280575824155037,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 186,
#   'LZ_y': 234,
#   'LZ_xy': 400,
#   'LZ_yx': 403,
#   'LZ_concat_mean': 401.5,
#   'LZ_concat_diff': 3,
#   'LZP_x_to_y': 217,
#   'LZP_y_to_x': 166,
#   'LZP_strength': 51,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 98,
#   'index_x': 9,
#   'index_y': 8,
#   'length_x': 84611,
#   'length_y': 154627,
#   'ETC_x': 571,
#   'ETC_y': 512,
#   'ETC_x_given_Gy': 105,
#   'ETC_y_given_Gx': 84,
#   'length_x_residual': 1594,
#   'length_y_residual': 2720,
#   'ETC_x_residual': 468,
#   'ETC_y_residual': 422,
#   'ETC_x_residual_norm': 0.2937853107344633,
#   'ETC_y_residual_norm': 0.1552041191614564,
#   'ETCP_x_to_y': -6,
#   'ETCP_y_to_x': 2,
#   'ETCP_strength': 8,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'x_causes_y',
#   'ETCP_cause': 'x',
#   'ETCE_x_to_y': 0.1552041191614564,
#   'ETCE_y_to_x': 0.2937853107344633,
#   'ETCE_strength': 0.13858119157300688,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'y_causes_x',
#   'ETCE_cause': 'y',
#   'LZ_x': 186,
#   'LZ_y': 128,
#   'LZ_xy': 301,
#   'LZ_yx': 282,
#   'LZ_concat_mean': 291.5,
#   'LZ_concat_diff': 19,
#   'LZP_x_to_y': 96,
#   'LZP_y_to_x': 173,
#   'LZP_strength': 77,
#   'LZP_threshold': 1,
#   'LZP_direction': 'x_causes_y',
#   'LZP_cause': 'x',
#   'Consensus': False},
#  {'index_pair': 99,
#   'index_x': 9,
#   'index_y': 9,
#   'length_x': 84611,
#   'length_y': 84611,
#   'ETC_x': 571,
#   'ETC_y': 571,
#   'ETC_x_given_Gy': 571,
#   'ETC_y_given_Gx': 571,
#   'length_x_residual': 1,
#   'length_y_residual': 1,
#   'ETC_x_residual': 0,
#   'ETC_y_residual': 0,
#   'ETC_x_residual_norm': 0,
#   'ETC_y_residual_norm': 0,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0,
#   'ETCE_y_to_x': 0,
#   'ETCE_strength': 0,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'n_or_m',
#   'ETCE_cause': 'n_or_m',
#   'LZ_x': 186,
#   'LZ_y': 186,
#   'LZ_xy': 187,
#   'LZ_yx': 187,
#   'LZ_concat_mean': 187.0,
#   'LZ_concat_diff': 0,
#   'LZP_x_to_y': 1,
#   'LZP_y_to_x': 1,
#   'LZP_strength': 0,
#   'LZP_threshold': 1,
#   'LZP_direction': 'n_or_m',
#   'LZP_cause': 'n_or_m',
#   'Consensus': True}]

# %%
# alt_labels = [11, 5, 12, 13, 14, 7, 15, 16, 9, 10]


draw.draw_causal_inference(dists, labels, mela='Kalyani')
# Out:
# digraph "" {
# 	graph [bb="0,0,3014.4,1210.6",
# 		rankdir=TD
# 	];
# 	node [label="\N"];
# 	"Himadri-Sute(Kalyani)"	[color=grey,
# 		fontcolor=white,
# 		fontsize=36,
# 		height=0.94281,
# 		pos="1014.5,241.71",
# 		style=filled,
# 		width=8.4067];
# 	"Jalajakshi(Hamsadhwani)"	[fontsize=36,
# 		height=0.94281,
# 		pos="1014.5,33.941",
# 		width=9.5067];
# 	"Himadri-Sute(Kalyani)" -> "Jalajakshi(Hamsadhwani)"	[pos="e,1014.5,67.919 1014.5,207.65 1014.5,172.55 1014.5,116.92 1014.5,78.323",
# 		weight=1.0];
# 	"nidhi-chala(Kalyani)"	[color=grey,
# 		fontcolor=white,
# 		fontsize=36,
# 		height=0.94281,
# 		pos="1645.5,137.82",
# 		style=filled,
# 		width=7.5425];
# 	"Himadri-Sute(Kalyani)" -> "nidhi-chala(Kalyani)"	[pos="e,1483.1,165.05 1183.2,213.47 1272.8,199 1382.8,181.24 1473,166.67",
# 		weight=1.0];
# 	"nidhi-chala(Kalyani)" -> "Jalajakshi(Hamsadhwani)"	[pos="e,1189.2,63.144 1483,110.59 1396.3,96.578 1289.1,79.281 1199.2,64.765",
# 		weight=1.0];
# 	"Kamalambam(Kalyani)"	[color=grey,
# 		fontcolor=white,
# 		fontsize=36,
# 		height=0.94281,
# 		pos="1140.5,968.88",
# 		style=filled,
# 		width=8.5246];
# 	"Kamalambam(Kalyani)" -> "Himadri-Sute(Kalyani)"	[pos="e,774.06,262.35 856.57,955.96 687.98,945.87 501.95,928.25 475.52,898.94 461.23,883.09 394.79,593.63 480.52,415.53 512.15,349.82 \
# 541.14,341.83 607.52,311.65 656.12,289.55 710.89,274.48 764.13,264.21",
# 		weight=1.0];
# 	"Kamalambam(Kalyani)" -> "Jalajakshi(Hamsadhwani)"	[pos="e,700.67,47.495 865.73,953.65 673.8,941.76 445.09,922.9 405.52,898.94 202.26,775.89 114.52,688.07 114.52,450.47 114.52,450.47 114.52,\
# 450.47 114.52,240.71 114.52,170.26 134.94,141.47 194.52,103.88 236.98,77.093 480.09,58.936 690.67,48.009",
# 		weight=1.0];
# 	"Kamalambam(Kalyani)" -> "nidhi-chala(Kalyani)"	[pos="e,1374.4,140.07 857.91,955.61 681.73,945.22 482.84,927.37 452.52,898.94 356.3,808.71 303.09,427.29 366.52,311.65 407.83,236.33 447.83,\
# 234.34 529.52,207.76 678.87,159.17 1085.3,144.47 1364.1,140.22",
# 		weight=1.0];
# 	"Pankaja-lochana(Kalyani)"	[color=grey,
# 		fontcolor=white,
# 		fontsize=36,
# 		height=0.94281,
# 		pos="976.52,553.35",
# 		style=filled,
# 		width=9.4477];
# 	"Kamalambam(Kalyani)" -> "Pankaja-lochana(Kalyani)"	[pos="e,975.72,587.58 1177.5,935.03 1186.8,924.53 1195.6,912.17 1200.5,898.94 1211.1,870.68 1214.4,857.83 1200.5,831.06 1150.7,735.12 \
# 1059.8,782.23 1001.5,691.18 983.72,663.37 977.8,626.24 976.15,597.68",
# 		weight=1.0];
# 	"raghunaayaka(Hamsadhwani)"	[fontsize=36,
# 		height=0.94281,
# 		pos="1482.5,345.59",
# 		width=11.157];
# 	"Kamalambam(Kalyani)" -> "raghunaayaka(Hamsadhwani)"	[pos="e,1179.5,367.9 1160.4,934.97 1175.6,904.97 1190.5,860.89 1167.5,831.06 1129.4,781.51 1089.9,817.49 1031.5,795.06 843.05,722.63 732.69,\
# 759.65 627.52,587.29 611.8,561.54 608.42,542.76 627.52,519.41 696.01,435.69 954.31,391.59 1169.3,368.96",
# 		weight=1.0];
# 	"Sive-Pahi Maam(Kalyani)"	[color=grey,
# 		fontcolor=white,
# 		fontsize=36,
# 		height=0.94281,
# 		pos="821.52,865",
# 		style=filled,
# 		width=9.3495];
# 	"Kamalambam(Kalyani)" -> "Sive-Pahi Maam(Kalyani)"	[pos="e,920.04,897.46 1042.6,936.62 1006.9,925.21 966.31,912.24 929.74,900.56",
# 		weight=1.0];
# 	"vaarana mukha va(Hamsadhwani)"	[fontsize=36,
# 		height=0.94281,
# 		pos="2048.5,449.47",
# 		width=12.649];
# 	"Kamalambam(Kalyani)" -> "vaarana mukha va(Hamsadhwani)"	[pos="e,2117.5,483.16 1357.4,944.86 1637.3,909.76 2098.7,831.65 2185.5,691.18 2226.2,625.39 2203.4,581.68 2157.5,519.41 2148.9,507.77 \
# 2137.7,497.61 2125.8,488.93",
# 		weight=1.0];
# 	"vatapi-ganapathim(Hamsadhwani)"	[fontsize=36,
# 		height=0.94281,
# 		pos="1693.5,657.23",
# 		width=12.767];
# 	"Kamalambam(Kalyani)" -> "vatapi-ganapathim(Hamsadhwani)"	[pos="e,1355.9,680.29 1205.1,935.66 1218.5,925.8 1230.9,913.6 1238.5,898.94 1273.9,831.29 1189.6,784.92 1239.5,727.18 1257.1,706.86 1296.9,\
# 692.46 1345.9,682.27",
# 		weight=1.0];
# 	"surrogate2(Hamsadhwani)"	[fontsize=36,
# 		height=0.94281,
# 		pos="1608.5,761.12",
# 		width=9.9977];
# 	"Kamalambam(Kalyani)" -> "surrogate2(Hamsadhwani)"	[pos="e,1535.1,794.42 1213.4,935.84 1298,898.64 1437.3,837.42 1525.8,798.47",
# 		weight=1.0];
# 	"Pankaja-lochana(Kalyani)" -> "Himadri-Sute(Kalyani)"	[pos="e,1007.1,275.9 978.77,519.13 982.16,472.57 989.39,385.35 1000.5,311.65 1001.8,303.23 1003.4,294.28 1005.1,285.72",
# 		weight=1.0];
# 	"Pankaja-lochana(Kalyani)" -> "Jalajakshi(Hamsadhwani)"	[pos="e,881.75,65.364 848.51,521.86 821.11,512.09 793.28,499.49 769.52,483.41 661.94,410.64 604.48,318.39 672.52,207.76 716.13,136.86 \
# 798.82,93.979 871.96,68.668",
# 		weight=1.0];
# 	"Pankaja-lochana(Kalyani)" -> "nidhi-chala(Kalyani)"	[pos="e,1374.6,140.21 917.08,519.89 809.36,457.16 601.96,315.95 702.52,207.76 747.14,159.76 1103.1,144.82 1364.5,140.37",
# 		weight=1.0];
# 	"Pankaja-lochana(Kalyani)" -> "raghunaayaka(Hamsadhwani)"	[pos="e,1403.1,378.89 1055.3,520.31 1147,483.04 1298,421.64 1393.7,382.7",
# 		weight=1.0];
# 	"Pankaja-lochana(Kalyani)" -> "vaarana mukha va(Hamsadhwani)"	[pos="e,1773.6,476.6 1217.8,529.42 1379.5,514.05 1593.3,493.73 1763.5,477.56",
# 		weight=1.0];
# 	"raghunaayaka(Hamsadhwani)" -> "Himadri-Sute(Kalyani)"	[pos="e,1149.5,272.09 1341.2,313.81 1283.7,301.3 1217.3,286.85 1159.4,274.25",
# 		weight=1.0];
# 	"raghunaayaka(Hamsadhwani)" -> "Jalajakshi(Hamsadhwani)"	[pos="e,1082.4,67.244 1449.3,311.65 1418.8,282.43 1371.8,239.58 1326.5,207.76 1250.6,154.38 1156.6,104.26 1091.8,71.89",
# 		weight=1.0];
# 	"raghunaayaka(Hamsadhwani)" -> "nidhi-chala(Kalyani)"	[pos="e,1619.4,171.8 1508.7,311.53 1537.1,275.68 1582.5,218.42 1613.1,179.75",
# 		weight=1.0];
# 	"Sive-Pahi Maam(Kalyani)" -> "Himadri-Sute(Kalyani)"	[pos="e,831.23,268.73 720.26,832.62 698.12,822.83 675.86,810.44 657.52,795.06 525.3,684.15 472.31,553.84 575.52,415.53 633.71,337.54 732.43,\
# 294.72 821.53,271.22",
# 		weight=1.0];
# 	"Sive-Pahi Maam(Kalyani)" -> "Jalajakshi(Hamsadhwani)"	[pos="e,714.55,50.356 615.52,838.13 579.84,828.11 544.34,814.24 513.52,795.06 296.27,659.87 152.52,602.46 152.52,346.59 152.52,346.59 \
# 152.52,346.59 152.52,240.71 152.52,123.62 457.22,73.024 704.3,51.245",
# 		weight=1.0];
# 	"Sive-Pahi Maam(Kalyani)" -> "nidhi-chala(Kalyani)"	[pos="e,1378.1,143.91 662.46,835.01 635.68,825.3 609.48,812.34 587.52,795.06 415.85,659.95 354.36,475.79 498.52,311.65 557.95,243.97 586.59,\
# 234.77 672.52,207.76 797.5,168.49 1126.8,151.51 1367.8,144.22",
# 		weight=1.0];
# 	"Sive-Pahi Maam(Kalyani)" -> "Pankaja-lochana(Kalyani)"	[pos="e,959.82,587.72 838.11,830.86 866.41,774.32 923.99,659.29 955.22,596.9",
# 		weight=1.0];
# 	"Sive-Pahi Maam(Kalyani)" -> "raghunaayaka(Hamsadhwani)"	[pos="e,1110.1,358.37 774.39,831.26 732.08,799.71 670.88,748.43 632.52,691.18 564.32,589.4 535.03,489.72 632.52,415.53 671.1,386.17 892.71,\
# 368.81 1100,358.85",
# 		weight=1.0];
# 	"Sive-Pahi Maam(Kalyani)" -> "vaarana mukha va(Hamsadhwani)"	[pos="e,1813.5,478.61 865.21,831.18 936.57,779.17 1084.3,678.1 1224.5,623.29 1412.1,550 1636.4,505.54 1803.6,480.11",
# 		weight=1.0];
# 	"Sive-Pahi Maam(Kalyani)" -> "vatapi-ganapathim(Hamsadhwani)"	[pos="e,1361.5,680.73 1025.6,838 1059.1,827.97 1092.1,814.13 1120.5,795.06 1151.2,774.47 1136.9,746.27 1168.5,727.18 1202.4,706.74 1272.8,\
# 692.25 1351.4,682.02",
# 		weight=1.0];
# 	"Sive-Pahi Maam(Kalyani)" -> "surrogate2(Hamsadhwani)"	[pos="e,1401.5,788.92 1023.7,837.83 1136.3,823.25 1276.6,805.09 1391.5,790.21",
# 		weight=1.0];
# 	"vaarana mukha va(Hamsadhwani)" -> "Himadri-Sute(Kalyani)"	[pos="e,1314.9,246.09 2022.6,415.55 1994.6,382.8 1946.9,334.26 1893.5,311.65 1793.8,269.4 1535.8,252.79 1324.9,246.39",
# 		weight=1.0];
# 	"vaarana mukha va(Hamsadhwani)" -> "Jalajakshi(Hamsadhwani)"	[pos="e,1356.1,36.312 2396.9,427.58 2506,417.06 2610.7,401.68 2659.5,379.53 2780.3,324.78 2865.4,199.44 2773.5,103.88 2725.6,54.031 1865.8,\
# 40.21 1366.4,36.39",
# 		weight=1.0];
# 	"vaarana mukha va(Hamsadhwani)" -> "nidhi-chala(Kalyani)"	[pos="e,1829.4,162.87 2046.8,415.29 2042.3,363 2025.7,261.85 1964.5,207.76 1944.1,189.71 1894,175.49 1839.3,164.77",
# 		weight=1.0];
# 	"vaarana mukha va(Hamsadhwani)" -> "raghunaayaka(Hamsadhwani)"	[pos="e,1648.8,376.52 1878.7,417.9 1809.3,405.42 1729.1,390.97 1659.1,378.37",
# 		weight=1.0];
# 	"vatapi-ganapathim(Hamsadhwani)" -> "Himadri-Sute(Kalyani)"	[pos="e,1021.2,275.66 1579.2,624.35 1546.2,613.88 1510.5,601.28 1478.5,587.29 1422.4,562.73 1412.8,547.93 1358.5,519.41 1232.9,453.36 \
# 1168.9,482.77 1071.5,379.53 1046.9,353.4 1032.2,315.1 1023.9,285.67",
# 		weight=1.0];
# 	"vatapi-ganapathim(Hamsadhwani)" -> "Jalajakshi(Hamsadhwani)"	[pos="e,1353.5,38.657 1657.5,623.1 1607.4,573.11 1528.8,477.67 1584.5,415.53 1634.1,360.3 1865.6,433.55 1916.5,379.53 2000.6,290.29 2009.9,\
# 193.77 1926.5,103.88 1887.7,62.004 1604.5,45.422 1363.8,38.931",
# 		weight=1.0];
# 	"vatapi-ganapathim(Hamsadhwani)" -> "nidhi-chala(Kalyani)"	[pos="e,1721.3,170.51 1598.7,623.89 1582.9,614.45 1568.5,602.45 1558.5,587.29 1516.5,523.51 1500.4,472.31 1551.5,415.53 1602.6,358.73 \
# 1842.4,436.32 1893.5,379.53 1962.5,302.85 1827,220.58 1730.5,174.83",
# 		weight=1.0];
# 	"vatapi-ganapathim(Hamsadhwani)" -> "Pankaja-lochana(Kalyani)"	[pos="e,1167.4,581.47 1487.1,626.9 1389.8,613.08 1274.2,596.65 1177.6,582.92",
# 		weight=1.0];
# 	"vatapi-ganapathim(Hamsadhwani)" -> "raghunaayaka(Hamsadhwani)"	[pos="e,1476.6,379.71 1576.6,624.29 1556.2,614.83 1536.4,602.72 1520.5,587.29 1467.9,536.21 1469.1,443.96 1475.4,389.7",
# 		weight=1.0];
# 	"vatapi-ganapathim(Hamsadhwani)" -> "vaarana mukha va(Hamsadhwani)"	[pos="e,1992.1,483.18 1750.2,623.4 1813.7,586.59 1916.5,527 1983.3,488.27",
# 		weight=1.0];
# 	"surrogate2(Hamsadhwani)" -> "Himadri-Sute(Kalyani)"	[pos="e,1009.6,275.71 1333.1,739.23 1275.1,729.02 1225.6,713.81 1206.5,691.18 1187.1,668.11 1188.5,647.52 1206.5,623.29 1239.5,578.92 \
# 1292.6,631.66 1325.5,587.29 1343.5,563.07 1341.7,544.9 1325.5,519.41 1247.7,396.49 1114,498.02 1029.5,379.53 1010.4,352.67 1007.5,\
# 314.99 1008.9,285.97",
# 		weight=1.0];
# 	"surrogate2(Hamsadhwani)" -> "Jalajakshi(Hamsadhwani)"	[pos="e,826.02,62.331 1276.4,748.04 1023.5,730.79 706.02,688.91 627.52,587.29 494.8,415.49 524.57,235.09 697.52,103.88 718.12,88.252 764.73,\
# 74.965 816.04,64.35",
# 		weight=1.0];
# 	"surrogate2(Hamsadhwani)" -> "nidhi-chala(Kalyani)"	[pos="e,1907.3,146.89 1882.3,739 2002.7,727.34 2129.5,711.14 2185.5,691.18 2347.7,633.35 2429.6,634.32 2512.5,483.41 2645.2,241.9 2218.6,\
# 169.2 1917.5,147.6",
# 		weight=1.0];
# 	"surrogate2(Hamsadhwani)" -> "Pankaja-lochana(Kalyani)"	[pos="e,1002.4,587.46 1358.1,736.73 1232.9,723.39 1102.7,706.36 1077.5,691.18 1045.9,672.11 1051.5,653.03 1029.5,623.29 1022.9,614.27 \
# 1015.6,604.68 1008.7,595.61",
# 		weight=1.0];
# 	"surrogate2(Hamsadhwani)" -> "raghunaayaka(Hamsadhwani)"	[pos="e,1474.7,379.69 1345.1,737.94 1289.8,727.74 1242.7,712.87 1224.5,691.18 1205.2,668.03 1206.2,647.23 1224.5,623.29 1262,574.36 1310.5,\
# 626.01 1358.5,587.29 1422.1,536.03 1456.5,443.53 1472,389.34",
# 		weight=1.0];
# 	"surrogate2(Hamsadhwani)" -> "vaarana mukha va(Hamsadhwani)"	[pos="e,2085.6,483.37 1896.7,740.73 2021.4,729.34 2143.3,712.88 2162.5,691.18 2215.6,631.06 2144.4,541.89 2093,490.65",
# 		weight=1.0];
# 	"surrogate2(Hamsadhwani)" -> "vatapi-ganapathim(Hamsadhwani)"	[pos="e,1666.1,691.15 1636.1,727.04 1643.6,718.05 1651.8,708.21 1659.6,698.86",
# 		weight=1.0];
# 	"sivakaameswari(Kalyani)"	[color=grey,
# 		fontcolor=white,
# 		fontsize=36,
# 		height=0.94281,
# 		pos="439.52,1072.8",
# 		style=filled,
# 		width=9.3102];
# 	"sivakaameswari(Kalyani)" -> "Himadri-Sute(Kalyani)"	[pos="e,750.37,258.36 350.33,1040 278.88,1008.2 190.52,951.52 190.52,866 190.52,866 190.52,866 190.52,760.12 190.52,518.32 292.49,438.22 \
# 498.52,311.65 540.39,285.92 639.81,269.61 740.33,259.36",
# 		weight=1.0];
# 	"sivakaameswari(Kalyani)" -> "Jalajakshi(Hamsadhwani)"	[pos="e,684.76,43.082 265.85,1043.7 217.94,1032.9 174.23,1019.1 156.52,1002.8 73.607,926.44 76.519,874.85 76.519,762.12 76.519,762.12 \
# 76.519,762.12 76.519,240.71 76.519,176.41 72.667,143.23 123.52,103.88 167.52,69.833 441.94,52.297 674.75,43.457",
# 		weight=1.0];
# 	"sivakaameswari(Kalyani)" -> "nidhi-chala(Kalyani)"	[pos="e,1373.8,139.12 276.03,1043.1 251.4,1033.4 227.83,1020.3 208.52,1002.8 159.83,958.7 152.52,931.71 152.52,866 152.52,866 152.52,866 \
# 152.52,760.12 152.52,580.13 336.02,242.35 387.52,207.76 466.38,154.8 1017.5,141.97 1363.7,139.2",
# 		weight=1.0];
# 	"sivakaameswari(Kalyani)" -> "Kamalambam(Kalyani)"	[pos="e,958.88,996.28 626.91,1044.5 726.51,1030.1 848.72,1012.3 948.94,997.72",
# 		weight=1.0];
# 	"sivakaameswari(Kalyani)" -> "Pankaja-lochana(Kalyani)"	[pos="e,903.84,586.53 427.88,1038.7 412.55,988.91 392.3,893.65 435.52,831.06 456.07,801.29 476.9,812.64 508.52,795.06 558.39,767.32 567.51,\
# 754.68 617.52,727.18 710.52,676.03 821,624.11 894.6,590.72",
# 		weight=1.0];
# 	"sivakaameswari(Kalyani)" -> "raghunaayaka(Hamsadhwani)"	[pos="e,1108.1,357.9 416.39,1038.9 409.94,1027.9 403.81,1015.3 400.52,1002.8 381.08,929 394.69,907.18 400.52,831.06 415.82,631.25 408.72,\
# 526.59 575.52,415.53 620.02,385.9 871.26,368.32 1098,358.34",
# 		weight=1.0];
# 	"sivakaameswari(Kalyani)" -> "Sive-Pahi Maam(Kalyani)"	[pos="e,761.27,898.45 500.05,1039.2 568.64,1002.2 680.24,942.1 752.26,903.31",
# 		weight=1.0];
# 	"sivakaameswari(Kalyani)" -> "vaarana mukha va(Hamsadhwani)"	[pos="e,1594.9,452.73 420.09,1038.8 414.57,1027.8 409.31,1015.1 406.52,1002.8 402.55,985.36 403.07,844.83 407.52,831.06 459.59,669.71 \
# 478.92,601.04 627.52,519.41 710.4,473.89 1202.6,458.16 1584.8,452.87",
# 		weight=1.0];
# 	"sivakaameswari(Kalyani)" -> "vatapi-ganapathim(Hamsadhwani)"	[pos="e,1444.5,685.81 433.49,1038.5 426.19,986.52 420.88,886.37 475.52,831.06 508.98,797.19 1087,726.63 1434.5,686.94",
# 		weight=1.0];
# 	"sivakaameswari(Kalyani)" -> "surrogate2(Hamsadhwani)"	[pos="e,1592.4,795.17 764.34,1064.4 1039.2,1055.7 1397.8,1037.8 1456.5,1002.8 1495.3,979.71 1556.1,867.08 1587.8,804.41",
# 		weight=1.0];
# 	"surrogate(Hamsadhwani)"	[fontsize=36,
# 		height=0.94281,
# 		pos="2198.5,968.88",
# 		width=9.5263];
# 	"sivakaameswari(Kalyani)" -> "surrogate(Hamsadhwani)"	[pos="e,1906.8,986.78 726.54,1055.1 1048.6,1036.5 1568.7,1006.4 1896.7,987.37",
# 		weight=1.0];
# 	"surrogate(Hamsadhwani)" -> "Himadri-Sute(Kalyani)"	[pos="e,1296.4,254.13 2286.8,936.05 2308,926.07 2329.6,913.72 2347.5,898.94 2436.5,825.62 2609.5,503.91 2535.5,415.53 2458.1,323.08 1726.2,\
# 274.86 1306.6,254.61",
# 		weight=1.0];
# 	"surrogate(Hamsadhwani)" -> "Jalajakshi(Hamsadhwani)"	[pos="e,1355.9,36.462 2352,938.45 2380.1,928.76 2407.9,915.92 2431.5,898.94 2590.1,785.02 2945.6,239.94 2805.5,103.88 2754.8,54.608 1872.9,\
# 40.55 1366,36.54",
# 		weight=1.0];
# 	"surrogate(Hamsadhwani)" -> "nidhi-chala(Kalyani)"	[pos="e,1905.4,147.79 2319.5,937.08 2344.4,927.37 2369.5,914.87 2390.5,898.94 2435.7,864.71 2435.1,843.52 2464.5,795.06 2577.1,609.51 \
# 2652.1,493.42 2533.5,311.65 2491.4,247.05 2466.5,235.42 2394.5,207.76 2309.3,175.02 2093.6,157.47 1915.5,148.3",
# 		weight=1.0];
# 	"surrogate(Hamsadhwani)" -> "Pankaja-lochana(Kalyani)"	[pos="e,1020.8,587.06 2168.8,934.9 2110,869.65 1983.8,730.12 1977.5,727.18 1825.8,656.14 1385.7,736.82 1224.5,691.18 1152,670.64 1077.4,\
# 625.63 1029.2,592.83",
# 		weight=1.0];
# 	"surrogate(Hamsadhwani)" -> "raghunaayaka(Hamsadhwani)"	[pos="e,1849.3,359.43 2263.6,935.38 2279.6,925.26 2295.8,913 2308.5,898.94 2386.6,812.34 2592.2,500.69 2512.5,415.53 2489.7,391.13 2144,\
# 371.77 1859.4,359.85",
# 		weight=1.0];
# 	"surrogate(Hamsadhwani)" -> "Sive-Pahi Maam(Kalyani)"	[pos="e,1088.2,885.73 1928.5,947.9 1688.8,930.17 1340,904.36 1098.2,886.47",
# 		weight=1.0];
# 	"surrogate(Hamsadhwani)" -> "vaarana mukha va(Hamsadhwani)"	[pos="e,2220.2,480.95 2237.6,935.09 2277.4,897.71 2333.5,832.61 2333.5,762.12 2333.5,762.12 2333.5,762.12 2333.5,656.23 2333.5,594.5 2351.3,\
# 564.87 2309.5,519.41 2296.7,505.47 2266,493.46 2230,483.56",
# 		weight=1.0];
# 	"surrogate(Hamsadhwani)" -> "vatapi-ganapathim(Hamsadhwani)"	[pos="e,1916,686.97 2187.8,934.95 2168.7,882.08 2123.8,778.95 2048.5,727.18 2026.3,711.89 1979,699.1 1926,688.85",
# 		weight=1.0];
# 	"surrogate(Hamsadhwani)" -> "surrogate2(Hamsadhwani)"	[pos="e,1699.9,793.98 2107.3,936.07 1999.7,898.53 1821.2,836.29 1709.5,797.33",
# 		weight=1.0];
# 	"surrogate(Kalyani)"	[color=grey,
# 		fontcolor=white,
# 		fontsize=36,
# 		height=0.94281,
# 		pos="1589.5,1176.6",
# 		style=filled,
# 		width=7.0711];
# 	"surrogate(Kalyani)" -> "Himadri-Sute(Kalyani)"	[pos="e,743.52,256.87 1336.1,1173.1 916.31,1167.7 118.28,1151.5 75.519,1106.7 -34.816,991.23 170.79,538.65 272.52,415.53 317.45,361.15 \
# 327.88,339.89 392.52,311.65 453.53,284.99 598.68,268.05 733.43,257.64",
# 		weight=1.0];
# 	"surrogate(Kalyani)" -> "Jalajakshi(Hamsadhwani)"	[pos="e,686.68,43.737 1337.4,1171.9 912.01,1164.6 92.743,1145.6 42.519,1106.7 -7.7821,1067.8 0.51881,1033.5 0.51881,969.88 0.51881,969.88 \
# 0.51881,969.88 0.51881,240.71 0.51881,171.36 17.185,141.38 75.519,103.88 126.06,71.393 428.26,53.483 676.39,44.121",
# 		weight=1.0];
# 	"surrogate(Kalyani)" -> "nidhi-chala(Kalyani)"	[pos="e,1907.1,146.95 1840.4,1170.8 2096.7,1163.8 2476.2,1146.8 2616.5,1106.7 2726.9,1075.2 2835.5,1084.6 2835.5,969.88 2835.5,969.88 \
# 2835.5,969.88 2835.5,344.59 2835.5,210.46 2695.7,243.88 2566.5,207.76 2448.7,174.82 2144.1,156.66 1917.2,147.36",
# 		weight=1.0];
# 	"surrogate(Kalyani)" -> "Kamalambam(Kalyani)"	[pos="e,1210.5,1002 1520.3,1143.9 1439.2,1106.7 1304.9,1045.2 1219.6,1006.1",
# 		weight=1.0];
# 	"surrogate(Kalyani)" -> "Pankaja-lochana(Kalyani)"	[pos="e,816.32,583.33 1336.1,1172.9 921.02,1167.3 137.59,1150.8 95.519,1106.7 -21.422,984.24 527.12,685.73 684.52,623.29 723.07,608 765.88,\
# 595.55 806.58,585.66",
# 		weight=1.0];
# 	"surrogate(Kalyani)" -> "raghunaayaka(Hamsadhwani)"	[pos="e,1876.1,352.47 1840.5,1170.8 2069.8,1163.8 2390.9,1147 2510.5,1106.7 2616.4,1071 2721.5,1081.6 2721.5,969.88 2721.5,969.88 2721.5,\
# 969.88 2721.5,864 2721.5,648.22 2711,541.17 2535.5,415.53 2482.3,377.41 2160.3,360.37 1886.2,352.75",
# 		weight=1.0];
# 	"surrogate(Kalyani)" -> "Sive-Pahi Maam(Kalyani)"	[pos="e,811.8,899.18 1381.3,1157.1 1179.5,1134.3 894,1087.8 824.52,1002.8 803.54,977.15 804.54,938.81 809.79,909.24",
# 		weight=1.0];
# 	"surrogate(Kalyani)" -> "vaarana mukha va(Hamsadhwani)"	[pos="e,2289.9,478.31 1839.4,1170.1 2049,1162.7 2330.7,1145.7 2436.5,1106.7 2510.6,1079.4 2544.6,1073.1 2580.5,1002.8 2686.3,796.13 2578.6,\
# 643.75 2382.5,519.41 2357.1,503.32 2328.7,490.89 2299.4,481.32",
# 		weight=1.0];
# 	"surrogate(Kalyani)" -> "vatapi-ganapathim(Hamsadhwani)"	[pos="e,2028.8,680.51 1836,1168.1 2092,1154.2 2466.8,1114.8 2550.5,1002.8 2702.6,799.52 2338.8,715.89 2039,681.66",
# 		weight=1.0];
# 	"surrogate(Kalyani)" -> "surrogate2(Hamsadhwani)"	[pos="e,1607,795.13 1591,1142.5 1594.5,1068.2 1602.7,888.12 1606.5,805.22",
# 		weight=1.0];
# 	"surrogate(Kalyani)" -> "sivakaameswari(Kalyani)"	[pos="e,679.97,1096.5 1377.8,1157.8 1216.9,1144.1 990.26,1124.6 791.52,1106.7 758.69,1103.8 724.15,1100.6 690.05,1097.4",
# 		weight=1.0];
# 	"surrogate(Kalyani)" -> "surrogate(Hamsadhwani)"	[pos="e,2201.2,1003 1816.3,1161.1 1967,1149.4 2141.9,1130.8 2168.5,1106.7 2194.2,1083.4 2200.6,1043.7 2201.2,1013.1",
# 		weight=1.0];
# 	"surrogate2(Kalyani)"	[color=grey,
# 		fontcolor=white,
# 		fontsize=36,
# 		height=0.94281,
# 		pos="1888.5,1072.8",
# 		style=filled,
# 		width=7.5228];
# 	"surrogate(Kalyani)" -> "surrogate2(Kalyani)"	[pos="e,1797.5,1104.8 1680,1144.8 1714.1,1133.2 1752.9,1120 1787.8,1108.1",
# 		weight=1.0];
# 	"surrogate2(Kalyani)" -> "Himadri-Sute(Kalyani)"	[pos="e,1312.5,247.76 2157.9,1069.3 2317.4,1063 2500.9,1046.2 2567.5,1002.8 2626.2,964.64 2645.5,936 2645.5,866 2645.5,866 2645.5,866 \
# 2645.5,656.23 2645.5,542.33 2637.1,497.05 2557.5,415.53 2469.5,325.29 2416.7,338.47 2293.5,311.65 2115.4,272.88 1641.1,255.49 1322.8,\
# 248",
# 		weight=1.0];
# 	"surrogate2(Kalyani)" -> "Jalajakshi(Hamsadhwani)"	[pos="e,1356,36.474 2140.1,1060.1 2356.7,1048.5 2641.8,1028.6 2689.5,1002.8 3045.8,810.86 3130.2,380.2 2834.5,103.88 2781.8,54.653 1880.2,\
# 40.577 1366.1,36.553",
# 		weight=1.0];
# 	"surrogate2(Kalyani)" -> "nidhi-chala(Kalyani)"	[pos="e,1912.1,144.32 2151.8,1064.6 2325,1056.5 2533.9,1039.3 2614.5,1002.8 2695.2,966.25 2759.5,954.6 2759.5,866 2759.5,866 2759.5,866 \
# 2759.5,448.47 2759.5,279.25 2621.4,271.19 2464.5,207.76 2369,169.14 2120.5,152.16 1922.1,144.69",
# 		weight=1.0];
# 	"surrogate2(Kalyani)" -> "Kamalambam(Kalyani)"	[pos="e,1329.7,995.65 1708.9,1047.3 1597.6,1032.1 1454.5,1012.6 1339.7,997.01",
# 		weight=1.0];
# 	"surrogate2(Kalyani)" -> "Pankaja-lochana(Kalyani)"	[pos="e,988.53,587.28 1806.8,1040.3 1777.3,1028.8 1743.8,1015.4 1713.5,1002.8 1501.1,914.48 1445.4,897.62 1239.5,795.06 1184.3,767.56 \
# 1174.1,753.88 1118.5,727.18 1080.1,708.7 1059.5,721.57 1029.5,691.18 1026,687.57 1006.4,635.65 992.04,596.83",
# 		weight=1.0];
# 	"surrogate2(Kalyani)" -> "raghunaayaka(Hamsadhwani)"	[pos="e,1498.6,379.75 1863.4,1038.8 1856.5,1027.9 1850,1015.4 1846.5,1002.8 1838.4,973.77 1832.4,961.6 1846.5,934.94 1859.8,909.78 1876.6,\
# 915.78 1899.5,898.94 2019.7,810.86 2097.6,825.24 2162.5,691.18 2175.7,664.02 2181.2,647 2162.5,623.29 1999.1,415.58 1805,629.1 1584.5,\
# 483.41 1548.9,459.85 1521,419.4 1503.5,388.57",
# 		weight=1.0];
# 	"surrogate2(Kalyani)" -> "Sive-Pahi Maam(Kalyani)"	[pos="e,1115.7,881.52 1686.6,1050 1636.3,1039.8 1583.6,1024.8 1537.5,1002.8 1495.1,982.57 1499.7,953.35 1456.5,934.94 1396.7,909.44 1258.3,\
# 892.83 1126,882.32",
# 		weight=1.0];
# 	"surrogate2(Kalyani)" -> "vaarana mukha va(Hamsadhwani)"	[pos="e,2262.7,479.5 2143.6,1061.4 2318.1,1051.5 2522.8,1033.6 2550.5,1002.8 2583.3,966.5 2487.1,637.51 2336.5,519.41 2317.3,504.35 2295.3,\
# 492.51 2272.3,483.2",
# 		weight=1.0];
# 	"surrogate2(Kalyani)" -> "vatapi-ganapathim(Hamsadhwani)"	[pos="e,1891.3,687.92 1840.9,1039 1829.9,1028.8 1819.6,1016.6 1813.5,1002.8 1801.4,975.2 1800.9,962.33 1813.5,934.94 1862.8,828.12 2050.2,\
# 819.65 1977.5,727.18 1965.8,712.27 1936.7,700.2 1901.4,690.57",
# 		weight=1.0];
# 	"surrogate2(Kalyani)" -> "surrogate2(Hamsadhwani)"	[pos="e,1625.7,795.32 1825.4,1039.6 1808.2,1029.2 1790.2,1016.7 1775.5,1002.8 1712.2,943.08 1658.8,855.58 1630.5,804.17",
# 		weight=1.0];
# 	"surrogate2(Kalyani)" -> "surrogate(Hamsadhwani)"	[pos="e,2102.3,1001.5 1982.4,1040.9 2017.2,1029.5 2057,1016.4 2092.8,1004.6",
# 		weight=1.0];
# }
