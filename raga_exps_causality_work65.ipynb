# %%
import pandas as pd
import data
from utils import distances, draw, parallelizer
import numpy as np
import multiprocessing

# %%
df = pd.read_csv("/home/efm-workstation/notations/65/himadrisute-parsed.txt")
df_filtered1 = df[df[" Note"] < 99999]

df = pd.read_csv("/home/efm-workstation/notations/65/jalajakshi-parsed.txt")
df_filtered2 = df[df[" Note"] < 99999]

df = pd.read_csv("/home/efm-workstation/notations/65/kamalambam-parsed.txt")
df_filtered3 = df[df[" Note"] < 99999]

df = pd.read_csv("/home/efm-workstation/notations/65/nidhicala-parsed.txt")
df_filtered4 = df[df[" Note"] < 99999]

df = pd.read_csv("/home/efm-workstation/notations/65/pankajalocana-parsed.txt")
df_filtered5 = df[df[" Note"] < 99999]

df = pd.read_csv("/home/efm-workstation/notations/65/raghunayaka-parsed.txt")
df_filtered6 = df[df[" Note"] < 99999]

df = pd.read_csv("/home/efm-workstation/notations/65/sivakaameswari-parsed.txt")
df_filtered7 = df[df[" Note"] < 99999]

df = pd.read_csv("/home/efm-workstation/notations/65/sive-pahimam-parsed.txt")
df_filtered8 = df[df[" Note"] < 99999]

df = pd.read_csv("/home/efm-workstation/notations/65/vaarana-parsed.txt")
df_filtered9 = df[df[" Note"] < 99999]

df = pd.read_csv("/home/efm-workstation/notations/65/vatapi-parsed.txt")
df_filtered10 = df[df[" Note"] < 99999]

song_coords1 = []
for i in range(len(df_filtered1)):
    song_coords1.append((df_filtered1.iloc[i, 0], df_filtered1.iloc[i, 1], df_filtered1.iloc[i, 2]))


song_coords2 = []
for i in range(len(df_filtered2)):
    song_coords2.append((df_filtered2.iloc[i, 0], df_filtered2.iloc[i, 1], df_filtered2.iloc[i, 2]))


song_coords3 = []
for i in range(len(df_filtered3)):
    song_coords3.append((df_filtered3.iloc[i, 0], df_filtered3.iloc[i, 1], df_filtered3.iloc[i, 2]))


song_coords4 = []
for i in range(len(df_filtered4)):
    song_coords4.append((df_filtered4.iloc[i, 0], df_filtered4.iloc[i, 1], df_filtered4.iloc[i, 2]))


song_coords5 = []
for i in range(len(df_filtered5)):
    song_coords5.append((df_filtered5.iloc[i, 0], df_filtered5.iloc[i, 1], df_filtered5.iloc[i, 2]))


song_coords6 = []
for i in range(len(df_filtered6)):
    song_coords6.append((df_filtered6.iloc[i, 0], df_filtered6.iloc[i, 1], df_filtered6.iloc[i, 2]))


song_coords7 = []
for i in range(len(df_filtered7)):
    song_coords7.append((df_filtered7.iloc[i, 0], df_filtered7.iloc[i, 1], df_filtered7.iloc[i, 2]))


song_coords8 = []
for i in range(len(df_filtered8)):
    song_coords8.append((df_filtered8.iloc[i, 0], df_filtered8.iloc[i, 1], df_filtered8.iloc[i, 2]))

song_coords9 = []
for i in range(len(df_filtered9)):
    song_coords9.append((df_filtered9.iloc[i, 0], df_filtered9.iloc[i, 1], df_filtered9.iloc[i, 2]))

song_coords10 = []
for i in range(len(df_filtered10)):
    song_coords10.append((df_filtered10.iloc[i, 0], df_filtered10.iloc[i, 1], df_filtered10.iloc[i, 2]))

# %%
# def calc_metrics(all_coords):
#     dist_matrix = np.zeros((len(all_coords), len(all_coords)))
#     for i in range(len(all_coords)):
#         for j in range(len(all_coords)):
#             dist_matrix[i, j] = distances.dtwEuclidean(all_coords[i], all_coords[j], len(all_coords[i]), len(all_coords[j]))

    # return dist_matrix
lists = [song_coords1, song_coords2, song_coords3, song_coords4, song_coords5, song_coords6, song_coords7, song_coords8, song_coords9, song_coords10]

dists = parallelizer.list_parallelizer(distances.dtwEuclidean, lists)

# %%
labels = ["Himadri-Sute(Kalyani)", "Jalajakshi(Hamsadhwani)", "Kamalambam(Kalyani)", "nidhi-chala(Kalyani)", "Pankaja-lochana(kalyani)", "raghunaayaka(Hamsadhwani)", "sivakaameswari(Kalyani)", "Sive-Pahi Maam(Kalyani)", "vaarana mukha va(Hamsadhwani)", "vatapi-ganapathim(Hamsadhwani)"]

# draw.draw_weighted_graph(dists, 5000, labels)

from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt
def llf(id):
    return labels[id]
Z = linkage(dists, 'single')
fig = plt.figure()
dn = dendrogram(Z, leaf_label_func=llf, leaf_rotation=0, orientation='right')
# Out:
# <ipython-input-5-21aaae489685>:9: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   Z = linkage(dists, 'single')

# %%
song_coords1 = data.GetAdjustedMelody(song_coords1)
song_coords2 = data.GetAdjustedMelody(song_coords2)
song_coords3 = data.GetAdjustedMelody(song_coords3)
song_coords4 = data.GetAdjustedMelody(song_coords4)
song_coords5 = data.GetAdjustedMelody(song_coords5)
song_coords6 = data.GetAdjustedMelody(song_coords6)
song_coords7 = data.GetAdjustedMelody(song_coords7)
song_coords8 = data.GetAdjustedMelody(song_coords8)
song_coords9 = data.GetAdjustedMelody(song_coords9)
song_coords10 = data.GetAdjustedMelody(song_coords10)

# %%
print(len(song_coords1))
print(len(song_coords2))
print(len(song_coords3))
print(len(song_coords4))
print(len(song_coords5))
print(len(song_coords6))
print(len(song_coords7))
print(len(song_coords8))
print(len(song_coords9))
print(len(song_coords10))

np.mean([
    len(song_coords1),
    len(song_coords2),
    len(song_coords3),
    len(song_coords4),
    len(song_coords5),
    len(song_coords6),
    len(song_coords7),
    len(song_coords8),
    len(song_coords9),
    len(song_coords10),
])
# Out:
# 114980
# 212034
# 89140
# 271834
# 239046
# 156777
# 79104
# 107954
# 154627
# 84611
# 151010.7

# %%
lists = [song_coords1, song_coords2, song_coords3, song_coords4, song_coords5, song_coords6, song_coords7, song_coords8, song_coords9, song_coords10]

dists = parallelizer.list_parallelizer(distances.GetLZPCausality, lists)

# %%
XYTuples = []
for i in range(len(lists)):
    for j in range(len(lists)):
        XYTuples.append((i, j, lists[i], lists[j]))

distances.GetLZPCausalityParallel(XYTuples)
# Out:
# ....................................................................................................
# [{'index_pair': 0,
#   'index_x': 0,
#   'index_y': 0,
#   'length_x': 114980,
#   'length_y': 114980,
#   'ETC_x': 443,
#   'ETC_y': 443,
#   'ETC_x_given_Gy': 443,
#   'ETC_y_given_Gx': 443,
#   'length_x_residual': 1,
#   'length_y_residual': 1,
#   'ETC_x_residual': 0,
#   'ETC_y_residual': 0,
#   'ETC_x_residual_norm': 0,
#   'ETC_y_residual_norm': 0,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0,
#   'ETCE_y_to_x': 0,
#   'ETCE_strength': 0,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'n_or_m',
#   'ETCE_cause': 'n_or_m',
#   'LZ_x': 107,
#   'LZ_y': 107,
#   'LZ_xy': 108,
#   'LZ_yx': 108,
#   'LZ_concat_mean': 108.0,
#   'LZ_concat_diff': 0,
#   'LZP_x_to_y': 1,
#   'LZP_y_to_x': 1,
#   'LZP_strength': 0,
#   'LZP_threshold': 1,
#   'LZP_direction': 'n_or_m',
#   'LZP_cause': 'n_or_m',
#   'Consensus': True},
#  {'index_pair': 1,
#   'index_x': 0,
#   'index_y': 1,
#   'length_x': 114980,
#   'length_y': 212034,
#   'ETC_x': 443,
#   'ETC_y': 441,
#   'ETC_x_given_Gy': 67,
#   'ETC_y_given_Gx': 4,
#   'length_x_residual': 46189,
#   'length_y_residual': 154921,
#   'ETC_x_residual': 378,
#   'ETC_y_residual': 437,
#   'ETC_x_residual_norm': 0.00818394388152767,
#   'ETC_y_residual_norm': 0.0028208107410276273,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 2,
#   'ETCP_strength': 2,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'x_causes_y',
#   'ETCP_cause': 'x',
#   'ETCE_x_to_y': 0.0028208107410276273,
#   'ETCE_y_to_x': 0.00818394388152767,
#   'ETCE_strength': 0.005363133140500042,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'y_causes_x',
#   'ETCE_cause': 'y',
#   'LZ_x': 107,
#   'LZ_y': 162,
#   'LZ_xy': 259,
#   'LZ_yx': 253,
#   'LZ_concat_mean': 256.0,
#   'LZ_concat_diff': 6,
#   'LZP_x_to_y': 146,
#   'LZP_y_to_x': 97,
#   'LZP_strength': 49,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 2,
#   'index_x': 0,
#   'index_y': 2,
#   'length_x': 114980,
#   'length_y': 89140,
#   'ETC_x': 443,
#   'ETC_y': 788,
#   'ETC_x_given_Gy': 93,
#   'ETC_y_given_Gx': 96,
#   'length_x_residual': 2687,
#   'length_y_residual': 3457,
#   'ETC_x_residual': 350,
#   'ETC_y_residual': 692,
#   'ETC_x_residual_norm': 0.1303052866716307,
#   'ETC_y_residual_norm': 0.20023148148148148,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.20023148148148148,
#   'ETCE_y_to_x': 0.1303052866716307,
#   'ETCE_strength': 0.0699261948098508,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 107,
#   'LZ_y': 231,
#   'LZ_xy': 293,
#   'LZ_yx': 329,
#   'LZ_concat_mean': 311.0,
#   'LZ_concat_diff': 36,
#   'LZP_x_to_y': 222,
#   'LZP_y_to_x': 62,
#   'LZP_strength': 160,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 3,
#   'index_x': 0,
#   'index_y': 3,
#   'length_x': 114980,
#   'length_y': 271834,
#   'ETC_x': 443,
#   'ETC_y': 675,
#   'ETC_x_given_Gy': 134,
#   'ETC_y_given_Gx': 56,
#   'length_x_residual': 1612,
#   'length_y_residual': 16557,
#   'ETC_x_residual': 317,
#   'ETC_y_residual': 619,
#   'ETC_x_residual_norm': 0.196772191185599,
#   'ETC_y_residual_norm': 0.037388258033341386,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 8,
#   'ETCP_strength': 8,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'x_causes_y',
#   'ETCP_cause': 'x',
#   'ETCE_x_to_y': 0.037388258033341386,
#   'ETCE_y_to_x': 0.196772191185599,
#   'ETCE_strength': 0.1593839331522576,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'y_causes_x',
#   'ETCE_cause': 'y',
#   'LZ_x': 107,
#   'LZ_y': 204,
#   'LZ_xy': 288,
#   'LZ_yx': 279,
#   'LZ_concat_mean': 283.5,
#   'LZ_concat_diff': 9,
#   'LZP_x_to_y': 172,
#   'LZP_y_to_x': 84,
#   'LZP_strength': 88,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 4,
#   'index_x': 0,
#   'index_y': 4,
#   'length_x': 114980,
#   'length_y': 239046,
#   'ETC_x': 443,
#   'ETC_y': 565,
#   'ETC_x_given_Gy': 144,
#   'ETC_y_given_Gx': 153,
#   'length_x_residual': 860,
#   'length_y_residual': 1744,
#   'ETC_x_residual': 306,
#   'ETC_y_residual': 418,
#   'ETC_x_residual_norm': 0.3562281722933644,
#   'ETC_y_residual_norm': 0.23981640849110727,
#   'ETCP_x_to_y': 6,
#   'ETCP_y_to_x': 7,
#   'ETCP_strength': 1,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.23981640849110727,
#   'ETCE_y_to_x': 0.3562281722933644,
#   'ETCE_strength': 0.11641176380225712,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'y_causes_x',
#   'ETCE_cause': 'y',
#   'LZ_x': 107,
#   'LZ_y': 170,
#   'LZ_xy': 254,
#   'LZ_yx': 248,
#   'LZ_concat_mean': 251.0,
#   'LZ_concat_diff': 6,
#   'LZP_x_to_y': 141,
#   'LZP_y_to_x': 84,
#   'LZP_strength': 57,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 5,
#   'index_x': 0,
#   'index_y': 5,
#   'length_x': 114980,
#   'length_y': 156777,
#   'ETC_x': 443,
#   'ETC_y': 562,
#   'ETC_x_given_Gy': 114,
#   'ETC_y_given_Gx': 4,
#   'length_x_residual': 26465,
#   'length_y_residual': 107271,
#   'ETC_x_residual': 332,
#   'ETC_y_residual': 558,
#   'ETC_x_residual_norm': 0.0125453446191052,
#   'ETC_y_residual_norm': 0.0052018271650974175,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 3,
#   'ETCP_strength': 3,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'x_causes_y',
#   'ETCP_cause': 'x',
#   'ETCE_x_to_y': 0.0052018271650974175,
#   'ETCE_y_to_x': 0.0125453446191052,
#   'ETCE_strength': 0.007343517454007782,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'y_causes_x',
#   'ETCE_cause': 'y',
#   'LZ_x': 107,
#   'LZ_y': 152,
#   'LZ_xy': 242,
#   'LZ_yx': 245,
#   'LZ_concat_mean': 243.5,
#   'LZ_concat_diff': 3,
#   'LZP_x_to_y': 138,
#   'LZP_y_to_x': 90,
#   'LZP_strength': 48,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 6,
#   'index_x': 0,
#   'index_y': 6,
#   'length_x': 114980,
#   'length_y': 79104,
#   'ETC_x': 443,
#   'ETC_y': 792,
#   'ETC_x_given_Gy': 93,
#   'ETC_y_given_Gx': 96,
#   'length_x_residual': 3502,
#   'length_y_residual': 3780,
#   'ETC_x_residual': 350,
#   'ETC_y_residual': 698,
#   'ETC_x_residual_norm': 0.09997143673236218,
#   'ETC_y_residual_norm': 0.18470494839904736,
#   'ETCP_x_to_y': 2,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 2,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'y_causes_x',
#   'ETCP_cause': 'y',
#   'ETCE_x_to_y': 0.18470494839904736,
#   'ETCE_y_to_x': 0.09997143673236218,
#   'ETCE_strength': 0.08473351166668518,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 107,
#   'LZ_y': 239,
#   'LZ_xy': 308,
#   'LZ_yx': 342,
#   'LZ_concat_mean': 325.0,
#   'LZ_concat_diff': 34,
#   'LZP_x_to_y': 235,
#   'LZP_y_to_x': 69,
#   'LZP_strength': 166,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 7,
#   'index_x': 0,
#   'index_y': 7,
#   'length_x': 114980,
#   'length_y': 107954,
#   'ETC_x': 443,
#   'ETC_y': 877,
#   'ETC_x_given_Gy': 93,
#   'ETC_y_given_Gx': 96,
#   'length_x_residual': 5713,
#   'length_y_residual': 6327,
#   'ETC_x_residual': 350,
#   'ETC_y_residual': 781,
#   'ETC_x_residual_norm': 0.061274509803921566,
#   'ETC_y_residual_norm': 0.12345874170091685,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.12345874170091685,
#   'ETCE_y_to_x': 0.061274509803921566,
#   'ETCE_strength': 0.06218423189699528,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 107,
#   'LZ_y': 234,
#   'LZ_xy': 315,
#   'LZ_yx': 329,
#   'LZ_concat_mean': 322.0,
#   'LZ_concat_diff': 14,
#   'LZP_x_to_y': 222,
#   'LZP_y_to_x': 81,
#   'LZP_strength': 141,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 8,
#   'index_x': 0,
#   'index_y': 8,
#   'length_x': 114980,
#   'length_y': 154627,
#   'ETC_x': 443,
#   'ETC_y': 512,
#   'ETC_x_given_Gy': 70,
#   'ETC_y_given_Gx': 4,
#   'length_x_residual': 38107,
#   'length_y_residual': 107840,
#   'ETC_x_residual': 375,
#   'ETC_y_residual': 508,
#   'ETC_x_residual_norm': 0.009840969925995906,
#   'ETC_y_residual_norm': 0.004710726175131446,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 2,
#   'ETCP_strength': 2,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'x_causes_y',
#   'ETCP_cause': 'x',
#   'ETCE_x_to_y': 0.004710726175131446,
#   'ETCE_y_to_x': 0.009840969925995906,
#   'ETCE_strength': 0.0051302437508644605,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'y_causes_x',
#   'ETCE_cause': 'y',
#   'LZ_x': 107,
#   'LZ_y': 128,
#   'LZ_xy': 223,
#   'LZ_yx': 223,
#   'LZ_concat_mean': 223.0,
#   'LZ_concat_diff': 0,
#   'LZP_x_to_y': 116,
#   'LZP_y_to_x': 95,
#   'LZP_strength': 21,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 9,
#   'index_x': 0,
#   'index_y': 9,
#   'length_x': 114980,
#   'length_y': 84611,
#   'ETC_x': 443,
#   'ETC_y': 571,
#   'ETC_x_given_Gy': 66,
#   'ETC_y_given_Gx': 4,
#   'length_x_residual': 45449,
#   'length_y_residual': 60546,
#   'ETC_x_residual': 377,
#   'ETC_y_residual': 567,
#   'ETC_x_residual_norm': 0.008295194508009153,
#   'ETC_y_residual_norm': 0.009364935172185977,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.009364935172185977,
#   'ETCE_y_to_x': 0.008295194508009153,
#   'ETCE_strength': 0.0010697406641768242,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 107,
#   'LZ_y': 186,
#   'LZ_xy': 276,
#   'LZ_yx': 285,
#   'LZ_concat_mean': 280.5,
#   'LZ_concat_diff': 9,
#   'LZP_x_to_y': 178,
#   'LZP_y_to_x': 90,
#   'LZP_strength': 88,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 10,
#   'index_x': 1,
#   'index_y': 0,
#   'length_x': 212034,
#   'length_y': 114980,
#   'ETC_x': 441,
#   'ETC_y': 443,
#   'ETC_x_given_Gy': 4,
#   'ETC_y_given_Gx': 67,
#   'length_x_residual': 154921,
#   'length_y_residual': 46189,
#   'ETC_x_residual': 437,
#   'ETC_y_residual': 378,
#   'ETC_x_residual_norm': 0.0028208107410276273,
#   'ETC_y_residual_norm': 0.00818394388152767,
#   'ETCP_x_to_y': 2,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 2,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'y_causes_x',
#   'ETCP_cause': 'y',
#   'ETCE_x_to_y': 0.00818394388152767,
#   'ETCE_y_to_x': 0.0028208107410276273,
#   'ETCE_strength': 0.005363133140500042,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 162,
#   'LZ_y': 107,
#   'LZ_xy': 253,
#   'LZ_yx': 259,
#   'LZ_concat_mean': 256.0,
#   'LZ_concat_diff': 6,
#   'LZP_x_to_y': 97,
#   'LZP_y_to_x': 146,
#   'LZP_strength': 49,
#   'LZP_threshold': 1,
#   'LZP_direction': 'x_causes_y',
#   'LZP_cause': 'x',
#   'Consensus': False},
#  {'index_pair': 11,
#   'index_x': 1,
#   'index_y': 1,
#   'length_x': 212034,
#   'length_y': 212034,
#   'ETC_x': 441,
#   'ETC_y': 441,
#   'ETC_x_given_Gy': 441,
#   'ETC_y_given_Gx': 441,
#   'length_x_residual': 1,
#   'length_y_residual': 1,
#   'ETC_x_residual': 0,
#   'ETC_y_residual': 0,
#   'ETC_x_residual_norm': 0,
#   'ETC_y_residual_norm': 0,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0,
#   'ETCE_y_to_x': 0,
#   'ETCE_strength': 0,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'n_or_m',
#   'ETCE_cause': 'n_or_m',
#   'LZ_x': 162,
#   'LZ_y': 162,
#   'LZ_xy': 163,
#   'LZ_yx': 163,
#   'LZ_concat_mean': 163.0,
#   'LZ_concat_diff': 0,
#   'LZP_x_to_y': 1,
#   'LZP_y_to_x': 1,
#   'LZP_strength': 0,
#   'LZP_threshold': 1,
#   'LZP_direction': 'n_or_m',
#   'LZP_cause': 'n_or_m',
#   'Consensus': True},
#  {'index_pair': 12,
#   'index_x': 1,
#   'index_y': 2,
#   'length_x': 212034,
#   'length_y': 89140,
#   'ETC_x': 441,
#   'ETC_y': 788,
#   'ETC_x_given_Gy': 3,
#   'ETC_y_given_Gx': 5,
#   'length_x_residual': 168299,
#   'length_y_residual': 66401,
#   'ETC_x_residual': 438,
#   'ETC_y_residual': 783,
#   'ETC_x_residual_norm': 0.0026025264709028033,
#   'ETC_y_residual_norm': 0.011792168674698796,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.011792168674698796,
#   'ETCE_y_to_x': 0.0026025264709028033,
#   'ETCE_strength': 0.009189642203795992,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 162,
#   'LZ_y': 231,
#   'LZ_xy': 362,
#   'LZ_yx': 391,
#   'LZ_concat_mean': 376.5,
#   'LZ_concat_diff': 29,
#   'LZP_x_to_y': 229,
#   'LZP_y_to_x': 131,
#   'LZP_strength': 98,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 13,
#   'index_x': 1,
#   'index_y': 3,
#   'length_x': 212034,
#   'length_y': 271834,
#   'ETC_x': 441,
#   'ETC_y': 675,
#   'ETC_x_given_Gy': 4,
#   'ETC_y_given_Gx': 25,
#   'length_x_residual': 154921,
#   'length_y_residual': 138427,
#   'ETC_x_residual': 437,
#   'ETC_y_residual': 650,
#   'ETC_x_residual_norm': 0.0028208107410276273,
#   'ETC_y_residual_norm': 0.004695649661190817,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.004695649661190817,
#   'ETCE_y_to_x': 0.0028208107410276273,
#   'ETCE_strength': 0.0018748389201631898,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 162,
#   'LZ_y': 204,
#   'LZ_xy': 351,
#   'LZ_yx': 351,
#   'LZ_concat_mean': 351.0,
#   'LZ_concat_diff': 0,
#   'LZP_x_to_y': 189,
#   'LZP_y_to_x': 147,
#   'LZP_strength': 42,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 14,
#   'index_x': 1,
#   'index_y': 4,
#   'length_x': 212034,
#   'length_y': 239046,
#   'ETC_x': 441,
#   'ETC_y': 565,
#   'ETC_x_given_Gy': 3,
#   'ETC_y_given_Gx': 62,
#   'length_x_residual': 165155,
#   'length_y_residual': 86464,
#   'ETC_x_residual': 438,
#   'ETC_y_residual': 502,
#   'ETC_x_residual_norm': 0.002652070189035688,
#   'ETC_y_residual_norm': 0.005805951678752762,
#   'ETCP_x_to_y': -1,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 1,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.005805951678752762,
#   'ETCE_y_to_x': 0.002652070189035688,
#   'ETCE_strength': 0.0031538814897170736,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 162,
#   'LZ_y': 170,
#   'LZ_xy': 321,
#   'LZ_yx': 322,
#   'LZ_concat_mean': 321.5,
#   'LZ_concat_diff': 1,
#   'LZP_x_to_y': 160,
#   'LZP_y_to_x': 151,
#   'LZP_strength': 9,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 15,
#   'index_x': 1,
#   'index_y': 5,
#   'length_x': 212034,
#   'length_y': 156777,
#   'ETC_x': 441,
#   'ETC_y': 562,
#   'ETC_x_given_Gy': 4,
#   'ETC_y_given_Gx': 56,
#   'length_x_residual': 151833,
#   'length_y_residual': 37882,
#   'ETC_x_residual': 437,
#   'ETC_y_residual': 506,
#   'ETC_x_residual_norm': 0.002878181147584172,
#   'ETC_y_residual_norm': 0.013357619914996965,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.013357619914996965,
#   'ETCE_y_to_x': 0.002878181147584172,
#   'ETCE_strength': 0.010479438767412794,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 162,
#   'LZ_y': 152,
#   'LZ_xy': 284,
#   'LZ_yx': 301,
#   'LZ_concat_mean': 292.5,
#   'LZ_concat_diff': 17,
#   'LZP_x_to_y': 139,
#   'LZP_y_to_x': 132,
#   'LZP_strength': 7,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 16,
#   'index_x': 1,
#   'index_y': 6,
#   'length_x': 212034,
#   'length_y': 79104,
#   'ETC_x': 441,
#   'ETC_y': 792,
#   'ETC_x_given_Gy': 2,
#   'ETC_y_given_Gx': 68,
#   'length_x_residual': 191547,
#   'length_y_residual': 23699,
#   'ETC_x_residual': 439,
#   'ETC_y_residual': 726,
#   'ETC_x_residual_norm': 0.002291877669071659,
#   'ETC_y_residual_norm': 0.030635496666385348,
#   'ETCP_x_to_y': 2,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 2,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'y_causes_x',
#   'ETCP_cause': 'y',
#   'ETCE_x_to_y': 0.030635496666385348,
#   'ETCE_y_to_x': 0.002291877669071659,
#   'ETCE_strength': 0.028343618997313687,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 162,
#   'LZ_y': 239,
#   'LZ_xy': 370,
#   'LZ_yx': 399,
#   'LZ_concat_mean': 384.5,
#   'LZ_concat_diff': 29,
#   'LZP_x_to_y': 237,
#   'LZP_y_to_x': 131,
#   'LZP_strength': 106,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 17,
#   'index_x': 1,
#   'index_y': 7,
#   'length_x': 212034,
#   'length_y': 107954,
#   'ETC_x': 441,
#   'ETC_y': 877,
#   'ETC_x_given_Gy': 5,
#   'ETC_y_given_Gx': 98,
#   'length_x_residual': 148840,
#   'length_y_residual': 25210,
#   'ETC_x_residual': 436,
#   'ETC_y_residual': 779,
#   'ETC_x_residual_norm': 0.002929339756381056,
#   'ETC_y_residual_norm': 0.03090166210480384,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.03090166210480384,
#   'ETCE_y_to_x': 0.002929339756381056,
#   'ETCE_strength': 0.027972322348422785,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 162,
#   'LZ_y': 234,
#   'LZ_xy': 367,
#   'LZ_yx': 392,
#   'LZ_concat_mean': 379.5,
#   'LZ_concat_diff': 25,
#   'LZP_x_to_y': 230,
#   'LZP_y_to_x': 133,
#   'LZP_strength': 97,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 18,
#   'index_x': 1,
#   'index_y': 8,
#   'length_x': 212034,
#   'length_y': 154627,
#   'ETC_x': 441,
#   'ETC_y': 512,
#   'ETC_x_given_Gy': 3,
#   'ETC_y_given_Gx': 84,
#   'length_x_residual': 165155,
#   'length_y_residual': 16487,
#   'ETC_x_residual': 438,
#   'ETC_y_residual': 426,
#   'ETC_x_residual_norm': 0.002652070189035688,
#   'ETC_y_residual_norm': 0.025840106757248574,
#   'ETCP_x_to_y': -2,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 2,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'x_causes_y',
#   'ETCP_cause': 'x',
#   'ETCE_x_to_y': 0.025840106757248574,
#   'ETCE_y_to_x': 0.002652070189035688,
#   'ETCE_strength': 0.023188036568212885,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 162,
#   'LZ_y': 128,
#   'LZ_xy': 268,
#   'LZ_yx': 278,
#   'LZ_concat_mean': 273.0,
#   'LZ_concat_diff': 10,
#   'LZP_x_to_y': 116,
#   'LZP_y_to_x': 140,
#   'LZP_strength': 24,
#   'LZP_threshold': 1,
#   'LZP_direction': 'x_causes_y',
#   'LZP_cause': 'x',
#   'Consensus': True},
#  {'index_pair': 19,
#   'index_x': 1,
#   'index_y': 9,
#   'length_x': 212034,
#   'length_y': 84611,
#   'ETC_x': 441,
#   'ETC_y': 571,
#   'ETC_x_given_Gy': 4,
#   'ETC_y_given_Gx': 68,
#   'length_x_residual': 151833,
#   'length_y_residual': 11733,
#   'ETC_x_residual': 437,
#   'ETC_y_residual': 504,
#   'ETC_x_residual_norm': 0.002878181147584172,
#   'ETC_y_residual_norm': 0.04295942720763723,
#   'ETCP_x_to_y': 1,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 1,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.04295942720763723,
#   'ETCE_y_to_x': 0.002878181147584172,
#   'ETCE_strength': 0.040081246060053054,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 162,
#   'LZ_y': 186,
#   'LZ_xy': 321,
#   'LZ_yx': 346,
#   'LZ_concat_mean': 333.5,
#   'LZ_concat_diff': 25,
#   'LZP_x_to_y': 184,
#   'LZP_y_to_x': 135,
#   'LZP_strength': 49,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 20,
#   'index_x': 2,
#   'index_y': 0,
#   'length_x': 89140,
#   'length_y': 114980,
#   'ETC_x': 788,
#   'ETC_y': 443,
#   'ETC_x_given_Gy': 96,
#   'ETC_y_given_Gx': 93,
#   'length_x_residual': 3457,
#   'length_y_residual': 2687,
#   'ETC_x_residual': 692,
#   'ETC_y_residual': 350,
#   'ETC_x_residual_norm': 0.20023148148148148,
#   'ETC_y_residual_norm': 0.1303052866716307,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.1303052866716307,
#   'ETCE_y_to_x': 0.20023148148148148,
#   'ETCE_strength': 0.0699261948098508,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'y_causes_x',
#   'ETCE_cause': 'y',
#   'LZ_x': 231,
#   'LZ_y': 107,
#   'LZ_xy': 329,
#   'LZ_yx': 293,
#   'LZ_concat_mean': 311.0,
#   'LZ_concat_diff': 36,
#   'LZP_x_to_y': 62,
#   'LZP_y_to_x': 222,
#   'LZP_strength': 160,
#   'LZP_threshold': 1,
#   'LZP_direction': 'x_causes_y',
#   'LZP_cause': 'x',
#   'Consensus': False},
#  {'index_pair': 21,
#   'index_x': 2,
#   'index_y': 1,
#   'length_x': 89140,
#   'length_y': 212034,
#   'ETC_x': 788,
#   'ETC_y': 441,
#   'ETC_x_given_Gy': 5,
#   'ETC_y_given_Gx': 3,
#   'length_x_residual': 66401,
#   'length_y_residual': 168299,
#   'ETC_x_residual': 783,
#   'ETC_y_residual': 438,
#   'ETC_x_residual_norm': 0.011792168674698796,
#   'ETC_y_residual_norm': 0.0026025264709028033,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.0026025264709028033,
#   'ETCE_y_to_x': 0.011792168674698796,
#   'ETCE_strength': 0.009189642203795992,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'y_causes_x',
#   'ETCE_cause': 'y',
#   'LZ_x': 231,
#   'LZ_y': 162,
#   'LZ_xy': 391,
#   'LZ_yx': 362,
#   'LZ_concat_mean': 376.5,
#   'LZ_concat_diff': 29,
#   'LZP_x_to_y': 131,
#   'LZP_y_to_x': 229,
#   'LZP_strength': 98,
#   'LZP_threshold': 1,
#   'LZP_direction': 'x_causes_y',
#   'LZP_cause': 'x',
#   'Consensus': False},
#  {'index_pair': 22,
#   'index_x': 2,
#   'index_y': 2,
#   'length_x': 89140,
#   'length_y': 89140,
#   'ETC_x': 788,
#   'ETC_y': 788,
#   'ETC_x_given_Gy': 788,
#   'ETC_y_given_Gx': 788,
#   'length_x_residual': 1,
#   'length_y_residual': 1,
#   'ETC_x_residual': 0,
#   'ETC_y_residual': 0,
#   'ETC_x_residual_norm': 0,
#   'ETC_y_residual_norm': 0,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0,
#   'ETCE_y_to_x': 0,
#   'ETCE_strength': 0,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'n_or_m',
#   'ETCE_cause': 'n_or_m',
#   'LZ_x': 231,
#   'LZ_y': 231,
#   'LZ_xy': 232,
#   'LZ_yx': 232,
#   'LZ_concat_mean': 232.0,
#   'LZ_concat_diff': 0,
#   'LZP_x_to_y': 1,
#   'LZP_y_to_x': 1,
#   'LZP_strength': 0,
#   'LZP_threshold': 1,
#   'LZP_direction': 'n_or_m',
#   'LZP_cause': 'n_or_m',
#   'Consensus': True},
#  {'index_pair': 23,
#   'index_x': 2,
#   'index_y': 3,
#   'length_x': 89140,
#   'length_y': 271834,
#   'ETC_x': 788,
#   'ETC_y': 675,
#   'ETC_x_given_Gy': 93,
#   'ETC_y_given_Gx': 16,
#   'length_x_residual': 9306,
#   'length_y_residual': 118729,
#   'ETC_x_residual': 696,
#   'ETC_y_residual': 659,
#   'ETC_x_residual_norm': 0.07479849543256314,
#   'ETC_y_residual_norm': 0.005550501987736676,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 1,
#   'ETCP_strength': 1,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.005550501987736676,
#   'ETCE_y_to_x': 0.07479849543256314,
#   'ETCE_strength': 0.06924799344482648,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'y_causes_x',
#   'ETCE_cause': 'y',
#   'LZ_x': 231,
#   'LZ_y': 204,
#   'LZ_xy': 428,
#   'LZ_yx': 387,
#   'LZ_concat_mean': 407.5,
#   'LZ_concat_diff': 41,
#   'LZP_x_to_y': 156,
#   'LZP_y_to_x': 224,
#   'LZP_strength': 68,
#   'LZP_threshold': 1,
#   'LZP_direction': 'x_causes_y',
#   'LZP_cause': 'x',
#   'Consensus': False},
#  {'index_pair': 24,
#   'index_x': 2,
#   'index_y': 4,
#   'length_x': 89140,
#   'length_y': 239046,
#   'ETC_x': 788,
#   'ETC_y': 565,
#   'ETC_x_given_Gy': 94,
#   'ETC_y_given_Gx': 93,
#   'length_x_residual': 3659,
#   'length_y_residual': 5746,
#   'ETC_x_residual': 695,
#   'ETC_y_residual': 472,
#   'ETC_x_residual_norm': 0.18999453253143794,
#   'ETC_y_residual_norm': 0.08215839860748476,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 1,
#   'ETCP_strength': 1,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.08215839860748476,
#   'ETCE_y_to_x': 0.18999453253143794,
#   'ETCE_strength': 0.10783613392395318,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'y_causes_x',
#   'ETCE_cause': 'y',
#   'LZ_x': 231,
#   'LZ_y': 170,
#   'LZ_xy': 387,
#   'LZ_yx': 352,
#   'LZ_concat_mean': 369.5,
#   'LZ_concat_diff': 35,
#   'LZP_x_to_y': 121,
#   'LZP_y_to_x': 217,
#   'LZP_strength': 96,
#   'LZP_threshold': 1,
#   'LZP_direction': 'x_causes_y',
#   'LZP_cause': 'x',
#   'Consensus': False},
#  {'index_pair': 25,
#   'index_x': 2,
#   'index_y': 5,
#   'length_x': 89140,
#   'length_y': 156777,
#   'ETC_x': 788,
#   'ETC_y': 562,
#   'ETC_x_given_Gy': 65,
#   'ETC_y_given_Gx': 3,
#   'length_x_residual': 25004,
#   'length_y_residual': 120394,
#   'ETC_x_residual': 724,
#   'ETC_y_residual': 559,
#   'ETC_x_residual_norm': 0.028956525216973963,
#   'ETC_y_residual_norm': 0.004643127092106684,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 1,
#   'ETCP_strength': 1,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.004643127092106684,
#   'ETCE_y_to_x': 0.028956525216973963,
#   'ETCE_strength': 0.02431339812486728,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'y_causes_x',
#   'ETCE_cause': 'y',
#   'LZ_x': 231,
#   'LZ_y': 152,
#   'LZ_xy': 375,
#   'LZ_yx': 353,
#   'LZ_concat_mean': 364.0,
#   'LZ_concat_diff': 22,
#   'LZP_x_to_y': 122,
#   'LZP_y_to_x': 223,
#   'LZP_strength': 101,
#   'LZP_threshold': 1,
#   'LZP_direction': 'x_causes_y',
#   'LZP_cause': 'x',
#   'Consensus': False},
#  {'index_pair': 26,
#   'index_x': 2,
#   'index_y': 6,
#   'length_x': 89140,
#   'length_y': 79104,
#   'ETC_x': 788,
#   'ETC_y': 792,
#   'ETC_x_given_Gy': 90,
#   'ETC_y_given_Gx': 93,
#   'length_x_residual': 6077,
#   'length_y_residual': 3626,
#   'ETC_x_residual': 699,
#   'ETC_y_residual': 699,
#   'ETC_x_residual_norm': 0.11504279131007242,
#   'ETC_y_residual_norm': 0.19282758620689655,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 1,
#   'ETCP_strength': 1,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.19282758620689655,
#   'ETCE_y_to_x': 0.11504279131007242,
#   'ETCE_strength': 0.07778479489682413,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 231,
#   'LZ_y': 239,
#   'LZ_xy': 423,
#   'LZ_yx': 438,
#   'LZ_concat_mean': 430.5,
#   'LZ_concat_diff': 15,
#   'LZP_x_to_y': 207,
#   'LZP_y_to_x': 184,
#   'LZP_strength': 23,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 27,
#   'index_x': 2,
#   'index_y': 7,
#   'length_x': 89140,
#   'length_y': 107954,
#   'ETC_x': 788,
#   'ETC_y': 877,
#   'ETC_x_given_Gy': 82,
#   'ETC_y_given_Gx': 93,
#   'length_x_residual': 7086,
#   'length_y_residual': 5456,
#   'ETC_x_residual': 707,
#   'ETC_y_residual': 784,
#   'ETC_x_residual_norm': 0.09978828510938603,
#   'ETC_y_residual_norm': 0.14372135655362053,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 1,
#   'ETCP_strength': 1,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.14372135655362053,
#   'ETCE_y_to_x': 0.09978828510938603,
#   'ETCE_strength': 0.0439330714442345,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 231,
#   'LZ_y': 234,
#   'LZ_xy': 428,
#   'LZ_yx': 425,
#   'LZ_concat_mean': 426.5,
#   'LZ_concat_diff': 3,
#   'LZP_x_to_y': 194,
#   'LZP_y_to_x': 194,
#   'LZP_strength': 0,
#   'LZP_threshold': 1,
#   'LZP_direction': 'n_or_m',
#   'LZP_cause': 'n_or_m',
#   'Consensus': False},
#  {'index_pair': 28,
#   'index_x': 2,
#   'index_y': 8,
#   'length_x': 89140,
#   'length_y': 154627,
#   'ETC_x': 788,
#   'ETC_y': 512,
#   'ETC_x_given_Gy': 3,
#   'ETC_y_given_Gx': 3,
#   'length_x_residual': 75575,
#   'length_y_residual': 119330,
#   'ETC_x_residual': 785,
#   'ETC_y_residual': 509,
#   'ETC_x_residual_norm': 0.010387170190806361,
#   'ETC_y_residual_norm': 0.004265518021604136,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.004265518021604136,
#   'ETCE_y_to_x': 0.010387170190806361,
#   'ETCE_strength': 0.006121652169202225,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'y_causes_x',
#   'ETCE_cause': 'y',
#   'LZ_x': 231,
#   'LZ_y': 128,
#   'LZ_xy': 354,
#   'LZ_yx': 328,
#   'LZ_concat_mean': 341.0,
#   'LZ_concat_diff': 26,
#   'LZP_x_to_y': 97,
#   'LZP_y_to_x': 226,
#   'LZP_strength': 129,
#   'LZP_threshold': 1,
#   'LZP_direction': 'x_causes_y',
#   'LZP_cause': 'x',
#   'Consensus': False},
#  {'index_pair': 29,
#   'index_x': 2,
#   'index_y': 9,
#   'length_x': 89140,
#   'length_y': 84611,
#   'ETC_x': 788,
#   'ETC_y': 571,
#   'ETC_x_given_Gy': 61,
#   'ETC_y_given_Gx': 3,
#   'length_x_residual': 32449,
#   'length_y_residual': 66948,
#   'ETC_x_residual': 728,
#   'ETC_y_residual': 568,
#   'ETC_x_residual_norm': 0.022435897435897436,
#   'ETC_y_residual_norm': 0.00848432342001882,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 1,
#   'ETCP_strength': 1,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.00848432342001882,
#   'ETCE_y_to_x': 0.022435897435897436,
#   'ETCE_strength': 0.013951574015878616,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'y_causes_x',
#   'ETCE_cause': 'y',
#   'LZ_x': 231,
#   'LZ_y': 186,
#   'LZ_xy': 393,
#   'LZ_yx': 388,
#   'LZ_concat_mean': 390.5,
#   'LZ_concat_diff': 5,
#   'LZP_x_to_y': 157,
#   'LZP_y_to_x': 207,
#   'LZP_strength': 50,
#   'LZP_threshold': 1,
#   'LZP_direction': 'x_causes_y',
#   'LZP_cause': 'x',
#   'Consensus': False},
#  {'index_pair': 30,
#   'index_x': 3,
#   'index_y': 0,
#   'length_x': 271834,
#   'length_y': 114980,
#   'ETC_x': 675,
#   'ETC_y': 443,
#   'ETC_x_given_Gy': 56,
#   'ETC_y_given_Gx': 134,
#   'length_x_residual': 16557,
#   'length_y_residual': 1612,
#   'ETC_x_residual': 619,
#   'ETC_y_residual': 317,
#   'ETC_x_residual_norm': 0.037388258033341386,
#   'ETC_y_residual_norm': 0.196772191185599,
#   'ETCP_x_to_y': 8,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 8,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'y_causes_x',
#   'ETCP_cause': 'y',
#   'ETCE_x_to_y': 0.196772191185599,
#   'ETCE_y_to_x': 0.037388258033341386,
#   'ETCE_strength': 0.1593839331522576,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 204,
#   'LZ_y': 107,
#   'LZ_xy': 279,
#   'LZ_yx': 288,
#   'LZ_concat_mean': 283.5,
#   'LZ_concat_diff': 9,
#   'LZP_x_to_y': 84,
#   'LZP_y_to_x': 172,
#   'LZP_strength': 88,
#   'LZP_threshold': 1,
#   'LZP_direction': 'x_causes_y',
#   'LZP_cause': 'x',
#   'Consensus': False},
#  {'index_pair': 31,
#   'index_x': 3,
#   'index_y': 1,
#   'length_x': 271834,
#   'length_y': 212034,
#   'ETC_x': 675,
#   'ETC_y': 441,
#   'ETC_x_given_Gy': 25,
#   'ETC_y_given_Gx': 4,
#   'length_x_residual': 138427,
#   'length_y_residual': 154921,
#   'ETC_x_residual': 650,
#   'ETC_y_residual': 437,
#   'ETC_x_residual_norm': 0.004695649661190817,
#   'ETC_y_residual_norm': 0.0028208107410276273,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.0028208107410276273,
#   'ETCE_y_to_x': 0.004695649661190817,
#   'ETCE_strength': 0.0018748389201631898,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'y_causes_x',
#   'ETCE_cause': 'y',
#   'LZ_x': 204,
#   'LZ_y': 162,
#   'LZ_xy': 351,
#   'LZ_yx': 351,
#   'LZ_concat_mean': 351.0,
#   'LZ_concat_diff': 0,
#   'LZP_x_to_y': 147,
#   'LZP_y_to_x': 189,
#   'LZP_strength': 42,
#   'LZP_threshold': 1,
#   'LZP_direction': 'x_causes_y',
#   'LZP_cause': 'x',
#   'Consensus': False},
#  {'index_pair': 32,
#   'index_x': 3,
#   'index_y': 2,
#   'length_x': 271834,
#   'length_y': 89140,
#   'ETC_x': 675,
#   'ETC_y': 788,
#   'ETC_x_given_Gy': 16,
#   'ETC_y_given_Gx': 93,
#   'length_x_residual': 118729,
#   'length_y_residual': 9306,
#   'ETC_x_residual': 659,
#   'ETC_y_residual': 696,
#   'ETC_x_residual_norm': 0.005550501987736676,
#   'ETC_y_residual_norm': 0.07479849543256314,
#   'ETCP_x_to_y': 1,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 1,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.07479849543256314,
#   'ETCE_y_to_x': 0.005550501987736676,
#   'ETCE_strength': 0.06924799344482648,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 204,
#   'LZ_y': 231,
#   'LZ_xy': 387,
#   'LZ_yx': 428,
#   'LZ_concat_mean': 407.5,
#   'LZ_concat_diff': 41,
#   'LZP_x_to_y': 224,
#   'LZP_y_to_x': 156,
#   'LZP_strength': 68,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 33,
#   'index_x': 3,
#   'index_y': 3,
#   'length_x': 271834,
#   'length_y': 271834,
#   'ETC_x': 675,
#   'ETC_y': 675,
#   'ETC_x_given_Gy': 675,
#   'ETC_y_given_Gx': 675,
#   'length_x_residual': 1,
#   'length_y_residual': 1,
#   'ETC_x_residual': 0,
#   'ETC_y_residual': 0,
#   'ETC_x_residual_norm': 0,
#   'ETC_y_residual_norm': 0,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0,
#   'ETCE_y_to_x': 0,
#   'ETCE_strength': 0,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'n_or_m',
#   'ETCE_cause': 'n_or_m',
#   'LZ_x': 204,
#   'LZ_y': 204,
#   'LZ_xy': 205,
#   'LZ_yx': 205,
#   'LZ_concat_mean': 205.0,
#   'LZ_concat_diff': 0,
#   'LZP_x_to_y': 1,
#   'LZP_y_to_x': 1,
#   'LZP_strength': 0,
#   'LZP_threshold': 1,
#   'LZP_direction': 'n_or_m',
#   'LZP_cause': 'n_or_m',
#   'Consensus': True},
#  {'index_pair': 34,
#   'index_x': 3,
#   'index_y': 4,
#   'length_x': 271834,
#   'length_y': 239046,
#   'ETC_x': 675,
#   'ETC_y': 565,
#   'ETC_x_given_Gy': 51,
#   'ETC_y_given_Gx': 135,
#   'length_x_residual': 18521,
#   'length_y_residual': 4108,
#   'ETC_x_residual': 624,
#   'ETC_y_residual': 431,
#   'ETC_x_residual_norm': 0.033693304535637146,
#   'ETC_y_residual_norm': 0.1049427806184563,
#   'ETCP_x_to_y': 1,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 1,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.1049427806184563,
#   'ETCE_y_to_x': 0.033693304535637146,
#   'ETCE_strength': 0.07124947608281915,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 204,
#   'LZ_y': 170,
#   'LZ_xy': 342,
#   'LZ_yx': 333,
#   'LZ_concat_mean': 337.5,
#   'LZ_concat_diff': 9,
#   'LZP_x_to_y': 129,
#   'LZP_y_to_x': 172,
#   'LZP_strength': 43,
#   'LZP_threshold': 1,
#   'LZP_direction': 'x_causes_y',
#   'LZP_cause': 'x',
#   'Consensus': False},
#  {'index_pair': 35,
#   'index_x': 3,
#   'index_y': 5,
#   'length_x': 271834,
#   'length_y': 156777,
#   'ETC_x': 675,
#   'ETC_y': 562,
#   'ETC_x_given_Gy': 15,
#   'ETC_y_given_Gx': 4,
#   'length_x_residual': 129793,
#   'length_y_residual': 107271,
#   'ETC_x_residual': 660,
#   'ETC_y_residual': 558,
#   'ETC_x_residual_norm': 0.005085059171597633,
#   'ETC_y_residual_norm': 0.0052018271650974175,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.0052018271650974175,
#   'ETCE_y_to_x': 0.005085059171597633,
#   'ETCE_strength': 0.00011676799349978444,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 204,
#   'LZ_y': 152,
#   'LZ_xy': 331,
#   'LZ_yx': 340,
#   'LZ_concat_mean': 335.5,
#   'LZ_concat_diff': 9,
#   'LZP_x_to_y': 136,
#   'LZP_y_to_x': 179,
#   'LZP_strength': 43,
#   'LZP_threshold': 1,
#   'LZP_direction': 'x_causes_y',
#   'LZP_cause': 'x',
#   'Consensus': False},
#  {'index_pair': 36,
#   'index_x': 3,
#   'index_y': 6,
#   'length_x': 271834,
#   'length_y': 79104,
#   'ETC_x': 675,
#   'ETC_y': 792,
#   'ETC_x_given_Gy': 46,
#   'ETC_y_given_Gx': 93,
#   'length_x_residual': 44130,
#   'length_y_residual': 3700,
#   'ETC_x_residual': 629,
#   'ETC_y_residual': 699,
#   'ETC_x_residual_norm': 0.01425366539010628,
#   'ETC_y_residual_norm': 0.18896999188969993,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.18896999188969993,
#   'ETCE_y_to_x': 0.01425366539010628,
#   'ETCE_strength': 0.17471632649959365,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 204,
#   'LZ_y': 239,
#   'LZ_xy': 393,
#   'LZ_yx': 440,
#   'LZ_concat_mean': 416.5,
#   'LZ_concat_diff': 47,
#   'LZP_x_to_y': 236,
#   'LZP_y_to_x': 154,
#   'LZP_strength': 82,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 37,
#   'index_x': 3,
#   'index_y': 7,
#   'length_x': 271834,
#   'length_y': 107954,
#   'ETC_x': 675,
#   'ETC_y': 877,
#   'ETC_x_given_Gy': 21,
#   'ETC_y_given_Gx': 93,
#   'length_x_residual': 96937,
#   'length_y_residual': 10621,
#   'ETC_x_residual': 654,
#   'ETC_y_residual': 784,
#   'ETC_x_residual_norm': 0.006746719485021045,
#   'ETC_y_residual_norm': 0.07382297551789077,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.07382297551789077,
#   'ETCE_y_to_x': 0.006746719485021045,
#   'ETCE_strength': 0.06707625603286972,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 204,
#   'LZ_y': 234,
#   'LZ_xy': 398,
#   'LZ_yx': 428,
#   'LZ_concat_mean': 413.0,
#   'LZ_concat_diff': 30,
#   'LZP_x_to_y': 224,
#   'LZP_y_to_x': 164,
#   'LZP_strength': 60,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 38,
#   'index_x': 3,
#   'index_y': 8,
#   'length_x': 271834,
#   'length_y': 154627,
#   'ETC_x': 675,
#   'ETC_y': 512,
#   'ETC_x_given_Gy': 11,
#   'ETC_y_given_Gx': 4,
#   'length_x_residual': 152057,
#   'length_y_residual': 107840,
#   'ETC_x_residual': 664,
#   'ETC_y_residual': 508,
#   'ETC_x_residual_norm': 0.004366812227074236,
#   'ETC_y_residual_norm': 0.004710726175131446,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.004710726175131446,
#   'ETCE_y_to_x': 0.004366812227074236,
#   'ETCE_strength': 0.00034391394805721037,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 204,
#   'LZ_y': 128,
#   'LZ_xy': 314,
#   'LZ_yx': 318,
#   'LZ_concat_mean': 316.0,
#   'LZ_concat_diff': 4,
#   'LZP_x_to_y': 114,
#   'LZP_y_to_x': 186,
#   'LZP_strength': 72,
#   'LZP_threshold': 1,
#   'LZP_direction': 'x_causes_y',
#   'LZP_cause': 'x',
#   'Consensus': False},
#  {'index_pair': 39,
#   'index_x': 3,
#   'index_y': 9,
#   'length_x': 271834,
#   'length_y': 84611,
#   'ETC_x': 675,
#   'ETC_y': 571,
#   'ETC_x_given_Gy': 5,
#   'ETC_y_given_Gx': 4,
#   'length_x_residual': 199312,
#   'length_y_residual': 60546,
#   'ETC_x_residual': 670,
#   'ETC_y_residual': 567,
#   'ETC_x_residual_norm': 0.003361580645323138,
#   'ETC_y_residual_norm': 0.009364935172185977,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.009364935172185977,
#   'ETCE_y_to_x': 0.003361580645323138,
#   'ETCE_strength': 0.006003354526862839,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 204,
#   'LZ_y': 186,
#   'LZ_xy': 367,
#   'LZ_yx': 386,
#   'LZ_concat_mean': 376.5,
#   'LZ_concat_diff': 19,
#   'LZP_x_to_y': 182,
#   'LZP_y_to_x': 181,
#   'LZP_strength': 1,
#   'LZP_threshold': 1,
#   'LZP_direction': 'n_or_m',
#   'LZP_cause': 'n_or_m',
#   'Consensus': False},
#  {'index_pair': 40,
#   'index_x': 4,
#   'index_y': 0,
#   'length_x': 239046,
#   'length_y': 114980,
#   'ETC_x': 565,
#   'ETC_y': 443,
#   'ETC_x_given_Gy': 153,
#   'ETC_y_given_Gx': 144,
#   'length_x_residual': 1744,
#   'length_y_residual': 860,
#   'ETC_x_residual': 418,
#   'ETC_y_residual': 306,
#   'ETC_x_residual_norm': 0.23981640849110727,
#   'ETC_y_residual_norm': 0.3562281722933644,
#   'ETCP_x_to_y': 7,
#   'ETCP_y_to_x': 6,
#   'ETCP_strength': 1,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.3562281722933644,
#   'ETCE_y_to_x': 0.23981640849110727,
#   'ETCE_strength': 0.11641176380225712,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 170,
#   'LZ_y': 107,
#   'LZ_xy': 248,
#   'LZ_yx': 254,
#   'LZ_concat_mean': 251.0,
#   'LZ_concat_diff': 6,
#   'LZP_x_to_y': 84,
#   'LZP_y_to_x': 141,
#   'LZP_strength': 57,
#   'LZP_threshold': 1,
#   'LZP_direction': 'x_causes_y',
#   'LZP_cause': 'x',
#   'Consensus': False},
#  {'index_pair': 41,
#   'index_x': 4,
#   'index_y': 1,
#   'length_x': 239046,
#   'length_y': 212034,
#   'ETC_x': 565,
#   'ETC_y': 441,
#   'ETC_x_given_Gy': 62,
#   'ETC_y_given_Gx': 3,
#   'length_x_residual': 86464,
#   'length_y_residual': 165155,
#   'ETC_x_residual': 502,
#   'ETC_y_residual': 438,
#   'ETC_x_residual_norm': 0.005805951678752762,
#   'ETC_y_residual_norm': 0.002652070189035688,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': -1,
#   'ETCP_strength': 1,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.002652070189035688,
#   'ETCE_y_to_x': 0.005805951678752762,
#   'ETCE_strength': 0.0031538814897170736,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'y_causes_x',
#   'ETCE_cause': 'y',
#   'LZ_x': 170,
#   'LZ_y': 162,
#   'LZ_xy': 322,
#   'LZ_yx': 321,
#   'LZ_concat_mean': 321.5,
#   'LZ_concat_diff': 1,
#   'LZP_x_to_y': 151,
#   'LZP_y_to_x': 160,
#   'LZP_strength': 9,
#   'LZP_threshold': 1,
#   'LZP_direction': 'x_causes_y',
#   'LZP_cause': 'x',
#   'Consensus': False},
#  {'index_pair': 42,
#   'index_x': 4,
#   'index_y': 2,
#   'length_x': 239046,
#   'length_y': 89140,
#   'ETC_x': 565,
#   'ETC_y': 788,
#   'ETC_x_given_Gy': 93,
#   'ETC_y_given_Gx': 94,
#   'length_x_residual': 5746,
#   'length_y_residual': 3659,
#   'ETC_x_residual': 472,
#   'ETC_y_residual': 695,
#   'ETC_x_residual_norm': 0.08215839860748476,
#   'ETC_y_residual_norm': 0.18999453253143794,
#   'ETCP_x_to_y': 1,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 1,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.18999453253143794,
#   'ETCE_y_to_x': 0.08215839860748476,
#   'ETCE_strength': 0.10783613392395318,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 170,
#   'LZ_y': 231,
#   'LZ_xy': 352,
#   'LZ_yx': 387,
#   'LZ_concat_mean': 369.5,
#   'LZ_concat_diff': 35,
#   'LZP_x_to_y': 217,
#   'LZP_y_to_x': 121,
#   'LZP_strength': 96,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 43,
#   'index_x': 4,
#   'index_y': 3,
#   'length_x': 239046,
#   'length_y': 271834,
#   'ETC_x': 565,
#   'ETC_y': 675,
#   'ETC_x_given_Gy': 135,
#   'ETC_y_given_Gx': 51,
#   'length_x_residual': 4108,
#   'length_y_residual': 18521,
#   'ETC_x_residual': 431,
#   'ETC_y_residual': 624,
#   'ETC_x_residual_norm': 0.1049427806184563,
#   'ETC_y_residual_norm': 0.033693304535637146,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 1,
#   'ETCP_strength': 1,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.033693304535637146,
#   'ETCE_y_to_x': 0.1049427806184563,
#   'ETCE_strength': 0.07124947608281915,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'y_causes_x',
#   'ETCE_cause': 'y',
#   'LZ_x': 170,
#   'LZ_y': 204,
#   'LZ_xy': 333,
#   'LZ_yx': 342,
#   'LZ_concat_mean': 337.5,
#   'LZ_concat_diff': 9,
#   'LZP_x_to_y': 172,
#   'LZP_y_to_x': 129,
#   'LZP_strength': 43,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 44,
#   'index_x': 4,
#   'index_y': 4,
#   'length_x': 239046,
#   'length_y': 239046,
#   'ETC_x': 565,
#   'ETC_y': 565,
#   'ETC_x_given_Gy': 565,
#   'ETC_y_given_Gx': 565,
#   'length_x_residual': 1,
#   'length_y_residual': 1,
#   'ETC_x_residual': 0,
#   'ETC_y_residual': 0,
#   'ETC_x_residual_norm': 0,
#   'ETC_y_residual_norm': 0,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0,
#   'ETCE_y_to_x': 0,
#   'ETCE_strength': 0,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'n_or_m',
#   'ETCE_cause': 'n_or_m',
#   'LZ_x': 170,
#   'LZ_y': 170,
#   'LZ_xy': 171,
#   'LZ_yx': 171,
#   'LZ_concat_mean': 171.0,
#   'LZ_concat_diff': 0,
#   'LZP_x_to_y': 1,
#   'LZP_y_to_x': 1,
#   'LZP_strength': 0,
#   'LZP_threshold': 1,
#   'LZP_direction': 'n_or_m',
#   'LZP_cause': 'n_or_m',
#   'Consensus': True},
#  {'index_pair': 45,
#   'index_x': 4,
#   'index_y': 5,
#   'length_x': 239046,
#   'length_y': 156777,
#   'ETC_x': 565,
#   'ETC_y': 562,
#   'ETC_x_given_Gy': 114,
#   'ETC_y_given_Gx': 3,
#   'length_x_residual': 50698,
#   'length_y_residual': 113670,
#   'ETC_x_residual': 449,
#   'ETC_y_residual': 559,
#   'ETC_x_residual_norm': 0.008856539834704222,
#   'ETC_y_residual_norm': 0.004917787611398007,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': -2,
#   'ETCP_strength': 2,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'y_causes_x',
#   'ETCP_cause': 'y',
#   'ETCE_x_to_y': 0.004917787611398007,
#   'ETCE_y_to_x': 0.008856539834704222,
#   'ETCE_strength': 0.003938752223306216,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'y_causes_x',
#   'ETCE_cause': 'y',
#   'LZ_x': 170,
#   'LZ_y': 152,
#   'LZ_xy': 300,
#   'LZ_yx': 306,
#   'LZ_concat_mean': 303.0,
#   'LZ_concat_diff': 6,
#   'LZP_x_to_y': 136,
#   'LZP_y_to_x': 148,
#   'LZP_strength': 12,
#   'LZP_threshold': 1,
#   'LZP_direction': 'x_causes_y',
#   'LZP_cause': 'x',
#   'Consensus': False},
#  {'index_pair': 46,
#   'index_x': 4,
#   'index_y': 6,
#   'length_x': 239046,
#   'length_y': 79104,
#   'ETC_x': 565,
#   'ETC_y': 792,
#   'ETC_x_given_Gy': 95,
#   'ETC_y_given_Gx': 97,
#   'length_x_residual': 8289,
#   'length_y_residual': 3492,
#   'ETC_x_residual': 471,
#   'ETC_y_residual': 697,
#   'ETC_x_residual_norm': 0.05682915057915058,
#   'ETC_y_residual_norm': 0.1996562589515898,
#   'ETCP_x_to_y': 2,
#   'ETCP_y_to_x': 1,
#   'ETCP_strength': 1,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.1996562589515898,
#   'ETCE_y_to_x': 0.05682915057915058,
#   'ETCE_strength': 0.14282710837243923,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 170,
#   'LZ_y': 239,
#   'LZ_xy': 364,
#   'LZ_yx': 405,
#   'LZ_concat_mean': 384.5,
#   'LZ_concat_diff': 41,
#   'LZP_x_to_y': 235,
#   'LZP_y_to_x': 125,
#   'LZP_strength': 110,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 47,
#   'index_x': 4,
#   'index_y': 7,
#   'length_x': 239046,
#   'length_y': 107954,
#   'ETC_x': 565,
#   'ETC_y': 877,
#   'ETC_x_given_Gy': 103,
#   'ETC_y_given_Gx': 97,
#   'length_x_residual': 8891,
#   'length_y_residual': 5939,
#   'ETC_x_residual': 462,
#   'ETC_y_residual': 780,
#   'ETC_x_residual_norm': 0.05196850393700787,
#   'ETC_y_residual_norm': 0.13135735938026272,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.13135735938026272,
#   'ETCE_y_to_x': 0.05196850393700787,
#   'ETCE_strength': 0.07938885544325484,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 170,
#   'LZ_y': 234,
#   'LZ_xy': 367,
#   'LZ_yx': 397,
#   'LZ_concat_mean': 382.0,
#   'LZ_concat_diff': 30,
#   'LZP_x_to_y': 227,
#   'LZP_y_to_x': 133,
#   'LZP_strength': 94,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 48,
#   'index_x': 4,
#   'index_y': 8,
#   'length_x': 239046,
#   'length_y': 154627,
#   'ETC_x': 565,
#   'ETC_y': 512,
#   'ETC_x_given_Gy': 77,
#   'ETC_y_given_Gx': 3,
#   'length_x_residual': 75985,
#   'length_y_residual': 114154,
#   'ETC_x_residual': 488,
#   'ETC_y_residual': 509,
#   'ETC_x_residual_norm': 0.00642240471678248,
#   'ETC_y_residual_norm': 0.0044589279300587805,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.0044589279300587805,
#   'ETCE_y_to_x': 0.00642240471678248,
#   'ETCE_strength': 0.0019634767867236997,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'y_causes_x',
#   'ETCE_cause': 'y',
#   'LZ_x': 170,
#   'LZ_y': 128,
#   'LZ_xy': 284,
#   'LZ_yx': 286,
#   'LZ_concat_mean': 285.0,
#   'LZ_concat_diff': 2,
#   'LZP_x_to_y': 116,
#   'LZP_y_to_x': 156,
#   'LZP_strength': 40,
#   'LZP_threshold': 1,
#   'LZP_direction': 'x_causes_y',
#   'LZP_cause': 'x',
# ...
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'y_causes_x',
#   'ETCE_cause': 'y',
#   'LZ_x': 128,
#   'LZ_y': 204,
#   'LZ_xy': 318,
#   'LZ_yx': 314,
#   'LZ_concat_mean': 316.0,
#   'LZ_concat_diff': 4,
#   'LZP_x_to_y': 186,
#   'LZP_y_to_x': 114,
#   'LZP_strength': 72,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 84,
#   'index_x': 8,
#   'index_y': 4,
#   'length_x': 154627,
#   'length_y': 239046,
#   'ETC_x': 512,
#   'ETC_y': 565,
#   'ETC_x_given_Gy': 3,
#   'ETC_y_given_Gx': 77,
#   'length_x_residual': 114154,
#   'length_y_residual': 75985,
#   'ETC_x_residual': 509,
#   'ETC_y_residual': 488,
#   'ETC_x_residual_norm': 0.0044589279300587805,
#   'ETC_y_residual_norm': 0.00642240471678248,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.00642240471678248,
#   'ETCE_y_to_x': 0.0044589279300587805,
#   'ETCE_strength': 0.0019634767867236997,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 128,
#   'LZ_y': 170,
#   'LZ_xy': 286,
#   'LZ_yx': 284,
#   'LZ_concat_mean': 285.0,
#   'LZ_concat_diff': 2,
#   'LZP_x_to_y': 156,
#   'LZP_y_to_x': 116,
#   'LZP_strength': 40,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 85,
#   'index_x': 8,
#   'index_y': 5,
#   'length_x': 154627,
#   'length_y': 156777,
#   'ETC_x': 512,
#   'ETC_y': 562,
#   'ETC_x_given_Gy': 4,
#   'ETC_y_given_Gx': 70,
#   'length_x_residual': 108950,
#   'length_y_residual': 24821,
#   'ETC_x_residual': 508,
#   'ETC_y_residual': 492,
#   'ETC_x_residual_norm': 0.0046627321040119685,
#   'ETC_y_residual_norm': 0.019822723609991943,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.019822723609991943,
#   'ETCE_y_to_x': 0.0046627321040119685,
#   'ETCE_strength': 0.015159991505979974,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 128,
#   'LZ_y': 152,
#   'LZ_xy': 252,
#   'LZ_yx': 255,
#   'LZ_concat_mean': 253.5,
#   'LZ_concat_diff': 3,
#   'LZP_x_to_y': 127,
#   'LZP_y_to_x': 100,
#   'LZP_strength': 27,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 86,
#   'index_x': 8,
#   'index_y': 6,
#   'length_x': 154627,
#   'length_y': 79104,
#   'ETC_x': 512,
#   'ETC_y': 792,
#   'ETC_x_given_Gy': 2,
#   'ETC_y_given_Gx': 95,
#   'length_x_residual': 130938,
#   'length_y_residual': 20320,
#   'ETC_x_residual': 510,
#   'ETC_y_residual': 705,
#   'ETC_x_residual_norm': 0.003895002940345357,
#   'ETC_y_residual_norm': 0.0346965893990846,
#   'ETCP_x_to_y': 8,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 8,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'y_causes_x',
#   'ETCP_cause': 'y',
#   'ETCE_x_to_y': 0.0346965893990846,
#   'ETCE_y_to_x': 0.003895002940345357,
#   'ETCE_strength': 0.03080158645873924,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 128,
#   'LZ_y': 239,
#   'LZ_xy': 341,
#   'LZ_yx': 365,
#   'LZ_concat_mean': 353.0,
#   'LZ_concat_diff': 24,
#   'LZP_x_to_y': 237,
#   'LZP_y_to_x': 102,
#   'LZP_strength': 135,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 87,
#   'index_x': 8,
#   'index_y': 7,
#   'length_x': 154627,
#   'length_y': 107954,
#   'ETC_x': 512,
#   'ETC_y': 877,
#   'ETC_x_given_Gy': 5,
#   'ETC_y_given_Gx': 77,
#   'length_x_residual': 106803,
#   'length_y_residual': 26206,
#   'ETC_x_residual': 507,
#   'ETC_y_residual': 800,
#   'ETC_x_residual_norm': 0.0047471021141926185,
#   'ETC_y_residual_norm': 0.03052852509063156,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.03052852509063156,
#   'ETCE_y_to_x': 0.0047471021141926185,
#   'ETCE_strength': 0.025781422976438942,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 128,
#   'LZ_y': 234,
#   'LZ_xy': 337,
#   'LZ_yx': 358,
#   'LZ_concat_mean': 347.5,
#   'LZ_concat_diff': 21,
#   'LZP_x_to_y': 230,
#   'LZP_y_to_x': 103,
#   'LZP_strength': 127,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 88,
#   'index_x': 8,
#   'index_y': 8,
#   'length_x': 154627,
#   'length_y': 154627,
#   'ETC_x': 512,
#   'ETC_y': 512,
#   'ETC_x_given_Gy': 512,
#   'ETC_y_given_Gx': 512,
#   'length_x_residual': 1,
#   'length_y_residual': 1,
#   'ETC_x_residual': 0,
#   'ETC_y_residual': 0,
#   'ETC_x_residual_norm': 0,
#   'ETC_y_residual_norm': 0,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0,
#   'ETCE_y_to_x': 0,
#   'ETCE_strength': 0,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'n_or_m',
#   'ETCE_cause': 'n_or_m',
#   'LZ_x': 128,
#   'LZ_y': 128,
#   'LZ_xy': 129,
#   'LZ_yx': 129,
#   'LZ_concat_mean': 129.0,
#   'LZ_concat_diff': 0,
#   'LZP_x_to_y': 1,
#   'LZP_y_to_x': 1,
#   'LZP_strength': 0,
#   'LZP_threshold': 1,
#   'LZP_direction': 'n_or_m',
#   'LZP_cause': 'n_or_m',
#   'Consensus': True},
#  {'index_pair': 89,
#   'index_x': 8,
#   'index_y': 9,
#   'length_x': 154627,
#   'length_y': 84611,
#   'ETC_x': 512,
#   'ETC_y': 571,
#   'ETC_x_given_Gy': 84,
#   'ETC_y_given_Gx': 105,
#   'length_x_residual': 2720,
#   'length_y_residual': 1594,
#   'ETC_x_residual': 422,
#   'ETC_y_residual': 468,
#   'ETC_x_residual_norm': 0.1552041191614564,
#   'ETC_y_residual_norm': 0.2937853107344633,
#   'ETCP_x_to_y': 2,
#   'ETCP_y_to_x': -6,
#   'ETCP_strength': 8,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'y_causes_x',
#   'ETCP_cause': 'y',
#   'ETCE_x_to_y': 0.2937853107344633,
#   'ETCE_y_to_x': 0.1552041191614564,
#   'ETCE_strength': 0.13858119157300688,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 128,
#   'LZ_y': 186,
#   'LZ_xy': 282,
#   'LZ_yx': 301,
#   'LZ_concat_mean': 291.5,
#   'LZ_concat_diff': 19,
#   'LZP_x_to_y': 173,
#   'LZP_y_to_x': 96,
#   'LZP_strength': 77,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 90,
#   'index_x': 9,
#   'index_y': 0,
#   'length_x': 84611,
#   'length_y': 114980,
#   'ETC_x': 571,
#   'ETC_y': 443,
#   'ETC_x_given_Gy': 4,
#   'ETC_y_given_Gx': 66,
#   'length_x_residual': 60546,
#   'length_y_residual': 45449,
#   'ETC_x_residual': 567,
#   'ETC_y_residual': 377,
#   'ETC_x_residual_norm': 0.009364935172185977,
#   'ETC_y_residual_norm': 0.008295194508009153,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.008295194508009153,
#   'ETCE_y_to_x': 0.009364935172185977,
#   'ETCE_strength': 0.0010697406641768242,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'y_causes_x',
#   'ETCE_cause': 'y',
#   'LZ_x': 186,
#   'LZ_y': 107,
#   'LZ_xy': 285,
#   'LZ_yx': 276,
#   'LZ_concat_mean': 280.5,
#   'LZ_concat_diff': 9,
#   'LZP_x_to_y': 90,
#   'LZP_y_to_x': 178,
#   'LZP_strength': 88,
#   'LZP_threshold': 1,
#   'LZP_direction': 'x_causes_y',
#   'LZP_cause': 'x',
#   'Consensus': False},
#  {'index_pair': 91,
#   'index_x': 9,
#   'index_y': 1,
#   'length_x': 84611,
#   'length_y': 212034,
#   'ETC_x': 571,
#   'ETC_y': 441,
#   'ETC_x_given_Gy': 68,
#   'ETC_y_given_Gx': 4,
#   'length_x_residual': 11733,
#   'length_y_residual': 151833,
#   'ETC_x_residual': 504,
#   'ETC_y_residual': 437,
#   'ETC_x_residual_norm': 0.04295942720763723,
#   'ETC_y_residual_norm': 0.002878181147584172,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 1,
#   'ETCP_strength': 1,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.002878181147584172,
#   'ETCE_y_to_x': 0.04295942720763723,
#   'ETCE_strength': 0.040081246060053054,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'y_causes_x',
#   'ETCE_cause': 'y',
#   'LZ_x': 186,
#   'LZ_y': 162,
#   'LZ_xy': 346,
#   'LZ_yx': 321,
#   'LZ_concat_mean': 333.5,
#   'LZ_concat_diff': 25,
#   'LZP_x_to_y': 135,
#   'LZP_y_to_x': 184,
#   'LZP_strength': 49,
#   'LZP_threshold': 1,
#   'LZP_direction': 'x_causes_y',
#   'LZP_cause': 'x',
#   'Consensus': False},
#  {'index_pair': 92,
#   'index_x': 9,
#   'index_y': 2,
#   'length_x': 84611,
#   'length_y': 89140,
#   'ETC_x': 571,
#   'ETC_y': 788,
#   'ETC_x_given_Gy': 3,
#   'ETC_y_given_Gx': 61,
#   'length_x_residual': 66948,
#   'length_y_residual': 32449,
#   'ETC_x_residual': 568,
#   'ETC_y_residual': 728,
#   'ETC_x_residual_norm': 0.00848432342001882,
#   'ETC_y_residual_norm': 0.022435897435897436,
#   'ETCP_x_to_y': 1,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 1,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.022435897435897436,
#   'ETCE_y_to_x': 0.00848432342001882,
#   'ETCE_strength': 0.013951574015878616,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 186,
#   'LZ_y': 231,
#   'LZ_xy': 388,
#   'LZ_yx': 393,
#   'LZ_concat_mean': 390.5,
#   'LZ_concat_diff': 5,
#   'LZP_x_to_y': 207,
#   'LZP_y_to_x': 157,
#   'LZP_strength': 50,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 93,
#   'index_x': 9,
#   'index_y': 3,
#   'length_x': 84611,
#   'length_y': 271834,
#   'ETC_x': 571,
#   'ETC_y': 675,
#   'ETC_x_given_Gy': 4,
#   'ETC_y_given_Gx': 5,
#   'length_x_residual': 60546,
#   'length_y_residual': 199312,
#   'ETC_x_residual': 567,
#   'ETC_y_residual': 670,
#   'ETC_x_residual_norm': 0.009364935172185977,
#   'ETC_y_residual_norm': 0.003361580645323138,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.003361580645323138,
#   'ETCE_y_to_x': 0.009364935172185977,
#   'ETCE_strength': 0.006003354526862839,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'y_causes_x',
#   'ETCE_cause': 'y',
#   'LZ_x': 186,
#   'LZ_y': 204,
#   'LZ_xy': 386,
#   'LZ_yx': 367,
#   'LZ_concat_mean': 376.5,
#   'LZ_concat_diff': 19,
#   'LZP_x_to_y': 181,
#   'LZP_y_to_x': 182,
#   'LZP_strength': 1,
#   'LZP_threshold': 1,
#   'LZP_direction': 'n_or_m',
#   'LZP_cause': 'n_or_m',
#   'Consensus': False},
#  {'index_pair': 94,
#   'index_x': 9,
#   'index_y': 4,
#   'length_x': 84611,
#   'length_y': 239046,
#   'ETC_x': 571,
#   'ETC_y': 565,
#   'ETC_x_given_Gy': 3,
#   'ETC_y_given_Gx': 66,
#   'length_x_residual': 63971,
#   'length_y_residual': 84959,
#   'ETC_x_residual': 568,
#   'ETC_y_residual': 500,
#   'ETC_x_residual_norm': 0.008879162107237768,
#   'ETC_y_residual_norm': 0.0058852609524706325,
#   'ETCP_x_to_y': 1,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 1,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.0058852609524706325,
#   'ETCE_y_to_x': 0.008879162107237768,
#   'ETCE_strength': 0.002993901154767136,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'y_causes_x',
#   'ETCE_cause': 'y',
#   'LZ_x': 186,
#   'LZ_y': 170,
#   'LZ_xy': 348,
#   'LZ_yx': 334,
#   'LZ_concat_mean': 341.0,
#   'LZ_concat_diff': 14,
#   'LZP_x_to_y': 148,
#   'LZP_y_to_x': 178,
#   'LZP_strength': 30,
#   'LZP_threshold': 1,
#   'LZP_direction': 'x_causes_y',
#   'LZP_cause': 'x',
#   'Consensus': False},
#  {'index_pair': 95,
#   'index_x': 9,
#   'index_y': 5,
#   'length_x': 84611,
#   'length_y': 156777,
#   'ETC_x': 571,
#   'ETC_y': 562,
#   'ETC_x_given_Gy': 4,
#   'ETC_y_given_Gx': 66,
#   'length_x_residual': 59349,
#   'length_y_residual': 29287,
#   'ETC_x_residual': 567,
#   'ETC_y_residual': 496,
#   'ETC_x_residual_norm': 0.00955381815730943,
#   'ETC_y_residual_norm': 0.016936420132486512,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.016936420132486512,
#   'ETCE_y_to_x': 0.00955381815730943,
#   'ETCE_strength': 0.007382601975177082,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 186,
#   'LZ_y': 152,
#   'LZ_xy': 324,
#   'LZ_yx': 309,
#   'LZ_concat_mean': 316.5,
#   'LZ_concat_diff': 15,
#   'LZP_x_to_y': 123,
#   'LZP_y_to_x': 172,
#   'LZP_strength': 49,
#   'LZP_threshold': 1,
#   'LZP_direction': 'x_causes_y',
#   'LZP_cause': 'x',
#   'Consensus': False},
#  {'index_pair': 96,
#   'index_x': 9,
#   'index_y': 6,
#   'length_x': 84611,
#   'length_y': 79104,
#   'ETC_x': 571,
#   'ETC_y': 792,
#   'ETC_x_given_Gy': 2,
#   'ETC_y_given_Gx': 86,
#   'length_x_residual': 74759,
#   'length_y_residual': 20474,
#   'ETC_x_residual': 569,
#   'ETC_y_residual': 708,
#   'ETC_x_residual_norm': 0.007611225554455711,
#   'ETC_y_residual_norm': 0.0345821325648415,
#   'ETCP_x_to_y': 2,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 2,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'y_causes_x',
#   'ETCP_cause': 'y',
#   'ETCE_x_to_y': 0.0345821325648415,
#   'ETCE_y_to_x': 0.007611225554455711,
#   'ETCE_strength': 0.026970907010385792,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 186,
#   'LZ_y': 239,
#   'LZ_xy': 398,
#   'LZ_yx': 409,
#   'LZ_concat_mean': 403.5,
#   'LZ_concat_diff': 11,
#   'LZP_x_to_y': 223,
#   'LZP_y_to_x': 159,
#   'LZP_strength': 64,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 97,
#   'index_x': 9,
#   'index_y': 7,
#   'length_x': 84611,
#   'length_y': 107954,
#   'ETC_x': 571,
#   'ETC_y': 877,
#   'ETC_x_given_Gy': 5,
#   'ETC_y_given_Gx': 66,
#   'length_x_residual': 58870,
#   'length_y_residual': 28068,
#   'ETC_x_residual': 566,
#   'ETC_y_residual': 811,
#   'ETC_x_residual_norm': 0.009614567938983166,
#   'ETC_y_residual_norm': 0.028895143763138204,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0.028895143763138204,
#   'ETCE_y_to_x': 0.009614567938983166,
#   'ETCE_strength': 0.019280575824155037,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'x_causes_y',
#   'ETCE_cause': 'x',
#   'LZ_x': 186,
#   'LZ_y': 234,
#   'LZ_xy': 400,
#   'LZ_yx': 403,
#   'LZ_concat_mean': 401.5,
#   'LZ_concat_diff': 3,
#   'LZP_x_to_y': 217,
#   'LZP_y_to_x': 166,
#   'LZP_strength': 51,
#   'LZP_threshold': 1,
#   'LZP_direction': 'y_causes_x',
#   'LZP_cause': 'y',
#   'Consensus': False},
#  {'index_pair': 98,
#   'index_x': 9,
#   'index_y': 8,
#   'length_x': 84611,
#   'length_y': 154627,
#   'ETC_x': 571,
#   'ETC_y': 512,
#   'ETC_x_given_Gy': 105,
#   'ETC_y_given_Gx': 84,
#   'length_x_residual': 1594,
#   'length_y_residual': 2720,
#   'ETC_x_residual': 468,
#   'ETC_y_residual': 422,
#   'ETC_x_residual_norm': 0.2937853107344633,
#   'ETC_y_residual_norm': 0.1552041191614564,
#   'ETCP_x_to_y': -6,
#   'ETCP_y_to_x': 2,
#   'ETCP_strength': 8,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'x_causes_y',
#   'ETCP_cause': 'x',
#   'ETCE_x_to_y': 0.1552041191614564,
#   'ETCE_y_to_x': 0.2937853107344633,
#   'ETCE_strength': 0.13858119157300688,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'y_causes_x',
#   'ETCE_cause': 'y',
#   'LZ_x': 186,
#   'LZ_y': 128,
#   'LZ_xy': 301,
#   'LZ_yx': 282,
#   'LZ_concat_mean': 291.5,
#   'LZ_concat_diff': 19,
#   'LZP_x_to_y': 96,
#   'LZP_y_to_x': 173,
#   'LZP_strength': 77,
#   'LZP_threshold': 1,
#   'LZP_direction': 'x_causes_y',
#   'LZP_cause': 'x',
#   'Consensus': False},
#  {'index_pair': 99,
#   'index_x': 9,
#   'index_y': 9,
#   'length_x': 84611,
#   'length_y': 84611,
#   'ETC_x': 571,
#   'ETC_y': 571,
#   'ETC_x_given_Gy': 571,
#   'ETC_y_given_Gx': 571,
#   'length_x_residual': 1,
#   'length_y_residual': 1,
#   'ETC_x_residual': 0,
#   'ETC_y_residual': 0,
#   'ETC_x_residual_norm': 0,
#   'ETC_y_residual_norm': 0,
#   'ETCP_x_to_y': 0,
#   'ETCP_y_to_x': 0,
#   'ETCP_strength': 0,
#   'ETCP_threshold': 1,
#   'ETCP_direction': 'n_or_m',
#   'ETCP_cause': 'n_or_m',
#   'ETCE_x_to_y': 0,
#   'ETCE_y_to_x': 0,
#   'ETCE_strength': 0,
#   'ETCE_tolerance': 0,
#   'ETCE_direction': 'n_or_m',
#   'ETCE_cause': 'n_or_m',
#   'LZ_x': 186,
#   'LZ_y': 186,
#   'LZ_xy': 187,
#   'LZ_yx': 187,
#   'LZ_concat_mean': 187.0,
#   'LZ_concat_diff': 0,
#   'LZP_x_to_y': 1,
#   'LZP_y_to_x': 1,
#   'LZP_strength': 0,
#   'LZP_threshold': 1,
#   'LZP_direction': 'n_or_m',
#   'LZP_cause': 'n_or_m',
#   'Consensus': True}]

# %%
draw.draw_causal_inference(dists, labels)
# Out:
# digraph "" {
# 	graph [bb="0,0,1100,540",
# 		rankdir=TD
# 	];
# 	node [label="\N"];
# 	"Jalajakshi(Hamsadhwani)"	[height=0.5,
# 		pos="423,162",
# 		width=3.5927];
# 	"Himadri-Sute(Kalyani)"	[height=0.5,
# 		pos="580,18",
# 		width=3.1955];
# 	"Jalajakshi(Hamsadhwani)" -> "Himadri-Sute(Kalyani)"	[pos="e,561.4,35.825 441.63,144.15 469.48,118.96 522.1,71.367 553.81,42.685",
# 		weight=1.0];
# 	"vaarana mukha va(Hamsadhwani)"	[height=0.5,
# 		pos="777,90",
# 		width=4.694];
# 	"Jalajakshi(Hamsadhwani)" -> "vaarana mukha va(Hamsadhwani)"	[pos="e,700.69,106.09 494.21,146.92 550.92,135.71 630.51,119.97 690.81,108.04",
# 		weight=1.0];
# 	"vaarana mukha va(Hamsadhwani)" -> "Himadri-Sute(Kalyani)"	[pos="e,624.21,34.708 730.81,72.588 701.77,62.269 664.18,48.913 633.8,38.116",
# 		weight=1.0];
# 	"Kamalambam(Kalyani)"	[height=0.5,
# 		pos="296,450",
# 		width=3.2136];
# 	"Kamalambam(Kalyani)" -> "Jalajakshi(Hamsadhwani)"	[pos="e,397.06,179.73 269.57,432.47 257.54,423.35 244.55,410.85 238,396 231.55,381.36 232.62,375.07 238,360 265.89,281.97 343.35,217.84 \
# 388.71,185.57",
# 		weight=1.0];
# 	"Kamalambam(Kalyani)" -> "Himadri-Sute(Kalyani)"	[pos="e,479.52,26.851 218.05,436.59 187.86,428.8 154.5,416.22 129,396 92.929,367.39 76,353.04 76,307 76,307 76,307 76,161 76,79.855 321.1,\
# 42.829 469.45,27.849",
# 		weight=1.0];
# 	"Kamalambam(Kalyani)" -> "vaarana mukha va(Hamsadhwani)"	[pos="e,612.26,94.026 245.3,433.71 191.45,413.96 114,373.93 114,307 114,307 114,307 114,233 114,133.06 405.67,103.23 602.1,94.464",
# 		weight=1.0];
# 	"nidhi-chala(Kalyani)"	[height=0.5,
# 		pos="359,378",
# 		width=2.8706];
# 	"Kamalambam(Kalyani)" -> "nidhi-chala(Kalyani)"	[pos="e,343.45,396.28 311.25,432.05 318.88,423.58 328.25,413.17 336.67,403.82",
# 		weight=1.0];
# 	"Pankaja-lochana(kalyani)"	[height=0.5,
# 		pos="717,306",
# 		width=3.5205];
# 	"Kamalambam(Kalyani)" -> "Pankaja-lochana(kalyani)"	[pos="e,674.58,323.12 348.68,433.84 383.54,423.61 430.18,409.56 471,396 538.48,373.59 615.43,345.3 665.03,326.71",
# 		weight=1.0];
# 	"raghunaayaka(Hamsadhwani)"	[height=0.5,
# 		pos="562,234",
# 		width=4.1524];
# 	"Kamalambam(Kalyani)" -> "raghunaayaka(Hamsadhwani)"	[pos="e,500.98,250.49 275.27,432.05 255.43,413.73 230.75,383.93 247,360 275.38,318.21 407.39,276.25 491.26,253.14",
# 		weight=1.0];
# 	"vatapi-ganapathim(Hamsadhwani)"	[height=0.5,
# 		pos="803,378",
# 		width=4.7482];
# 	"Kamalambam(Kalyani)" -> "vatapi-ganapathim(Hamsadhwani)"	[pos="e,703.81,392.7 379.44,437.48 465.27,425.63 599.39,407.11 693.67,394.1",
# 		weight=1.0];
# 	"nidhi-chala(Kalyani)" -> "Jalajakshi(Hamsadhwani)"	[pos="e,400.24,179.82 356.55,359.61 353.02,329.02 349.15,264.26 371,216 375.98,205.01 384.26,194.97 392.78,186.66",
# 		weight=1.0];
# 	"nidhi-chala(Kalyani)" -> "Himadri-Sute(Kalyani)"	[pos="e,510.46,32.346 327.62,360.78 288.87,338.24 228,293.53 228,235 228,235 228,235 228,161 228,102.59 396.81,56.98 500.62,34.454",
# 		weight=1.0];
# 	"nidhi-chala(Kalyani)" -> "vaarana mukha va(Hamsadhwani)"	[pos="e,622.96,97.41 343.92,360.04 308.49,318.13 227.15,208.42 285,144 306.96,119.54 478.51,105.39 612.94,97.955",
# 		weight=1.0];
# 	"nidhi-chala(Kalyani)" -> "Pankaja-lochana(kalyani)"	[pos="e,645.78,320.92 425.08,364.08 484.53,352.45 572.07,335.34 635.77,322.88",
# 		weight=1.0];
# 	"nidhi-chala(Kalyani)" -> "raghunaayaka(Hamsadhwani)"	[pos="e,537.84,251.9 382.68,360.43 419.01,335.02 488.56,286.37 529.55,257.7",
# 		weight=1.0];
# 	"Pankaja-lochana(kalyani)" -> "Jalajakshi(Hamsadhwani)"	[pos="e,542.52,169.02 723.73,287.74 730.17,268.02 736.67,235.91 720,216 698.21,189.97 622.34,176.71 552.74,169.97",
# 		weight=1.0];
# 	"Pankaja-lochana(kalyani)" -> "Himadri-Sute(Kalyani)"	[pos="e,694.87,19.318 757.39,288.83 843.38,252.18 1030.7,159.2 955,72 922.88,35.024 801.15,23.135 704.98,19.657",
# 		weight=1.0];
# 	"Pankaja-lochana(kalyani)" -> "vaarana mukha va(Hamsadhwani)"	[pos="e,773.9,108.17 725.06,287.6 729.58,277.38 735.08,264.13 739,252 753.92,205.84 765.69,150.51 771.98,118.2",
# 		weight=1.0];
# 	"Pankaja-lochana(kalyani)" -> "raghunaayaka(Hamsadhwani)"	[pos="e,598.65,251.55 680.66,288.59 658.95,278.79 631.18,266.24 607.96,255.76",
# 		weight=1.0];
# 	"raghunaayaka(Hamsadhwani)" -> "Jalajakshi(Hamsadhwani)"	[pos="e,455.7,179.47 529.06,216.41 509.84,206.73 485.42,194.43 464.85,184.08",
# 		weight=1.0];
# 	"raghunaayaka(Hamsadhwani)" -> "Himadri-Sute(Kalyani)"	[pos="e,578.55,36.232 563.44,215.85 566.56,178.83 573.93,91.181 577.7,46.386",
# 		weight=1.0];
# 	"raghunaayaka(Hamsadhwani)" -> "vaarana mukha va(Hamsadhwani)"	[pos="e,751.53,107.82 587.51,216.15 626.22,190.59 699.86,141.95 743.05,113.42",
# 		weight=1.0];
# 	"vatapi-ganapathim(Hamsadhwani)" -> "Jalajakshi(Hamsadhwani)"	[pos="e,535.52,170.95 825.6,359.96 836.06,350.63 847.4,338.11 853,324 858.91,309.13 860.72,302.01 853,288 824.07,235.52 794.98,237.38 \
# 739,216 677.59,192.55 605.55,179.46 545.77,172.16",
# 		weight=1.0];
# 	"vatapi-ganapathim(Hamsadhwani)" -> "Himadri-Sute(Kalyani)"	[pos="e,685.63,25.198 901.66,363.19 974.85,346.74 1062,311.15 1062,235 1062,235 1062,235 1062,161 1062,106.3 1025.8,96.798 977,72 929.21,\
# 47.693 794.95,33.439 695.73,25.946",
# 		weight=1.0];
# 	"vatapi-ganapathim(Hamsadhwani)" -> "vaarana mukha va(Hamsadhwani)"	[pos="e,788.1,108 834.71,360.11 847.88,351.27 861.76,339.11 869,324 875.92,309.57 872.47,303.62 869,288 854.45,222.44 815.68,152.85 793.39,\
# 116.5",
# 		weight=1.0];
# 	"vatapi-ganapathim(Hamsadhwani)" -> "Pankaja-lochana(kalyani)"	[pos="e,737.63,323.79 782.18,360.05 771.2,351.11 757.55,340.01 745.59,330.27",
# 		weight=1.0];
# 	"vatapi-ganapathim(Hamsadhwani)" -> "raghunaayaka(Hamsadhwani)"	[pos="e,560.63,252.23 701.69,363.49 651.63,354.77 598.3,341.72 581,324 565.26,307.88 561.16,282.1 560.62,262.43",
# 		weight=1.0];
# 	"sivakaameswari(Kalyani)"	[height=0.5,
# 		pos="440,522",
# 		width=3.5205];
# 	"sivakaameswari(Kalyani)" -> "Jalajakshi(Hamsadhwani)"	[pos="e,377.88,178.93 326.53,513.89 258.93,507.02 182.26,493.68 161,468 85.524,376.84 295.71,225.93 309,216 326.96,202.58 348.87,191.4 \
# 368.66,182.81",
# 		weight=1.0];
# 	"sivakaameswari(Kalyani)" -> "Himadri-Sute(Kalyani)"	[pos="e,472.72,24.614 345.88,509.87 216.62,491.93 0,451.09 0,379 0,379 0,379 0,161 0,96.018 55.753,96.35 116,72 176.85,47.405 346.33,32.721 \
# 462.69,25.249",
# 		weight=1.0];
# 	"sivakaameswari(Kalyani)" -> "vaarana mukha va(Hamsadhwani)"	[pos="e,821.39,107.46 552.9,513.76 666.75,505.4 834.11,489.93 895,468 950.32,448.07 976.51,446.87 1006,396 1067.7,289.65 993.79,212.91 \
# 892,144 873.14,131.23 850.71,120.12 830.69,111.41",
# 		weight=1.0];
# 	"sivakaameswari(Kalyani)" -> "Kamalambam(Kalyani)"	[pos="e,329.55,467.31 406.24,504.59 386.11,494.8 360.36,482.29 338.81,471.81",
# 		weight=1.0];
# 	"sivakaameswari(Kalyani)" -> "nidhi-chala(Kalyani)"	[pos="e,385.54,395.62 439.56,503.75 438.37,484.9 434.33,454.4 421,432 414.14,420.48 403.87,410.23 393.66,401.89",
# 		weight=1.0];
# 	"sivakaameswari(Kalyani)" -> "Pankaja-lochana(kalyani)"	[pos="e,841.11,309.89 548.02,512.58 691.54,498.78 932.88,465.63 983,396 1023.6,339.64 936.4,318.45 851.22,310.74",
# 		weight=1.0];
# 	"sivakaameswari(Kalyani)" -> "raghunaayaka(Hamsadhwani)"	[pos="e,431.84,242.87 329.11,513.19 264.28,506.05 191.29,492.68 171,468 160.84,455.64 165.49,447.02 171,432 199.88,353.25 220.68,330.49 \
# 293,288 331.64,265.29 378.26,252.12 421.74,244.54",
# 		weight=1.0];
# 	"sivakaameswari(Kalyani)" -> "vatapi-ganapathim(Hamsadhwani)"	[pos="e,795.06,396.19 540.5,510.93 613.08,502.2 703.76,487.83 736,468 760.43,452.98 779.04,425.5 790.37,405.03",
# 		weight=1.0];
# 	"Sive-Pahi Maam(Kalyani)"	[height=0.5,
# 		pos="600,450",
# 		width=3.5205];
# 	"sivakaameswari(Kalyani)" -> "Sive-Pahi Maam(Kalyani)"	[pos="e,562.82,467.27 477.11,504.76 499.85,494.82 529.15,482 553.44,471.37",
# 		weight=1.0];
# 	"Sive-Pahi Maam(Kalyani)" -> "Jalajakshi(Hamsadhwani)"	[pos="e,413.41,180.28 572.82,432.19 527.61,402.43 438.51,335.62 404,252 395.71,231.91 401.81,207.72 409.23,189.63",
# 		weight=1.0];
# 	"Sive-Pahi Maam(Kalyani)" -> "Himadri-Sute(Kalyani)"	[pos="e,690.3,23.256 721.53,444.81 823.86,439.2 960.58,426.15 1006,396 1075,350.17 1100,317.86 1100,235 1100,235 1100,235 1100,161 1100,\
# 108.4 1068.5,96.533 1022,72 967.93,43.488 811.92,29.975 700.59,23.812",
# 		weight=1.0];
# 	"Sive-Pahi Maam(Kalyani)" -> "vaarana mukha va(Hamsadhwani)"	[pos="e,804.15,107.88 726.59,448.76 824.96,445.55 950.04,433.83 983,396 1067.5,299.04 891.83,166.04 812.83,113.58",
# 		weight=1.0];
# 	"Sive-Pahi Maam(Kalyani)" -> "nidhi-chala(Kalyani)"	[pos="e,409.7,393.73 547.11,433.64 509.43,422.69 458.71,407.96 419.43,396.55",
# 		weight=1.0];
# 	"Sive-Pahi Maam(Kalyani)" -> "Pankaja-lochana(kalyani)"	[pos="e,672.89,322.88 600.52,431.87 601.92,412.57 606.76,381.13 623,360 633.49,346.34 648.57,335.66 663.59,327.58",
# 		weight=1.0];
# 	"Sive-Pahi Maam(Kalyani)" -> "raghunaayaka(Hamsadhwani)"	[pos="e,560.78,252.18 592.35,431.64 582.34,407.89 565.34,363.69 559,324 556.48,308.2 558.55,303.99 559,288 559.24,279.67 559.68,270.62 \
# 560.15,262.39",
# 		weight=1.0];
# 	"Sive-Pahi Maam(Kalyani)" -> "vatapi-ganapathim(Hamsadhwani)"	[pos="e,755.59,395.35 645.81,433.2 675.48,422.97 714.35,409.57 746.02,398.65",
# 		weight=1.0];
# }
